# %%
from utils import *
import os

# %%
#recurso_publico_complemento_operacao

#reading the file
df = pd.read_csv(
    r"SICOR_COMPLEMENTO_OPERACAO_BASICA.gz",
    sep=';',
    encoding='latin1',
    #setting proper dtypes
    dtype= microdados_recurso_publico_complemento()
)

#renaming variables
df = rename_variables(df)

#ordering variables
df = df[create_column_order('https://docs.google.com/spreadsheets/d/1jQmW-mZP541IGP8CvreGK7QmGP6Kljwv/edit#gid=1066786795')]

#saving the file
df.to_csv(
    r"output\recurso_publico_complemento_operacao.csv",
    na_rep='',
    index=False,
    encoding='utf-8',
    sep=','
)

# %%
#recurso_publico_cooperado
#reading the file
df = pd.read_csv(
    r"SICOR_LISTA_COOPERADOS.gz",
    sep=';',
    encoding='latin1',
    #setting proper dtypes
    dtype= microdados_recurso_publico_cooperado_dtype()
)

#renaming variables
df = rename_variables(df)

#ordering variables
df = df[create_column_order('https://docs.google.com/spreadsheets/d/1CIM_enrWOD6PxahuVdfBAQ8IRFl1HWVD/edit#gid=1419816679')]

#saving the file
df.to_csv(
    r"output\recurso_publico_cooperado.csv",
    na_rep='',
    index=False,
    encoding='utf-8',
    sep=','
)

# %%
#recurso_publico_gleba
#reading the file
df = pd.read_csv(
    r"SICOR_GLEBAS.gz",
    sep=';',
    encoding='latin1',
    #setting proper dtypes
    dtype= microdados_recurso_publico_gleba_dtype()
)

#renaming variables
df = rename_variables(df)

#ordering variables
df = df[create_column_order('https://docs.google.com/spreadsheets/d/1sulWvRnfJAgm2RsACQnbWF5PaX67wvgN/edit#gid=104533074')]

#saving the file
df.to_csv(
    r"output\recurso_publico_gleba.csv",
    na_rep='',
    index=False,
    encoding='utf-8',
    sep=','
)

# %%
#recurso_publico_mutuario
#reading the file
df = pd.read_csv(
    r"SICOR_MUTUARIOS.gz",
    sep=';',
    encoding='latin1',
    #setting proper dtypes
    dtype= microdados_recurso_publico_gleba_dtype()
)

#renaming variables
df = rename_variables(df)

#ordering variables
df = df[create_column_order('https://docs.google.com/spreadsheets/d/15utHspOlnQvuijoNKCdBbDx11YvTORl9/edit#gid=104533074')]

#saving the file
df.to_csv(
    r"output\recurso_publico_mutuario.csv",
    na_rep='',
    index=False,
    encoding='utf-8',
    sep=','
)

# %%
#recurso_propriedade
#reading the file
df = pd.read_csv(
    r"SICOR_PROPRIEDADES.gz",
    sep=';',
    encoding='latin1',
    #setting proper dtypes
    dtype= microdados_recurso_publico_propriedade_dtype()
)

#renaming variables
df = rename_variables(df)

#ordering variables
df = df[create_column_order('https://docs.google.com/spreadsheets/d/1W4t5muZT7qzts2cEdItLiWJ7djtFk4ob/edit#gid=646706852')]

#saving the file
df.to_csv(
    r"output\recurso_propriedade.csv",
    na_rep='',
    index=False,
    encoding='utf-8',
    sep=','
)
