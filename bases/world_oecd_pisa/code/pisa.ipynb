# %% [markdown]
# # Set up

# %%
# !pip install pyreadstat

import pandas as pd
import numpy as np
import os
from google.colab            import drive
import pyreadstat

drive.mount('/content/drive')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 2.5 MB 13.2 MB/s
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Listas

# %% [markdown]
# ### selected_variables

# %%
selected_variables = ['id_country_m49',
                      'id_school',
                      'id_student',
                      'assessment_type',
                      'national_centre_code',
                      'stratum',
                      'subregion',
                      'oecd',
                      'mode_respondent',
                      'language_questionnaire',
                      'language_assessment',
                      'id_form',
                      'international_grade',
                      'month_birth',
                      'year_birth',
                      'gender',
                      'effort_put_into_test',
                      'effort_would_have_invested',
                      'occupation_mother',
                      'occupation_father',
                      'occupation_self',
                      'grade_compared',
                      'age',
                      'national_study_programme',
                      'country_birth_self',
                      'country_birth_mother',
                      'country_birth_father',
                      'language_home',
                      'isced_level',
                      'isced_designation',
                      'isced_orientation',
                      'mother_isced',
                      'father_isced',
                      'highest_parent_isced',
                      'index_highest_parent_years_schooling',
                      'mother_isced_alternate_definition',
                      'father_isced_alternate_definition',
                      'highest_parent_isced_alternate_definition',
                      'index_highest_parent_international_years_schooling',
                      'mother_isei',
                      'father_isei',
                      'index_highest_parent_occupation',
                      'index_immigration_status',
                      'duration_early_childhood_education_care',
                      'grade_repetition',
                      'student_occupational_status',
                      'learning_time_mathematics',
                      'learning_time_language',
                      'learning_time_science',
                      'learning_time_total',
                      'school_change',
                      'number_educational_change',
                      'body_mass_index',
                      'index_economic_social_cultural_status',
                      'meta_cognition_understanding_remembering',
                      'meta_cognition_summarising',
                      'meta_cognition_assess_credibility',
                      'ict_home',
                      'ict_school',
                      'wle_home_possessions',
                      'wle_cultural_possessions',
                      'wle_home_educational_resources',
                      'wle_family_wealth',
                      'wle_ict_resources',
                      'wle_teacher_support_language',
                      'wle_perceived_feedback',
                      'wle_perceived_parents_emotional_support',
                      'wle_subjective_well_being_sense_belonging',
                      'wle_ict_use_outside_school_leisure',
                      'wle_ict_use_outside_school_work',
                      'wle_ict_use_at_school',
                      'wle_ict_interest',
                      'wle_ict_competence',
                      'wle_ict_autonomy',
                      'wle_ict_social_interaction',
                      'wle_parental_support_learning',
                      'wle_parents_emotional_support',
                      'wle_parents_perceived_school_quality',
                      'wle_school_policies_parental_involvement',
                      'wle_previous_parental_support_learning',
                      'wle_disciplinay_climate_specific_domain',
                      'wle_teacher_directed_instruction',
                      'wle_teacher_stimulation_reading',
                      'wle_adaptation_instruction',
                      'wle_perceived_teachers_interest',
                      'wle_joy_reading',
                      'wle_reading_self_concept_competence',
                      'wle_reading_self_concept_difficulty',
                      'wle_pisa_test_difficulty_perception',
                      'wle_competitiveness_perception',
                      'wle_cooperation_perception',
                      'wle_attitude_towards_school_learning_activities',
                      'wle_competitiveness',
                      'wle_work_mastery',
                      'wle_general_fear_failure',
                      'wle_eudaemonia',
                      'wle_subjective_well_being_positive_affect',
                      'wle_resilence',
                      'wle_mastery_goal_orientation',
                      'wle_self_efficacy_regarding_global_issues',
                      'wle_students_awareness_global_issues',
                      'wle_students_attitudes_towards_immigrants',
                      'wle_students_interest_learning_other_cultures',
                      'wle_perspective_taking',
                      'wle_cognitive_flexibility',
                      'wle_respect_people_from_other_cultures',
                      'wle_intercultural_communication_awareness',
                      'wle_global_mindedness',
                      'wle_discriminating_school_climate',
                      'wle_students_experience_being_bullied',
                      'wle_ict_use_during_lessons',
                      'wle_ict_use_outside_lessons',
                      'wle_carrer_information',
                      'wle_labour_market_information_by_school',
                      'wle_labour_market_information_outside_school',
                      'wle_financial_matters_confidence',
                      'wle_financial_matters_confidence_digital_devices',
                      'wle_financial_education_school_lessons',
                      'wle_parents_involvement_financial_literacy',
                      'wle_parents_reading_enjoyment',
                      'wle_parents_attitudes_towards_immigrants',
                      'wle_parents_interest_learking_other_cultures',
                      'wle_parents_awareness_global_issues',
                      'wle_body_image',
                      'wle_parents_social_connections',
                      'final_student_weight',
                      'student_weight_1',
                      'student_weight_2',
                      'student_weight_3',
                      'student_weight_4',
                      'student_weight_5',
                      'student_weight_6',
                      'student_weight_7',
                      'student_weight_8',
                      'student_weight_9',
                      'student_weight_10',
                      'student_weight_11',
                      'student_weight_12',
                      'student_weight_13',
                      'student_weight_14',
                      'student_weight_15',
                      'student_weight_16',
                      'student_weight_17',
                      'student_weight_18',
                      'student_weight_19',
                      'student_weight_20',
                      'student_weight_21',
                      'student_weight_22',
                      'student_weight_23',
                      'student_weight_24',
                      'student_weight_25',
                      'student_weight_26',
                      'student_weight_27',
                      'student_weight_28',
                      'student_weight_29',
                      'student_weight_30',
                      'student_weight_31',
                      'student_weight_32',
                      'student_weight_33',
                      'student_weight_34',
                      'student_weight_35',
                      'student_weight_36',
                      'student_weight_37',
                      'student_weight_38',
                      'student_weight_39',
                      'student_weight_40',
                      'student_weight_41',
                      'student_weight_42',
                      'student_weight_43',
                      'student_weight_44',
                      'student_weight_45',
                      'student_weight_46',
                      'student_weight_47',
                      'student_weight_48',
                      'student_weight_49',
                      'student_weight_50',
                      'student_weight_51',
                      'student_weight_52',
                      'student_weight_53',
                      'student_weight_54',
                      'student_weight_55',
                      'student_weight_56',
                      'student_weight_57',
                      'student_weight_58',
                      'student_weight_59',
                      'student_weight_60',
                      'student_weight_61',
                      'student_weight_62',
                      'student_weight_63',
                      'student_weight_64',
                      'student_weight_65',
                      'student_weight_66',
                      'student_weight_67',
                      'student_weight_68',
                      'student_weight_69',
                      'student_weight_70',
                      'student_weight_71',
                      'student_weight_72',
                      'student_weight_73',
                      'student_weight_74',
                      'student_weight_75',
                      'student_weight_76',
                      'student_weight_77',
                      'student_weight_78',
                      'student_weight_79',
                      'student_weight_80',
                      'randomly_assigned_unit_number',
                      'randomized_final_variance_stratum',
                      'plausible_value_1_mathematics',
                      'plausible_value_2_mathematics',
                      'plausible_value_3_mathematics',
                      'plausible_value_4_mathematics',
                      'plausible_value_5_mathematics',
                      'plausible_value_6_mathematics',
                      'plausible_value_7_mathematics',
                      'plausible_value_8_mathematics',
                      'plausible_value_9_mathematics',
                      'plausible_value_10_mathematics',
                      'plausible_value_1_reading',
                      'plausible_value_2_reading',
                      'plausible_value_3_reading',
                      'plausible_value_4_reading',
                      'plausible_value_5_reading',
                      'plausible_value_6_reading',
                      'plausible_value_7_reading',
                      'plausible_value_8_reading',
                      'plausible_value_9_reading',
                      'plausible_value_10_reading',
                      'plausible_value_1_science',
                      'plausible_value_2_science',
                      'plausible_value_3_science',
                      'plausible_value_4_science',
                      'plausible_value_5_science',
                      'plausible_value_6_science',
                      'plausible_value_7_science',
                      'plausible_value_8_science',
                      'plausible_value_9_science',
                      'plausible_value_10_science',
                      'senate_weight',
                      'date_database_creation']

# %% [markdown]
# ### dicionario_colunas

# %%
dicionario_colunas =  {
                      'CNT':	'id_country_iso_3',
                      'CNTRYID':	'id_country_m49',
                      'CNTSCHID':	'id_school',
                      'CNTSTUID':	'id_student',
                      'CYC':	'assessment_type',
                      'NatCen':	'national_centre_code',
                      'STRATUM':	'stratum',
                      'SUBNATIO':	'subregion',
                      'OECD':	'oecd',
                      'ADMINMODE':	'mode_respondent',
                      'LANGTEST_QQQ':	'language_questionnaire',
                      'LANGTEST_COG':	'language_assessment',
                      'BOOKID':	'id_form',
                      'ST001D01T':	'international_grade',
                      'ST003D02T':	'month_birth',
                      'ST003D03T':	'year_birth',
                      'ST004D01T':	'gender',
                      'EFFORT1':	'effort_put_into_test',
                      'EFFORT2':	'effort_would_have_invested',
                      'OCOD1':	'occupation_mother',
                      'OCOD2':	'occupation_father',
                      'OCOD3':	'occupation_self',
                      'GRADE':	'grade_compared',
                      'AGE':	'age',
                      'PROGN':	'national_study_programme',
                      'COBN_S':	'country_birth_self',
                      'COBN_M':	'country_birth_mother',
                      'COBN_F':	'country_birth_father',
                      'LANGN':	'language_home',
                      'ISCEDL':	'isced_level',
                      'ISCEDD':	'isced_designation',
                      'ISCEDO':	'isced_orientation',
                      'MISCED':	'mother_isced',
                      'FISCED':	'father_isced',
                      'HISCED':	'highest_parent_isced',
                      'PARED':	'index_highest_parent_years_schooling',
                      'MISCED_D':	'mother_isced_alternate_definition',
                      'FISCED_D':	'father_isced_alternate_definition',
                      'HISCED_D':	'highest_parent_isced_alternate_definition',
                      'PAREDINT':	'index_highest_parent_international_years_schooling',
                      'BMMJ1':	'mother_isei',
                      'BFMJ2':	'father_isei',
                      'HISEI':	'index_highest_parent_occupation',
                      'IMMIG':	'index_immigration_status',
                      'DURECEC':	'duration_early_childhood_education_care',
                      'REPEAT':	'grade_repetition',
                      'BSMJ':	'student_occupational_status',
                      'MMINS':	'learning_time_mathematics',
                      'LMINS':	'learning_time_language',
                      'SMINS':	'learning_time_science',
                      'TMINS':	'learning_time_total',
                      'SCCHANGE':	'school_change',
                      'CHANGE':	'number_educational_change',
                      'STUBMI':	'body_mass_index',
                      'ESCS':	'index_economic_social_cultural_status',
                      'UNDREM':	'meta_cognition_understanding_remembering',
                      'METASUM':	'meta_cognition_summarising',
                      'METASPAM':	'meta_cognition_assess_credibility',
                      'ICTHOME':	'ict_home',
                      'ICTSCH':	'ict_school',
                      'HOMEPOS':	'wle_home_possessions',
                      'CULTPOSS':	'wle_cultural_possessions',
                      'HEDRES':	'wle_home_educational_resources',
                      'WEALTH':	'wle_family_wealth',
                      'ICTRES':	'wle_ict_resources',
                      'TEACHSUP':	'wle_teacher_support_language',
                      'PERFEED':	'wle_perceived_feedback',
                      'EMOSUPS':	'wle_perceived_parents_emotional_support',
                      'BELONG':	'wle_subjective_well_being_sense_belonging',
                      'ENTUSE':	'wle_ict_use_outside_school_leisure',
                      'HOMESCH':	'wle_ict_use_outside_school_work',
                      'USESCH':	'wle_ict_use_at_school',
                      'INTICT':	'wle_ict_interest',
                      'COMPICT':	'wle_ict_competence',
                      'AUTICT':	'wle_ict_autonomy',
                      'SOIAICT':	'wle_ict_social_interaction',
                      'CURSUPP':	'wle_parental_support_learning',
                      'EMOSUPP':	'wle_parents_emotional_support',
                      'PQSCHOOL':	'wle_parents_perceived_school_quality',
                      'PASCHPOL':	'wle_school_policies_parental_involvement',
                      'PRESUPP':	'wle_previous_parental_support_learning',
                      'DISCLIMA':	'wle_disciplinay_climate_specific_domain',
                      'DIRINS':	'wle_teacher_directed_instruction',
                      'STIMREAD':	'wle_teacher_stimulation_reading',
                      'ADAPTIVITY':	'wle_adaptation_instruction',
                      'TEACHINT':	'wle_perceived_teachers_interest',
                      'JOYREAD':	'wle_joy_reading',
                      'SCREADCOMP':	'wle_reading_self_concept_competence',
                      'SCREADDIFF':	'wle_reading_self_concept_difficulty',
                      'PISADIFF':	'wle_pisa_test_difficulty_perception',
                      'PERCOMP':	'wle_competitiveness_perception',
                      'PERCOOP':	'wle_cooperation_perception',
                      'ATTLNACT':	'wle_attitude_towards_school_learning_activities',
                      'COMPETE':	'wle_competitiveness',
                      'WORKMAST':	'wle_work_mastery',
                      'GFOFAIL':	'wle_general_fear_failure',
                      'EUDMO':	'wle_eudaemonia',
                      'SWBP':	'wle_subjective_well_being_positive_affect',
                      'RESILIENCE':	'wle_resilence',
                      'MASTGOAL':	'wle_mastery_goal_orientation',
                      'GCSELFEFF':	'wle_self_efficacy_regarding_global_issues',
                      'GCAWARE':	'wle_students_awareness_global_issues',
                      'ATTIMM':	'wle_students_attitudes_towards_immigrants',
                      'INTCULT':	'wle_students_interest_learning_other_cultures',
                      'PERSPECT':	'wle_perspective_taking',
                      'COGFLEX':	'wle_cognitive_flexibility',
                      'RESPECT':	'wle_respect_people_from_other_cultures',
                      'AWACOM':	'wle_intercultural_communication_awareness',
                      'GLOBMIND':	'wle_global_mindedness',
                      'DISCRIM':	'wle_discriminating_school_climate',
                      'BEINGBULLIED':	'wle_students_experience_being_bullied',
                      'ICTCLASS':	'wle_ict_use_during_lessons',
                      'ICTOUTSIDE':	'wle_ict_use_outside_lessons',
                      'INFOCAR':	'wle_carrer_information',
                      'INFOJOB1':	'wle_labour_market_information_by_school',
                      'INFOJOB2':	'wle_labour_market_information_outside_school',
                      'FLCONFIN':	'wle_financial_matters_confidence',
                      'FLCONICT':	'wle_financial_matters_confidence_digital_devices',
                      'FLSCHOOL':	'wle_financial_education_school_lessons',
                      'FLFAMILY':	'wle_parents_involvement_financial_literacy',
                      'JOYREADP':	'wle_parents_reading_enjoyment',
                      'ATTIMMP':	'wle_parents_attitudes_towards_immigrants',
                      'INTCULTP':	'wle_parents_interest_learking_other_cultures',
                      'GCAWAREP':	'wle_parents_awareness_global_issues',
                      'BODYIMA':	'wle_body_image',
                      'SOCONPA':	'wle_parents_social_connections',
                      'W_FSTUWT':	'final_student_weight',
                      'W_FSTURWT1':	'student_weight_1',
                      'W_FSTURWT2':	'student_weight_2',
                      'W_FSTURWT3':	'student_weight_3',
                      'W_FSTURWT4':	'student_weight_4',
                      'W_FSTURWT5':	'student_weight_5',
                      'W_FSTURWT6':	'student_weight_6',
                      'W_FSTURWT7':	'student_weight_7',
                      'W_FSTURWT8':	'student_weight_8',
                      'W_FSTURWT9':	'student_weight_9',
                      'W_FSTURWT10':	'student_weight_10',
                      'W_FSTURWT11':	'student_weight_11',
                      'W_FSTURWT12':	'student_weight_12',
                      'W_FSTURWT13':	'student_weight_13',
                      'W_FSTURWT14':	'student_weight_14',
                      'W_FSTURWT15':	'student_weight_15',
                      'W_FSTURWT16':	'student_weight_16',
                      'W_FSTURWT17':	'student_weight_17',
                      'W_FSTURWT18':	'student_weight_18',
                      'W_FSTURWT19':	'student_weight_19',
                      'W_FSTURWT20':	'student_weight_20',
                      'W_FSTURWT21':	'student_weight_21',
                      'W_FSTURWT22':	'student_weight_22',
                      'W_FSTURWT23':	'student_weight_23',
                      'W_FSTURWT24':	'student_weight_24',
                      'W_FSTURWT25':	'student_weight_25',
                      'W_FSTURWT26':	'student_weight_26',
                      'W_FSTURWT27':	'student_weight_27',
                      'W_FSTURWT28':	'student_weight_28',
                      'W_FSTURWT29':	'student_weight_29',
                      'W_FSTURWT30':	'student_weight_30',
                      'W_FSTURWT31':	'student_weight_31',
                      'W_FSTURWT32':	'student_weight_32',
                      'W_FSTURWT33':	'student_weight_33',
                      'W_FSTURWT34':	'student_weight_34',
                      'W_FSTURWT35':	'student_weight_35',
                      'W_FSTURWT36':	'student_weight_36',
                      'W_FSTURWT37':	'student_weight_37',
                      'W_FSTURWT38':	'student_weight_38',
                      'W_FSTURWT39':	'student_weight_39',
                      'W_FSTURWT40':	'student_weight_40',
                      'W_FSTURWT41':	'student_weight_41',
                      'W_FSTURWT42':	'student_weight_42',
                      'W_FSTURWT43':	'student_weight_43',
                      'W_FSTURWT44':	'student_weight_44',
                      'W_FSTURWT45':	'student_weight_45',
                      'W_FSTURWT46':	'student_weight_46',
                      'W_FSTURWT47':	'student_weight_47',
                      'W_FSTURWT48':	'student_weight_48',
                      'W_FSTURWT49':	'student_weight_49',
                      'W_FSTURWT50':	'student_weight_50',
                      'W_FSTURWT51':	'student_weight_51',
                      'W_FSTURWT52':	'student_weight_52',
                      'W_FSTURWT53':	'student_weight_53',
                      'W_FSTURWT54':	'student_weight_54',
                      'W_FSTURWT55':	'student_weight_55',
                      'W_FSTURWT56':	'student_weight_56',
                      'W_FSTURWT57':	'student_weight_57',
                      'W_FSTURWT58':	'student_weight_58',
                      'W_FSTURWT59':	'student_weight_59',
                      'W_FSTURWT60':	'student_weight_60',
                      'W_FSTURWT61':	'student_weight_61',
                      'W_FSTURWT62':	'student_weight_62',
                      'W_FSTURWT63':	'student_weight_63',
                      'W_FSTURWT64':	'student_weight_64',
                      'W_FSTURWT65':	'student_weight_65',
                      'W_FSTURWT66':	'student_weight_66',
                      'W_FSTURWT67':	'student_weight_67',
                      'W_FSTURWT68':	'student_weight_68',
                      'W_FSTURWT69':	'student_weight_69',
                      'W_FSTURWT70':	'student_weight_70',
                      'W_FSTURWT71':	'student_weight_71',
                      'W_FSTURWT72':	'student_weight_72',
                      'W_FSTURWT73':	'student_weight_73',
                      'W_FSTURWT74':	'student_weight_74',
                      'W_FSTURWT75':	'student_weight_75',
                      'W_FSTURWT76':	'student_weight_76',
                      'W_FSTURWT77':	'student_weight_77',
                      'W_FSTURWT78':	'student_weight_78',
                      'W_FSTURWT79':	'student_weight_79',
                      'W_FSTURWT80':	'student_weight_80',
                      'UNIT':	'randomly_assigned_unit_number',
                      'WVARSTRR':	'randomized_final_variance_stratum',
                      'PV1MATH':	'plausible_value_1_mathematics',
                      'PV2MATH':	'plausible_value_2_mathematics',
                      'PV3MATH':	'plausible_value_3_mathematics',
                      'PV4MATH':	'plausible_value_4_mathematics',
                      'PV5MATH':	'plausible_value_5_mathematics',
                      'PV6MATH':	'plausible_value_6_mathematics',
                      'PV7MATH':	'plausible_value_7_mathematics',
                      'PV8MATH':	'plausible_value_8_mathematics',
                      'PV9MATH':	'plausible_value_9_mathematics',
                      'PV10MATH':	'plausible_value_10_mathematics',
                      'PV1READ':	'plausible_value_1_reading',
                      'PV2READ':	'plausible_value_2_reading',
                      'PV3READ':	'plausible_value_3_reading',
                      'PV4READ':	'plausible_value_4_reading',
                      'PV5READ':	'plausible_value_5_reading',
                      'PV6READ':	'plausible_value_6_reading',
                      'PV7READ':	'plausible_value_7_reading',
                      'PV8READ':	'plausible_value_8_reading',
                      'PV9READ':	'plausible_value_9_reading',
                      'PV10READ':	'plausible_value_10_reading',
                      'PV1SCIE':	'plausible_value_1_science',
                      'PV2SCIE':	'plausible_value_2_science',
                      'PV3SCIE':	'plausible_value_3_science',
                      'PV4SCIE':	'plausible_value_4_science',
                      'PV5SCIE':	'plausible_value_5_science',
                      'PV6SCIE':	'plausible_value_6_science',
                      'PV7SCIE':	'plausible_value_7_science',
                      'PV8SCIE':	'plausible_value_8_science',
                      'PV9SCIE':	'plausible_value_9_science',
                      'PV10SCIE':	'plausible_value_10_science',
                      'SENWT':	'senate_weight',
                      'VER_DAT':	'date_database_creation'}

# %% [markdown]
# ### original_name_variable_list

# %%
original_name_variable_list = [ 'CNT',
                                'CNTRYID',
                                'CNTSCHID',
                                'CNTSTUID',
                                'CYC',
                                'NatCen',
                                'STRATUM',
                                'SUBNATIO',
                                'OECD',
                                'ADMINMODE',
                                'LANGTEST_QQQ',
                                'LANGTEST_COG',
                                'BOOKID',
                                'ST001D01T',
                                'ST003D02T',
                                'ST003D03T',
                                'ST004D01T',
                                'EFFORT1',
                                'EFFORT2',
                                'OCOD1',
                                'OCOD2',
                                'OCOD3',
                                'GRADE',
                                'AGE',
                                'PROGN',
                                'COBN_S',
                                'COBN_M',
                                'COBN_F',
                                'LANGN',
                                'ISCEDL',
                                'ISCEDD',
                                'ISCEDO',
                                'MISCED',
                                'FISCED',
                                'HISCED',
                                'PARED',
                                'MISCED_D',
                                'FISCED_D',
                                'HISCED_D',
                                'PAREDINT',
                                'BMMJ1',
                                'BFMJ2',
                                'HISEI',
                                'IMMIG',
                                'DURECEC',
                                'REPEAT',
                                'BSMJ',
                                'MMINS',
                                'LMINS',
                                'SMINS',
                                'TMINS',
                                'SCCHANGE',
                                'CHANGE',
                                'STUBMI',
                                'ESCS',
                                'UNDREM',
                                'METASUM',
                                'METASPAM',
                                'ICTHOME',
                                'ICTSCH',
                                'HOMEPOS',
                                'CULTPOSS',
                                'HEDRES',
                                'WEALTH',
                                'ICTRES',
                                'TEACHSUP',
                                'PERFEED',
                                'EMOSUPS',
                                'BELONG',
                                'ENTUSE',
                                'HOMESCH',
                                'USESCH',
                                'INTICT',
                                'COMPICT',
                                'AUTICT',
                                'SOIAICT',
                                'CURSUPP',
                                'EMOSUPP',
                                'PQSCHOOL',
                                'PASCHPOL',
                                'PRESUPP',
                                'DISCLIMA',
                                'DIRINS',
                                'STIMREAD',
                                'ADAPTIVITY',
                                'TEACHINT',
                                'JOYREAD',
                                'SCREADCOMP',
                                'SCREADDIFF',
                                'PISADIFF',
                                'PERCOMP',
                                'PERCOOP',
                                'ATTLNACT',
                                'COMPETE',
                                'WORKMAST',
                                'GFOFAIL',
                                'EUDMO',
                                'SWBP',
                                'RESILIENCE',
                                'MASTGOAL',
                                'GCSELFEFF',
                                'GCAWARE',
                                'ATTIMM',
                                'INTCULT',
                                'PERSPECT',
                                'COGFLEX',
                                'RESPECT',
                                'AWACOM',
                                'GLOBMIND',
                                'DISCRIM',
                                'BEINGBULLIED',
                                'ICTCLASS',
                                'ICTOUTSIDE',
                                'INFOCAR',
                                'INFOJOB1',
                                'INFOJOB2',
                                'FLCONFIN',
                                'FLCONICT',
                                'FLSCHOOL',
                                'FLFAMILY',
                                'JOYREADP',
                                'ATTIMMP',
                                'INTCULTP',
                                'GCAWAREP',
                                'BODYIMA',
                                'SOCONPA',
                                'W_FSTUWT',
                                'W_FSTURWT1',
                                'W_FSTURWT2',
                                'W_FSTURWT3',
                                'W_FSTURWT4',
                                'W_FSTURWT5',
                                'W_FSTURWT6',
                                'W_FSTURWT7',
                                'W_FSTURWT8',
                                'W_FSTURWT9',
                                'W_FSTURWT10',
                                'W_FSTURWT11',
                                'W_FSTURWT12',
                                'W_FSTURWT13',
                                'W_FSTURWT14',
                                'W_FSTURWT15',
                                'W_FSTURWT16',
                                'W_FSTURWT17',
                                'W_FSTURWT18',
                                'W_FSTURWT19',
                                'W_FSTURWT20',
                                'W_FSTURWT21',
                                'W_FSTURWT22',
                                'W_FSTURWT23',
                                'W_FSTURWT24',
                                'W_FSTURWT25',
                                'W_FSTURWT26',
                                'W_FSTURWT27',
                                'W_FSTURWT28',
                                'W_FSTURWT29',
                                'W_FSTURWT30',
                                'W_FSTURWT31',
                                'W_FSTURWT32',
                                'W_FSTURWT33',
                                'W_FSTURWT34',
                                'W_FSTURWT35',
                                'W_FSTURWT36',
                                'W_FSTURWT37',
                                'W_FSTURWT38',
                                'W_FSTURWT39',
                                'W_FSTURWT40',
                                'W_FSTURWT41',
                                'W_FSTURWT42',
                                'W_FSTURWT43',
                                'W_FSTURWT44',
                                'W_FSTURWT45',
                                'W_FSTURWT46',
                                'W_FSTURWT47',
                                'W_FSTURWT48',
                                'W_FSTURWT49',
                                'W_FSTURWT50',
                                'W_FSTURWT51',
                                'W_FSTURWT52',
                                'W_FSTURWT53',
                                'W_FSTURWT54',
                                'W_FSTURWT55',
                                'W_FSTURWT56',
                                'W_FSTURWT57',
                                'W_FSTURWT58',
                                'W_FSTURWT59',
                                'W_FSTURWT60',
                                'W_FSTURWT61',
                                'W_FSTURWT62',
                                'W_FSTURWT63',
                                'W_FSTURWT64',
                                'W_FSTURWT65',
                                'W_FSTURWT66',
                                'W_FSTURWT67',
                                'W_FSTURWT68',
                                'W_FSTURWT69',
                                'W_FSTURWT70',
                                'W_FSTURWT71',
                                'W_FSTURWT72',
                                'W_FSTURWT73',
                                'W_FSTURWT74',
                                'W_FSTURWT75',
                                'W_FSTURWT76',
                                'W_FSTURWT77',
                                'W_FSTURWT78',
                                'W_FSTURWT79',
                                'W_FSTURWT80',
                                'UNIT',
                                'WVARSTRR',
                                'PV1MATH',
                                'PV2MATH',
                                'PV3MATH',
                                'PV4MATH',
                                'PV5MATH',
                                'PV6MATH',
                                'PV7MATH',
                                'PV8MATH',
                                'PV9MATH',
                                'PV10MATH',
                                'PV1READ',
                                'PV2READ',
                                'PV3READ',
                                'PV4READ',
                                'PV5READ',
                                'PV6READ',
                                'PV7READ',
                                'PV8READ',
                                'PV9READ',
                                'PV10READ',
                                'PV1SCIE',
                                'PV2SCIE',
                                'PV3SCIE',
                                'PV4SCIE',
                                'PV5SCIE',
                                'PV6SCIE',
                                'PV7SCIE',
                                'PV8SCIE',
                                'PV9SCIE',
                                'PV10SCIE',
                                'SENWT',
                                'VER_DAT']

# %% [markdown]
# # Funções

# %% [markdown]
# ### missing_columns(df_columns,all_columns)

# %%
def missing_columns(df_columns,all_columns):
  missing_columns = []
  for col in all_columns:
    if col not in df_columns:
      missing_columns.append(col)

  return missing_columns

# %% [markdown]
# # Editando e salvando arquivos

# %% [markdown]
# ##### 2018

# %%
df = pd.read_spss(r'/content/drive/Shareddrives/Base dos Dados - Geral/Dados/Conjuntos/mundo_oecd_pisa/input/2018/CY07_MSU_STU_QQQ.sav',
                  usecols = original_name_variable_list,
                  convert_categoricals = False)

# %%
df.rename(columns = dicionario_colunas, inplace = True)

# %%
for country in df['id_country_iso_3'].unique():
  path = '/content/drive/Shareddrives/Base dos Dados - Geral/Dados/Conjuntos/mundo_oecd_pisa/output/year=2018/id_country_iso_3={}'.format(country)
  
  try:
    os.makedirs(path)
  except:
    print('Já existe o diretório para o país {}'.format(country))

  selected_rows = df['id_country_iso_3']==country
  df_country  = df[selected_rows]
  df_country[selected_variables].to_csv(path + "/student.csv", index = False)

  del df_country

# %% [markdown]
# ##### 2015

# %%
df = pd.read_spss(r'/content/drive/Shareddrives/Base dos Dados - Geral/Dados/Conjuntos/mundo_oecd_pisa/input/2015/CY6_MS_CMB_STU_QQQ.sav',
                  usecols = original_name_variable_list,
                  convert_categoricals = False)

# %%
df.rename(columns = dicionario_colunas, inplace = True)

# %%
missing_columns = missing_columns(df.columns,selected_variables)
for country in df['id_country_iso_3'].unique():
  path = '/content/drive/Shareddrives/Base dos Dados - Geral/Dados/Conjuntos/mundo_oecd_pisa/output/year=2015/id_country_iso_3={}'.format(country)
  
  try:
    os.makedirs(path)
  except:
    print('Já existe o diretório para o país {}'.format(country))

  selected_rows = df['id_country_iso_3']==country
  df_country  = df[selected_rows]
  df_country[missing_columns] = ''
  df_country[selected_variables].to_csv(path + "/student.csv", index = False)

  del df_country
# Out:
# Já existe o diretório para o país ALB
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3645: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = value
# Já existe o diretório para o país DZA
# Já existe o diretório para o país AUS
# Já existe o diretório para o país AUT
# Já existe o diretório para o país BEL
# Já existe o diretório para o país BRA
# Já existe o diretório para o país BGR
# Já existe o diretório para o país CAN
# Já existe o diretório para o país CHL
# Já existe o diretório para o país TAP
# Já existe o diretório para o país COL
# Já existe o diretório para o país CRI
# Já existe o diretório para o país HRV
# Já existe o diretório para o país CZE
# Já existe o diretório para o país DNK
# ...
