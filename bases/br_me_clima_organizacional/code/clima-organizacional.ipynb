# %%
import os
import pandas as pd
import numpy as np

# %%
path = os.path.abspath(os.path.join('..', 'input'))
path_data = os.path.join(path, 'area-dados.xlsx')
visao_area = pd.read_excel(path_data)

# %%
visao_area = visao_area.set_index('index')
df_a = visao_area.T.copy()
df_a
# Out:
# index                                     subclasse_minusculo  \
# Médias                                           órgão (2020)
# Idade                                        25 anos ou menos
# Idade.1                               entre 26 anos e 34 anos
# Idade.2                               entre 35 anos e 44 anos
# Idade.3                               entre 45 anos e 54 anos
# ...                                                       ...
# Órgão.8143                192 - vice-presidencia da republica
# Órgão.8144                         192.1 - chefia de gabinete
# Órgão.8145  192.1.3 - departamento de administracao e fina...
# Órgão.8146  192.1.3.1 - coord.geral de orcam fin e contabi...
# Órgão.8147  192.1.3.2 - coordenacao geral de gestao de pes...
#
# index                                               subclasse  \
# Médias                                           Órgão (2020)
# Idade                                        25 anos ou menos
# ...

# %%
df_a['area_empresa'] = 'Área'
df_a = df_a.reset_index()

# %%
df_a.rename(columns = {'index':'classe',
                       'subclasse':'subclasse_maiusculo',
    'subclasse_minusculo':'subclasse',                       
    "Número de respostas":"quantidade_resposta",
    "Média Geral":"media_geral",
    "Média credibilidade":"credibilidade",
    "Média respeito":"respeito",
    "Média imparcialidade":"imparcialidade",
    "Média orgulho":"orgulho",
    "Média camaradagem":"camaradagem",
    "Media GPTW":"gestao",
    "Média adicionais":"adicionais",
    "Os gestores me mantêm informado sobre assuntos importantes e sobre mudanças na organização":"gestor_atualizacao_informacao",
    "Os gestores deixam claras suas expectativas":"gestor_expectativa_clara",
    "Posso fazer qualquer pergunta razoável aos gestores e obter respostas diretas":"gestor_resposta_direta",
    "É fácil se aproximar dos gestores e é também fácil falar com eles":"gestor_facil_proximidade",
    "Os gestores são competentes para tocar as atividades":"gestor_competente",
    "Os gestores selecionam pessoas que se enquadram bem aqui":"gestor_boa_selecao",
    "Os gestores sabem coordenar pessoas e distribuir tarefas adequadamente":"gestor_coordenacao_tarefa",
    "Os gestores confiam que as pessoas fazem um bom trabalho sem precisar controlá-las":"gestor_confianca_trabalho",
    "Os gestores aqui dão autonomia às pessoas":"gestor_autonomia",
    "Os gestores têm uma visão clara para onde estamos indo e como fazer para chegar lá":"gestor_visao_clara",
    "Os gestores cumprem o que prometem":"gestor_cumprimento_promessa",
    "Os gestores agem de acordo com o que falam":"gestor_coerencia_acao",
    "Os gestores são honestos e éticos na condução das atividades":"gestor_honestidade_etica",
    "A organização me oferece treinamento ou outras formas de desenvolvimento para o meu crescimento profissional":"oferta_desenvolvimento_profissional",
    "Eu recebo os equipamentos e recursos necessários para realizar meu trabalho":"equipamento_necessario_fornecido",
    "Os gestores agradecem o bom trabalho e o esforço extra":"gestor_agradecimento",
    "Os gestores reconhecem erros não intencionais como parte das atividades":"gestor_compreensao_erro",
    "Os gestores incentivam ideias e sugestões e as levam em consideração de forma sincera":"gestor_incentivo_ideia",
    "Os gestores envolvem as pessoas em decisões que afetam suas atividades e seu ambiente de trabalho":"gestor_envolvimento_decisao",
    "Este é um lugar fisicamente seguro para trabalhar":"ambiente_fisicamente_seguro",
    "Este é um lugar psicológica e emocionalmente saudável para trabalhar":"ambiente_psicologicamente_saudavel",
    "Nossas instalações contribuem para um bom ambiente de trabalho":"instalacao_bom_ambiente",
    "Posso me ausentar do trabalho quando necessário":"possibilidade_ausentar",
    "As pessoas são encorajadas a equilibrar sua vida profissional e pessoal":"equilibrio_profissional_pessoal",
    "Os gestores mostram interesse sincero por mim como pessoa e não somente como servidor":"gestor_interesse_pessoal",
    "Temos benefícios especiais e diferenciados aqui":"beneficio_diferenciado",
    "As pessoas aqui são pagas adequadamente pelo serviço que fazem":"remuneracao_adequada",
    "Todos aqui têm a oportunidade de receber um reconhecimento especial":"oportunidade_reconhecimento",
    "Eu sou considerado importante independentemente de minha posição na organização":"importancia_posicao_neutra",
    "As promoções são dadas às pessoas que realmente mais merecem":"promocao_merito",
    "Os gestores evitam o favoritismo":"gestor_sem_favoritismo",
    'As pessoas evitam fazer "politicagem" e intrigas como forma de obter resultados':"evitar_intriga",
    "As pessoas aqui são bem tratadas independentemente de sua idade":"tratada_bem_idade",
    "As pessoas aqui são bem tratadas independentemente de sua cor ou etnia":"tratada_bem_etnia_raca",
    "As pessoas aqui são bem tratadas independentemente de seu gênero":"tratada_bem_genero",
    "As pessoas aqui são bem tratadas independentemente de sua orientação sexual":"tratada_bem_orientacao_sexual",
    "Se eu for tratado injustamente, acredito que serei ouvido e acabarei recebendo um tratamento justo":"ser_ouvido_efetivamente",
    "As pessoas aqui estão dispostas a dar mais de si para concluir um trabalho":"disposicao_trabalho",
    "Pretendo trabalhar aqui por muito tempo":"continuar_trabalho",
    "As pessoas aqui têm vontade de vir para o trabalho":"vontade_trabalho",
    "Eu me sinto bem com a forma pela qual contribuímos para a comunidade":"realizacao_contribuicao_comunidade",
    "Posso ser eu mesmo por aqui":"liberdade_ser",
    "Aqui as pessoas se importam umas com as outras":"outra_pessoa_importa",
    "Este é um lugar descontraído para trabalhar":"ambiente_descontraido",
    "Quando se entra nesta organização, fazem você se sentir bem-vindo":"acolhimento_entrada",
    'Quando as pessoas mudam de função ou de área, a organização faz com que se sintam rapidamente "em casa"':"acolhimento_mudanca_funcao",
    "Existe um sentimento de equipe por aqui":"sentimento_equipe",
    "Pode-se contar com a colaboração das pessoas por aqui":"grupo_colaborativo",
    "Levando-se tudo em conta, eu diria que este é um excelente lugar para trabalhar":"ambiente_excelente_trabalho",
    "Nossos gestores representam plenamente os valores e comportamentos de nosso órgão":"gestor_representa_orgao",
    "Nós valorizamos pessoas que tentam fazer as coisas de formas novas e melhores, independentemente do resultado alcançado":"valoriza_inovacao",
    "Aqui, as pessoas se adaptam rapidamente às mudanças que são necessárias para o sucesso do órgão":"adaptacao_rapida_mudanca",
    "Com certeza, eu recomendaria meu órgão para amigos e família como um excelente lugar para trabalhar":"recomendacao_trabalho_orgao",
    "Nosso público-alvo classifica nossos serviços e/ou produtos como excelente":"produto_classificado_excelente",
    "Este órgão entrega ao seu público-alvo aquilo que promete com alta qualidade":"entrega_alta_qualidade",
    "As pessoas aqui são bem tratadas independentemente de serem pessoas com deficiência":"tratada_bem_deficiencia",
    "De maneira geral, eu estou satisfeito com meu trabalho.":"trabalho_satisfacao_geral",
    "Meu trabalho me inspira.":"trabalho_inspira",
    "O trabalho que desempenho me dá o sentimento de realização":"trabalho_realizacao",
    "Eu sinto uma forte conexão pessoal com meu órgão":"conexao_pessoal_orgao",
    "Me identifico com a missão do meu órgão":"identificacao_missao_orgao",
    "É importante para mim que meu trabalho contribua para o bem comum":"contribuicao_bem_comum",
    "Acredito que este órgão se preocupa com a acessibilidade das pessoas com deficiência":"orgao_preocupacao_acessibilidade",
    "Eu me sinto representado por minha entidade representativa":"entidade_representativa",
    "Estão claras as competências gerais que todos os servidores devem possuir":"clareza_competencia_geral",
    "Acredito que as avaliações de desempenho, de modo geral, são justas e refletem genuinamente o desempenho do avaliado":"avaliacao_desempenho_justa"}, inplace = True)

# %%
df_a = df_a[[
"classe",
"subclasse",
"area_empresa",
"quantidade_resposta",
"media_geral",
"credibilidade",
"respeito",
"imparcialidade",
"orgulho",
"camaradagem",
"gestao",
"adicionais",
"gestor_atualizacao_informacao",
"gestor_expectativa_clara",
"gestor_resposta_direta",
"gestor_facil_proximidade",
"gestor_competente",
"gestor_boa_selecao",
"gestor_coordenacao_tarefa",
"gestor_confianca_trabalho",
"gestor_autonomia",
"gestor_visao_clara",
"gestor_cumprimento_promessa",
"gestor_coerencia_acao",
"gestor_honestidade_etica",
"oferta_desenvolvimento_profissional",
"equipamento_necessario_fornecido",
"gestor_agradecimento",
"gestor_compreensao_erro",
"gestor_incentivo_ideia",
"gestor_envolvimento_decisao",
"ambiente_fisicamente_seguro",
"ambiente_psicologicamente_saudavel",
"instalacao_bom_ambiente",
"possibilidade_ausentar",
"equilibrio_profissional_pessoal",
"gestor_interesse_pessoal",
"beneficio_diferenciado",
"remuneracao_adequada",
"oportunidade_reconhecimento",
"importancia_posicao_neutra",
"promocao_merito",
"gestor_sem_favoritismo",
"evitar_intriga",
"tratada_bem_idade",
"tratada_bem_etnia_raca",
"tratada_bem_genero",
"tratada_bem_orientacao_sexual",
"ser_ouvido_efetivamente",
"disposicao_trabalho",
"continuar_trabalho",
"vontade_trabalho",
"realizacao_contribuicao_comunidade",
"liberdade_ser",
"outra_pessoa_importa",
"ambiente_descontraido",
"acolhimento_entrada",
"acolhimento_mudanca_funcao",
"sentimento_equipe",
"grupo_colaborativo",
"ambiente_excelente_trabalho",
"gestor_representa_orgao",
"valoriza_inovacao",
"adaptacao_rapida_mudanca",
"recomendacao_trabalho_orgao",
"produto_classificado_excelente",
"entrega_alta_qualidade",
"tratada_bem_deficiencia",
"trabalho_satisfacao_geral",
"trabalho_inspira",
"trabalho_realizacao",
"conexao_pessoal_orgao",
"identificacao_missao_orgao",
"contribuicao_bem_comum",
"orgao_preocupacao_acessibilidade",
"entidade_representativa",
"clareza_competencia_geral",
"avaliacao_desempenho_justa"]]

# %%
df_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8218 entries, 0 to 8217
# Data columns (total 78 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   classe                               8218 non-null   object
#  1   subclasse                            8218 non-null   object
#  2   area_empresa                         8218 non-null   object
#  3   quantidade_resposta                  8218 non-null   object
#  4   media_geral                          8218 non-null   object
#  5   credibilidade                        8218 non-null   object
#  6   respeito                             8218 non-null   object
#  7   imparcialidade                       8218 non-null   object
#  8   orgulho                              8218 non-null   object
#  9   camaradagem                          8218 non-null   object
#  10  gestao                               8218 non-null   object
# ...

# %% [markdown]
# ### visão empresa

# %%
path_data = os.path.join(path, 'empresa-dados.xlsx')
visao_empresa = pd.read_excel(path_data)

# %%
df_e = visao_empresa.set_index('index').T.copy()
df_e
# Out:
# index                                     subclasse_minusculo  \
# Médias                                           órgão (2020)
# Idade                                        25 anos ou menos
# Idade.1                               entre 26 anos e 34 anos
# Idade.2                               entre 35 anos e 44 anos
# Idade.3                               entre 45 anos e 54 anos
# ...                                                       ...
# Órgão.8143                192 - vice-presidencia da republica
# Órgão.8144                         192.1 - chefia de gabinete
# Órgão.8145  192.1.3 - departamento de administracao e fina...
# Órgão.8146  192.1.3.1 - coord.geral de orcam fin e contabi...
# Órgão.8147  192.1.3.2 - coordenacao geral de gestao de pes...
#
# index                                               subclasse  \
# Médias                                           Órgão (2020)
# Idade                                        25 anos ou menos
# ...

# %%
df_e['area_empresa'] = 'Empresa'
df_e = df_e.reset_index()

# %%
df_e.rename(columns = {'index':'classe',
    'subclasse':'subclasse_maiusculo',
    'subclasse_minusculo':'subclasse',
"Número de respostas":"quantidade_resposta",
"Média Geral":"media_geral",
"Média credibilidade":"credibilidade",
"Média respeito":"respeito",
"Média imparcialidade":"imparcialidade",
"Média orgulho":"orgulho",
"Média camaradagem":"camaradagem",
"Media GPTW":"gestao",
"Média adicionais":"adicionais",
"Os gestores me mantêm informado sobre assuntos importantes e sobre mudanças na organização":"gestor_atualizacao_informacao",
"Os gestores deixam claras suas expectativas":"gestor_expectativa_clara",
"Posso fazer qualquer pergunta razoável aos gestores e obter respostas diretas":"gestor_resposta_direta",
"É fácil se aproximar dos gestores e é também fácil falar com eles":"gestor_facil_proximidade",
"Os gestores são competentes para tocar as atividades":"gestor_competente",
"Os gestores selecionam pessoas que se enquadram bem aqui":"gestor_boa_selecao",
"Os gestores sabem coordenar pessoas e distribuir tarefas adequadamente":"gestor_coordenacao_tarefa",
"Os gestores confiam que as pessoas fazem um bom trabalho sem precisar controlá-las":"gestor_confianca_trabalho",
"Os gestores aqui dão autonomia às pessoas":"gestor_autonomia",
"Os gestores têm uma visão clara para onde estamos indo e como fazer para chegar lá":"gestor_visao_clara",
"Os gestores cumprem o que prometem":"gestor_cumprimento_promessa",
"Os gestores agem de acordo com o que falam":"gestor_coerencia_acao",
"Os gestores são honestos e éticos na condução das atividades":"gestor_honestidade_etica",
"A organização me oferece treinamento ou outras formas de desenvolvimento para o meu crescimento profissional":"oferta_desenvolvimento_profissional",
"Eu recebo os equipamentos e recursos necessários para realizar meu trabalho":"equipamento_necessario_fornecido",
"Os gestores agradecem o bom trabalho e o esforço extra":"gestor_agradecimento",
"Os gestores reconhecem erros não intencionais como parte das atividades":"gestor_compreensao_erro",
"Os gestores incentivam ideias e sugestões e as levam em consideração de forma sincera":"gestor_incentivo_ideia",
"Os gestores envolvem as pessoas em decisões que afetam suas atividades e seu ambiente de trabalho":"gestor_envolvimento_decisao",
"Este é um lugar fisicamente seguro para trabalhar":"ambiente_fisicamente_seguro",
"Este é um lugar psicológica e emocionalmente saudável para trabalhar":"ambiente_psicologicamente_saudavel",
"Nossas instalações contribuem para um bom ambiente de trabalho":"instalacao_bom_ambiente",
"Posso me ausentar do trabalho quando necessário":"possibilidade_ausentar",
"As pessoas são encorajadas a equilibrar sua vida profissional e pessoal":"equilibrio_profissional_pessoal",
"Os gestores mostram interesse sincero por mim como pessoa e não somente como servidor":"gestor_interesse_pessoal",
"Temos benefícios especiais e diferenciados aqui":"beneficio_diferenciado",
"As pessoas aqui são pagas adequadamente pelo serviço que fazem":"remuneracao_adequada",
"Todos aqui têm a oportunidade de receber um reconhecimento especial":"oportunidade_reconhecimento",
"Eu sou considerado importante independentemente de minha posição na organização":"importancia_posicao_neutra",
"As promoções são dadas às pessoas que realmente mais merecem":"promocao_merito",
"Os gestores evitam o favoritismo":"gestor_sem_favoritismo",
'As pessoas evitam fazer "politicagem" e intrigas como forma de obter resultados':"evitar_intriga",
"As pessoas aqui são bem tratadas independentemente de sua idade":"tratada_bem_idade",
"As pessoas aqui são bem tratadas independentemente de sua cor ou etnia":"tratada_bem_etnia_raca",
"As pessoas aqui são bem tratadas independentemente de seu gênero":"tratada_bem_genero",
"As pessoas aqui são bem tratadas independentemente de sua orientação sexual":"tratada_bem_orientacao_sexual",
"Se eu for tratado injustamente, acredito que serei ouvido e acabarei recebendo um tratamento justo":"ser_ouvido_efetivamente",
"As pessoas aqui estão dispostas a dar mais de si para concluir um trabalho":"disposicao_trabalho",
"Pretendo trabalhar aqui por muito tempo":"continuar_trabalho",
"As pessoas aqui têm vontade de vir para o trabalho":"vontade_trabalho",
"Eu me sinto bem com a forma pela qual contribuímos para a comunidade":"realizacao_contribuicao_comunidade",
"Posso ser eu mesmo por aqui":"liberdade_ser",
"Aqui as pessoas se importam umas com as outras":"outra_pessoa_importa",
"Este é um lugar descontraído para trabalhar":"ambiente_descontraido",
"Quando se entra nesta organização, fazem você se sentir bem-vindo":"acolhimento_entrada",
'Quando as pessoas mudam de função ou de área, a organização faz com que se sintam rapidamente "em casa"':"acolhimento_mudanca_funcao",
"Existe um sentimento de equipe por aqui":"sentimento_equipe",
"Pode-se contar com a colaboração das pessoas por aqui":"grupo_colaborativo",
"Levando-se tudo em conta, eu diria que este é um excelente lugar para trabalhar":"ambiente_excelente_trabalho",
"Nossos gestores representam plenamente os valores e comportamentos de nosso órgão":"gestor_representa_orgao",
"Nós valorizamos pessoas que tentam fazer as coisas de formas novas e melhores, independentemente do resultado alcançado":"valoriza_inovacao",
"Aqui, as pessoas se adaptam rapidamente às mudanças que são necessárias para o sucesso do órgão":"adaptacao_rapida_mudanca",
"Com certeza, eu recomendaria meu órgão para amigos e família como um excelente lugar para trabalhar":"recomendacao_trabalho_orgao",
"Nosso público-alvo classifica nossos serviços e/ou produtos como excelente":"produto_classificado_excelente",
"Este órgão entrega ao seu público-alvo aquilo que promete com alta qualidade":"entrega_alta_qualidade",
"As pessoas aqui são bem tratadas independentemente de serem pessoas com deficiência":"tratada_bem_deficiencia",
"De maneira geral, eu estou satisfeito com meu trabalho.":"trabalho_satisfacao_geral",
"Meu trabalho me inspira.":"trabalho_inspira",
"O trabalho que desempenho me dá o sentimento de realização":"trabalho_realizacao",
"Eu sinto uma forte conexão pessoal com meu órgão":"conexao_pessoal_orgao",
"Me identifico com a missão do meu órgão":"identificacao_missao_orgao",
"É importante para mim que meu trabalho contribua para o bem comum":"contribuicao_bem_comum",
"Acredito que este órgão se preocupa com a acessibilidade das pessoas com deficiência":"orgao_preocupacao_acessibilidade",
"Eu me sinto representado por minha entidade representativa":"entidade_representativa",
"Estão claras as competências gerais que todos os servidores devem possuir":"clareza_competencia_geral",
"Acredito que as avaliações de desempenho, de modo geral, são justas e refletem genuinamente o desempenho do avaliado":"avaliacao_desempenho_justa"}, inplace = True)

# %%
df_e
# Out:
# index      classe                                          subclasse  \
# 0          Médias                                       órgão (2020)
# 1           Idade                                   25 anos ou menos
# 2         Idade.1                            entre 26 anos e 34 anos
# 3         Idade.2                            entre 35 anos e 44 anos
# 4         Idade.3                            entre 45 anos e 54 anos
# ...           ...                                                ...
# 8213   Órgão.8143                192 - vice-presidencia da republica
# 8214   Órgão.8144                         192.1 - chefia de gabinete
# 8215   Órgão.8145  192.1.3 - departamento de administracao e fina...
# 8216   Órgão.8146  192.1.3.1 - coord.geral de orcam fin e contabi...
# 8217   Órgão.8147  192.1.3.2 - coordenacao geral de gestao de pes...
#
# index                                subclasse_maiusculo quantidade_resposta  \
# ...

# %%
df_e = df_e[[
"classe",
"subclasse",
"area_empresa",
"quantidade_resposta",
"media_geral",
"credibilidade",
"respeito",
"imparcialidade",
"orgulho",
"camaradagem",
"gestao",
"adicionais",
"gestor_atualizacao_informacao",
"gestor_expectativa_clara",
"gestor_resposta_direta",
"gestor_facil_proximidade",
"gestor_competente",
"gestor_boa_selecao",
"gestor_coordenacao_tarefa",
"gestor_confianca_trabalho",
"gestor_autonomia",
"gestor_visao_clara",
"gestor_cumprimento_promessa",
"gestor_coerencia_acao",
"gestor_honestidade_etica",
"oferta_desenvolvimento_profissional",
"equipamento_necessario_fornecido",
"gestor_agradecimento",
"gestor_compreensao_erro",
"gestor_incentivo_ideia",
"gestor_envolvimento_decisao",
"ambiente_fisicamente_seguro",
"ambiente_psicologicamente_saudavel",
"instalacao_bom_ambiente",
"possibilidade_ausentar",
"equilibrio_profissional_pessoal",
"gestor_interesse_pessoal",
"beneficio_diferenciado",
"remuneracao_adequada",
"oportunidade_reconhecimento",
"importancia_posicao_neutra",
"promocao_merito",
"gestor_sem_favoritismo",
"evitar_intriga",
"tratada_bem_idade",
"tratada_bem_etnia_raca",
"tratada_bem_genero",
"tratada_bem_orientacao_sexual",
"ser_ouvido_efetivamente",
"disposicao_trabalho",
"continuar_trabalho",
"vontade_trabalho",
"realizacao_contribuicao_comunidade",
"liberdade_ser",
"outra_pessoa_importa",
"ambiente_descontraido",
"acolhimento_entrada",
"acolhimento_mudanca_funcao",
"sentimento_equipe",
"grupo_colaborativo",
"ambiente_excelente_trabalho",
"gestor_representa_orgao",
"valoriza_inovacao",
"adaptacao_rapida_mudanca",
"recomendacao_trabalho_orgao",
"produto_classificado_excelente",
"entrega_alta_qualidade",
"tratada_bem_deficiencia",
"trabalho_satisfacao_geral",
"trabalho_inspira",
"trabalho_realizacao",
"conexao_pessoal_orgao",
"identificacao_missao_orgao",
"contribuicao_bem_comum",
"orgao_preocupacao_acessibilidade",
"entidade_representativa",
"clareza_competencia_geral",
"avaliacao_desempenho_justa"]]

# %% [markdown]
# ### juntando as tabelas

# %%
df_resposta = pd.concat([df_e,df_a]).reset_index(drop=True)
df_resposta
# Out:
# index      classe                                          subclasse  \
# 0          Médias                                       órgão (2020)
# 1           Idade                                   25 anos ou menos
# 2         Idade.1                            entre 26 anos e 34 anos
# 3         Idade.2                            entre 35 anos e 44 anos
# 4         Idade.3                            entre 45 anos e 54 anos
# ...           ...                                                ...
# 16431  Órgão.8143                192 - vice-presidencia da republica
# 16432  Órgão.8144                         192.1 - chefia de gabinete
# 16433  Órgão.8145  192.1.3 - departamento de administracao e fina...
# 16434  Órgão.8146  192.1.3.1 - coord.geral de orcam fin e contabi...
# 16435  Órgão.8147  192.1.3.2 - coordenacao geral de gestao de pes...
#
# index area_empresa quantidade_resposta media_geral credibilidade   respeito  \
# ...

# %%
for i in range(1,6):
    df_resposta['classe'].replace('Idade.'+str(i), 'Idade' , inplace = True)

# %%
for i in range(1,8148):
    df_resposta['classe'].replace('Órgão.'+str(i), 'Órgão' , inplace = True)

# %%
for i in range(1,7):
    df_resposta['classe'].replace('Escolaridade.'+str(i), 'Escolaridade' , inplace = True)

# %%
for i in range(1,8):
    df_resposta['classe'].replace('Tempo que você está trabalhando neste órgão.'+str(i), 'Tempo que você está trabalhando neste órgão' , inplace = True)

# %%
for i in range(1,28):
    df_resposta['classe'].replace('Estado em que se encontra em exercício.'+str(i), 'Estado em que se encontra em exercício' , inplace = True)

# %%
for i in range(1,5):
    df_resposta['classe'].replace('No último ano, quantas oportunidades significativas você teve para desenvolver novas e melhores formas de trabalhar?.'+str(i), 'No último ano, quantas oportunidades significativas você teve para desenvolver novas e melhores formas de trabalhar?' , inplace = True)

# %%
for i in range(1,6):
    df_resposta['classe'].replace('Com qual gênero você se identifica?.'+str(i), 'Com qual gênero você se identifica?' , inplace = True)

# %%
for i in range(1,7):
    df_resposta['classe'].replace('Cor ou Etnia.'+str(i), 'Cor ou Etnia' , inplace = True)

# %%
df_resposta['classe'].replace('Função.1', 'Função' , inplace = True)
df_resposta.replace('**', np.nan , inplace = True)
df_resposta.replace('***', np.nan , inplace = True)

# %%
df_resposta[df_resposta['classe']=='Médias']
# Out:
# index  classe     subclasse area_empresa  quantidade_resposta  media_geral  \
# 0      Médias  órgão (2020)      Empresa                32393    55.841900
# 8218   Médias  órgão (2020)         Área                32393    62.044783
#
# index  credibilidade   respeito  imparcialidade    orgulho  camaradagem  ...  \
# 0          50.464124  47.973947       57.207548  68.745724    55.590121  ...
# 8218       61.489076  54.430803       63.433135  66.077192    62.542389  ...
#
# index  trabalho_satisfacao_geral  trabalho_inspira  trabalho_realizacao  \
# 0                            NaN               NaN                  NaN
# 8218                   69.904028         63.619415            64.062549
#
# index  conexao_pessoal_orgao  identificacao_missao_orgao  \
# 0                  58.123460                   76.999394
# 8218               62.783242                   80.078003
#
# index  contribuicao_bem_comum  orgao_preocupacao_acessibilidade  \
# ...

# %%
df_remover = df_resposta[['classe','subclasse','area_empresa']]
df_resposta_novo = df_resposta.drop(df_remover, axis= 1)
df_resposta_novo = df_resposta_novo.astype('float')
df_resposta_novo['quantidade_resposta'] = df_resposta_novo['quantidade_resposta'].astype('Int64')
df_resposta_novo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16436 entries, 0 to 16435
# Data columns (total 75 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   quantidade_resposta                  16436 non-null  Int64
#  1   media_geral                          5366 non-null   float64
#  2   credibilidade                        5366 non-null   float64
#  3   respeito                             5366 non-null   float64
#  4   imparcialidade                       5366 non-null   float64
#  5   orgulho                              5366 non-null   float64
#  6   camaradagem                          5366 non-null   float64
#  7   gestao                               5366 non-null   float64
#  8   adicionais                           5366 non-null   float64
#  9   gestor_atualizacao_informacao        5366 non-null   float64
#  10  gestor_expectativa_clara             5366 non-null   float64
# ...

# %%
df_resposta_2 = pd.concat([df_remover,df_resposta_novo], axis = 1 )
df_resposta_2
# Out:
# index  classe                                          subclasse area_empresa  \
# 0      Médias                                       órgão (2020)      Empresa
# 1       Idade                                   25 anos ou menos      Empresa
# 2       Idade                            entre 26 anos e 34 anos      Empresa
# 3       Idade                            entre 35 anos e 44 anos      Empresa
# 4       Idade                            entre 45 anos e 54 anos      Empresa
# ...       ...                                                ...          ...
# 16431   Órgão                192 - vice-presidencia da republica         Área
# 16432   Órgão                         192.1 - chefia de gabinete         Área
# 16433   Órgão  192.1.3 - departamento de administracao e fina...         Área
# 16434   Órgão  192.1.3.1 - coord.geral de orcam fin e contabi...         Área
# 16435   Órgão  192.1.3.2 - coordenacao geral de gestao de pes...         Área
#
# ...

# %%
df_resposta_2['classe'].unique()
# Out:
# array(['Médias', 'Idade', 'Com qual gênero você se identifica?',
#        'Estado em que se encontra em exercício',
#        'Tempo que você está trabalhando neste órgão', 'Cor ou Etnia',
#        'Escolaridade',
#        'No último ano, quantas oportunidades significativas você teve para desenvolver novas e melhores formas de trabalhar?',
#        'Função', 'Órgão'], dtype=object)

# %%
df_resposta_2['classe'].replace('Com qual gênero você se identifica?', 'Gênero' , inplace = True)
df_resposta_2['classe'].replace('Tempo que você está trabalhando neste órgão', 'Tempo de trabalho no orgão' , inplace = True)
df_resposta_2['classe'].replace('Cor ou Etnia', 'Cor/Etnia' , inplace = True)
df_resposta_2['classe'].replace('No último ano, quantas oportunidades significativas você teve para desenvolver novas e melhores formas de trabalhar?', 'Quantidade de oportunidade para desenvolver novas e melhores formas de trabalhar' , inplace = True)

# %%
df_resposta_2['classe'].unique()
# Out:
# array(['Médias', 'Idade', 'Gênero', 'Unidade da Federação',
#        'Tempo de trabalho no orgão', 'Cor/Etnia', 'Escolaridade',
#        'Quantidade de oportunidade para desenvolver novas e melhores formas de trabalhar',
#        'Função', 'Órgão'], dtype=object)

# %%
df_resposta_2['classe'].replace('Estado em que se encontra em exercício', 'Unidade da Federação' , inplace = True)

# %%
path = os.path.abspath(os.path.join('..', 'output'))
path_df = os.path.join(path, 'clima-organizacional.csv')
df_resposta_2.to_csv(path_df, index=False)

# %%
df_resposta_2
# Out:
# index  classe                                          subclasse area_empresa  \
# 0      Médias                                       órgão (2020)      Empresa
# 1       Idade                                   25 anos ou menos      Empresa
# 2       Idade                            entre 26 anos e 34 anos      Empresa
# 3       Idade                            entre 35 anos e 44 anos      Empresa
# 4       Idade                            entre 45 anos e 54 anos      Empresa
# ...       ...                                                ...          ...
# 16431   Órgão                192 - vice-presidencia da republica         Área
# 16432   Órgão                         192.1 - chefia de gabinete         Área
# 16433   Órgão  192.1.3 - departamento de administracao e fina...         Área
# 16434   Órgão  192.1.3.1 - coord.geral de orcam fin e contabi...         Área
# 16435   Órgão  192.1.3.2 - coordenacao geral de gestao de pes...         Área
#
# ...
