# %%
## caged_brach
# %reload_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

pd.options.display.max_columns = 999
pd.options.display.max_rows = 1999
pd.options.display.max_colwidth = 200

from paths import *
from scpts import manipulation
from scpts import io
from scpts import caged

from basedosdados import Storage, Table, Dataset
import basedosdados as bd

import glob

# %% [markdown]
# ### Download Dados
#  - ftp://ftp.mtps.gov.br/pdet/microdados/CAGED/
#  - ftp://ftp.mtps.gov.br/pdet/microdados/CAGED_AJUSTES/
#  - ftp://ftp.mtps.gov.br/pdet/microdados/NOVO%20CAGED/

# %%
### CAGED ANTIGO
caged.caged_antigo_download()

### CAGED AJUSTES 
caged.caged_antigo_ajustes_download()

### CAGED AJUSTES
caged.caged_antigo_ajustes_2002a2009_download()
# Out:
# #===== CAGED ANTIGO =====#
#
# 01/2007 | já existe
# 02/2007 | já existe
# 03/2007 | já existe
# 04/2007 | já existe
# 05/2007 | já existe
# 06/2007 | já existe
# 07/2007 | já existe
# 08/2007 | já existe
# 09/2007 | já existe
# 10/2007 | já existe
# 11/2007 | já existe
# 12/2007 | já existe
# 01/2008 | já existe
# 02/2008 | já existe
# 03/2008 | já existe
# 04/2008 | já existe
# 05/2008 | já existe
# 06/2008 | já existe
# 07/2008 | já existe
# 08/2008 | já existe
# 09/2008 | já existe
# 10/2008 | já existe
# 11/2008 | já existe
# 12/2008 | já existe
# 01/2009 | já existe
# 02/2009 | já existe
# 03/2009 | já existe
# 04/2009 | já existe
# 05/2009 | já existe
# 06/2009 | já existe
# 07/2009 | já existe
# 08/2009 | já existe
# 09/2009 | já existe
# 10/2009 | já existe
# 11/2009 | já existe
# 12/2009 | já existe
# 01/2010 | já existe
# 02/2010 | já existe
# 03/2010 | já existe
# 04/2010 | já existe
# 05/2010 | já existe
# 06/2010 | já existe
# 07/2010 | já existe
# 08/2010 | já existe
# 09/2010 | já existe
# 10/2010 | já existe
# 11/2010 | já existe
# 12/2010 | já existe
# 01/2011 | já existe
# 02/2011 | já existe
# 03/2011 | já existe
# 04/2011 | já existe
# 05/2011 | já existe
# 06/2011 | já existe
# 07/2011 | já existe
# 08/2011 | já existe
# 09/2011 | já existe
# 10/2011 | já existe
# 11/2011 | já existe
# 12/2011 | já existe
# 01/2012 | já existe
# 02/2012 | já existe
# 03/2012 | já existe
# 04/2012 | já existe
# 05/2012 | já existe
# 06/2012 | já existe
# 07/2012 | já existe
# 08/2012 | já existe
# 09/2012 | já existe
# 10/2012 | já existe
# 11/2012 | já existe
# 12/2012 | já existe
# 01/2013 | já existe
# 02/2013 | já existe
# 03/2013 | já existe
# 04/2013 | já existe
# 05/2013 | já existe
# 06/2013 | já existe
# 07/2013 | já existe
# 08/2013 | já existe
# 09/2013 | já existe
# 10/2013 | já existe
# 11/2013 | já existe
# 12/2013 | já existe
# 01/2014 | já existe
# 02/2014 | já existe
# 03/2014 | já existe
# 04/2014 | já existe
# 05/2014 | já existe
# 06/2014 | já existe
# 07/2014 | já existe
# 08/2014 | já existe
# 09/2014 | já existe
# 10/2014 | já existe
# 11/2014 | já existe
# 12/2014 | já existe
# 01/2015 | já existe
# 02/2015 | já existe
# 03/2015 | já existe
# 04/2015 | já existe
# 05/2015 | já existe
# 06/2015 | já existe
# 07/2015 | já existe
# 08/2015 | já existe
# 09/2015 | já existe
# 10/2015 | já existe
# 11/2015 | já existe
# 12/2015 | já existe
# 01/2016 | já existe
# 02/2016 | já existe
# 03/2016 | já existe
# 04/2016 | já existe
# 05/2016 | já existe
# 06/2016 | já existe
# 07/2016 | já existe
# 08/2016 | já existe
# 09/2016 | já existe
# 10/2016 | já existe
# 11/2016 | já existe
# 12/2016 | já existe
# 01/2017 | já existe
# 02/2017 | já existe
# 03/2017 | já existe
# 04/2017 | já existe
# 05/2017 | já existe
# 06/2017 | já existe
# 07/2017 | já existe
# 08/2017 | já existe
# 09/2017 | já existe
# 10/2017 | já existe
# 11/2017 | já existe
# 12/2017 | já existe
# 01/2018 | já existe
# 02/2018 | já existe
# 03/2018 | já existe
# 04/2018 | já existe
# 05/2018 | já existe
# 06/2018 | já existe
# 07/2018 | já existe
# 08/2018 | já existe
# 09/2018 | já existe
# 10/2018 | já existe
# 11/2018 | já existe
# 12/2018 | já existe
# 01/2019 | já existe
# 02/2019 | já existe
# 03/2019 | já existe
# 04/2019 | já existe
# 05/2019 | já existe
# 06/2019 | já existe
# 07/2019 | já existe
# 08/2019 | já existe
# 09/2019 | já existe
# 10/2019 | já existe
# 11/2019 | já existe
# 12/2019 | já existe
#
#
# #=====  CAGED ANTIGO AJUSTES =====#
#
# 01/2010 | já existe
# 02/2010 | já existe
# 03/2010 | já existe
# 04/2010 | já existe
# 05/2010 | já existe
# 06/2010 | já existe
# 07/2010 | já existe
# 08/2010 | já existe
# 09/2010 | já existe
# 10/2010 | já existe
# 11/2010 | já existe
# 12/2010 | já existe
# 01/2011 | já existe
# 02/2011 | já existe
# 03/2011 | já existe
# 04/2011 | já existe
# 05/2011 | já existe
# 06/2011 | já existe
# 07/2011 | já existe
# 08/2011 | já existe
# 09/2011 | já existe
# 10/2011 | já existe
# 11/2011 | já existe
# 12/2011 | já existe
# 01/2012 | já existe
# 02/2012 | já existe
# 03/2012 | já existe
# 04/2012 | já existe
# 05/2012 | já existe
# 06/2012 | já existe
# 07/2012 | já existe
# 08/2012 | já existe
# 09/2012 | já existe
# 10/2012 | já existe
# 11/2012 | já existe
# 12/2012 | já existe
# 01/2013 | já existe
# 02/2013 | já existe
# 03/2013 | já existe
# 04/2013 | já existe
# 05/2013 | já existe
# 06/2013 | já existe
# 07/2013 | já existe
# 08/2013 | já existe
# 09/2013 | já existe
# 10/2013 | já existe
# 11/2013 | já existe
# 12/2013 | já existe
# 01/2014 | já existe
# 02/2014 | já existe
# 03/2014 | já existe
# 04/2014 | já existe
# 05/2014 | já existe
# 06/2014 | já existe
# 07/2014 | já existe
# 08/2014 | já existe
# 09/2014 | já existe
# 10/2014 | já existe
# 11/2014 | já existe
# 12/2014 | já existe
# 01/2015 | já existe
# 02/2015 | já existe
# 03/2015 | já existe
# 04/2015 | já existe
# 05/2015 | já existe
# 06/2015 | já existe
# 07/2015 | já existe
# 08/2015 | já existe
# 09/2015 | já existe
# 10/2015 | já existe
# 11/2015 | já existe
# 12/2015 | já existe
# 01/2016 | já existe
# 02/2016 | já existe
# 03/2016 | já existe
# 04/2016 | já existe
# 05/2016 | já existe
# 06/2016 | já existe
# 07/2016 | já existe
# 08/2016 | já existe
# 09/2016 | já existe
# 10/2016 | já existe
# 11/2016 | já existe
# 12/2016 | já existe
# 01/2017 | já existe
# 02/2017 | já existe
# 03/2017 | já existe
# 04/2017 | já existe
# 05/2017 | já existe
# 06/2017 | já existe
# 07/2017 | já existe
# 08/2017 | já existe
# 09/2017 | já existe
# 10/2017 | já existe
# 11/2017 | já existe
# 12/2017 | já existe
# 01/2018 | já existe
# 02/2018 | já existe
# 03/2018 | já existe
# 04/2018 | já existe
# 05/2018 | já existe
# 06/2018 | já existe
# 07/2018 | já existe
# 08/2018 | já existe
# 09/2018 | já existe
# 10/2018 | já existe
# 11/2018 | já existe
# 12/2018 | já existe
# 01/2019 | já existe
# 02/2019 | já existe
# 03/2019 | já existe
# 04/2019 | já existe
# 05/2019 | já existe
# 06/2019 | já existe
# 07/2019 | já existe
# 08/2019 | já existe
# 09/2019 | já existe
# 10/2019 | já existe
# 11/2019 | já existe
# 12/2019 | já existe
#
#
# #===== CAGED ANTIGO AJUSTES 2002a2009 =====#
#
# 2007 | criado em 00:02
# 2008 | não conseguiu baixar
# 2009 | criado em 00:02

# %%
## os arquivos de 2002 a 2009 não estão separadas por mês, 
## essa etapa extrai os dados e organiza na forma ano/mes
folders = glob.glob("../data/caged/raw/caged_antigo_ajustes/*/")
caged.caged_antigo_ajustes_2002a2009_extract_organize(folders)
# Out:
# 2007 | extraido
# 2008 | extraido
# 2009 | extraido

# %% [markdown]
# ### Padronizacao

# %% [markdown]
# - o arquivo CAGED_062012 teve troca de nome quando foi descompactado
# &nbsp;
# - Particao | ano=XXXX/mex=XX/sigla_uf=XX

# %%
# ##--------------Download basedosdados---------------###
# q_municipios = """
# SELECT id_municipio,id_municipio_6,sigla_uf
# FROM `basedosdados.br_bd_diretorios_brasil.municipio`
# """
# municipios = bd.read_sql(q_municipios, billing_project_id='gabinete-sv')
# municipios.to_parquet(f'../data/caged/raw/municipios.parquet')

# %%
### Padroniza CAGED ANTIGO AJUSTES  
clean_save_path = "../data/caged/clean/caged_antigo_ajustes/"
folders = glob.glob("../data/caged/raw/caged_antigo_ajustes/*/*/")
municipios = pd.read_parquet('../data/caged/raw/municipios.parquet')

caged.caged_antigo_padronize_and_partitioned(
    folders, 
    clean_save_path, 
    municipios, 
    force_remove_csv=False
)
# Out:
# 2007-1 | já tratado
#
# 2007-10 | já tratado
#
# 2007-11 | já tratado
#
# 2007-12 | já tratado
#
# 2007-2 | já tratado
#
# 2007-3 | já tratado
#
# 2007-4 | já tratado
#
# 2007-5 | já tratado
#
# 2007-6 | já tratado
#
# 2007-7 | já tratado
#
# 2007-8 | já tratado
#
# 2007-9 | já tratado
#
# 2008-1 | já tratado
#
# 2008-10 | já tratado
#
# 2008-11 | já tratado
#
# 2008-12 | já tratado
#
# 2008-2 | já tratado
#
# 2008-3 | já tratado
#
# 2008-4 | já tratado
#
# 2008-5 | já tratado
#
# 2008-6 | já tratado
#
# 2008-7 | já tratado
#
# 2008-8 | já tratado
#
# 2008-9 | já tratado
#
# 2009-1 | já tratado
#
# 2009-10 | já tratado
#
# 2009-11 | já tratado
#
# 2009-12 | já tratado
#
# 2009-2 | já tratado
#
# 2009-3 | já tratado
#
# 2009-4 | já tratado
#
# 2009-5 | já tratado
#
# 2009-6 | já tratado
#
# 2009-7 | já tratado
#
# 2009-8 | já tratado
#
# 2009-9 | já tratado
#
# 2010-1 | já tratado
#
# 2010-10 | já tratado
#
# 2010-11 | já tratado
#
# 2010-12 | já tratado
#
# 2010-2 | já tratado
#
# 2010-3 | já tratado
#
# 2010-4 | já tratado
#
# 2010-5 | já tratado
#
# 2010-6 | já tratado
#
# 2010-7 | já tratado
#
# 2010-8 | já tratado
#
# 2010-9 | já tratado
#
# 2011-1 | já tratado
#
# 2011-10 | já tratado
#
# 2011-11 | já tratado
#
# 2011-12 | já tratado
#
# 2011-2 | já tratado
#
# 2011-3 | já tratado
#
# 2011-4 | já tratado
#
# 2011-5 | já tratado
#
# 2011-6 | já tratado
#
# 2011-7 | já tratado
#
# 2011-8 | já tratado
#
# 2011-9 | já tratado
#
# 2012-1 | já tratado
#
# 2012-10 | já tratado
#
# 2012-11 | já tratado
#
# 2012-12 | já tratado
#
# 2012-2 | já tratado
#
# 2012-3 | já tratado
#
# 2012-4 | já tratado
#
# 2012-5 | já tratado
#
# 2012-6 | já tratado
#
# 2012-7 | já tratado
#
# 2012-8 | já tratado
#
# 2012-9 | já tratado
#
# 2013-1 | já tratado
#
# 2013-10 | já tratado
#
# 2013-11 | já tratado
#
# 2013-12 | já tratado
#
# 2013-2 | já tratado
#
# 2013-3 | já tratado
#
# 2013-4 | já tratado
#
# 2013-5 | já tratado
#
# 2013-6 | já tratado
#
# 2013-7 | já tratado
#
# 2013-8 | já tratado
#
# 2013-9 | já tratado
#
# 2014-1 | já tratado
#
# 2014-10 | já tratado
#
# 2014-11 | já tratado
#
# 2014-12 | já tratado
#
# 2014-2 | já tratado
#
# 2014-3 | já tratado
#
# 2014-4 | já tratado
#
# 2014-5 | já tratado
#
# 2014-6 | já tratado
#
# 2014-7 | já tratado
#
# 2014-8 | já tratado
#
# 2014-9 | já tratado
#
# 2015-1 | já tratado
#
# 2015-10 | já tratado
#
# 2015-11 | já tratado
#
# 2015-12 | já tratado
#
# 2015-2 | já tratado
#
# 2015-3 | já tratado
#
# 2015-4 | já tratado
#
# 2015-5 | já tratado
#
# 2015-6 | já tratado
#
# 2015-7 | já tratado
#
# 2015-8 | já tratado
#
# 2015-9 | já tratado
#
# 2016-1 | já tratado
#
# 2016-10 | já tratado
#
# 2016-11 | já tratado
#
# 2016-12 | já tratado
#
# 2016-2 | já tratado
#
# 2016-3 | já tratado
#
# 2016-4 | já tratado
#
# 2016-5 | já tratado
#
# 2016-6 | já tratado
#
# 2016-7 | já tratado
#
# 2016-8 | já tratado
#
# 2016-9 | já tratado
#
# 2017-1 | já tratado
#
# 2017-10 | já tratado
#
# 2017-11 | já tratado
#
# 2017-12 | já tratado
#
# 2017-2 | já tratado
#
# 2017-3 | já tratado
#
# 2017-4 | já tratado
#
# 2017-5 | já tratado
#
# 2017-6 | já tratado
#
# 2017-7 | já tratado
#
# 2017-8 | já tratado
#
# 2017-9 | já tratado
#
# 2018-1 | já tratado
#
# 2018-10 | já tratado
#
# 2018-11 | já tratado
#
# 2018-12 | já tratado
#
# 2018-2 | já tratado
#
# 2018-3 | já tratado
#
# 2018-4 | já tratado
#
# 2018-5 | já tratado
#
# 2018-6 | já tratado
#
# 2018-7 | já tratado
#
# 2018-8 | já tratado
#
# 2018-9 | já tratado
#
# 2019-1 | já tratado
#
# 2019-10 | já tratado
#
# 2019-11 | já tratado
#
# 2019-12 | já tratado
#
# 2019-2 | já tratado
#
# 2019-3 | já tratado
#
# 2019-4 | já tratado
#
# 2019-5 | já tratado
#
# 2019-6 | já tratado
#
# 2019-7 | já tratado
#
# 2019-8 | já tratado
#
# 2019-9 | já tratado

# %%
### Padroniza CAGED ANTIGO
clean_save_path = "../data/caged/clean/caged_antigo/"
folders = glob.glob("../data/caged/raw/caged_antigo/*/*/")
municipios = pd.read_parquet('../data/caged/raw/municipios.parquet')



df = caged.caged_antigo_padronize_and_partitioned(
    folders[68:], 
    clean_save_path, 
    municipios, 
    force_remove_csv=False
)
# Out:
# 2012-6 | extraido
# 2012-6 | padronizado | padrao
# 2012-6 | finalizado
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-26-9661c4f4062b> in <module>
#       6
#       7
# ----> 8 df = caged.caged_antigo_padronize_and_partitioned(
#       9     folders[68:],
#      10     clean_save_path,
#
# /mnt/AEB0CCA7B0CC777D/Jlab/gabinete_sv/bd+/mais_projects/scpts/caged.py in caged_antigo_padronize_and_partitioned(folders, clean_save_path, municipios, force_remove_csv)
#     356         dd = dd[["ano", "mes"] + cols]
#     357
# --> 358         all_cols = pd.concat([all_cols, dd])
#     359
#     360
#
# UnboundLocalError: local variable 'all_cols' referenced before assignment

# %%
# for ano in range(2007,2020):
#     os.mkdir('../data/caged/clean/caged_antigo_ajustes/'  + str(ano))

# %% [markdown]
# ### SOBE DADOS PARA BASEDOSDADOS | CAGED ANTIGO

# %%
# CAGED ANTIGO AJUSTES

# tb = Table('microdados_antigo_ajutes','br_me_caged')

# tb.create(
#     path='../data/caged/clean/caged_antigo_ajustes/2007/',
#     if_table_exists='replace',
#     if_storage_data_exists='pass',
#     if_table_config_exists='pass'
# )


# for ano in range(2008,2019):
#     tb.append(
#         filepath=f'../data/caged/clean/caged_antigo_ajustes/{ano}/',
#         partitions='ano=value/mes=value/sigla_uf=value',
#         if_exists='replace'
#     )
#     print(f'{ano} done!\n')
    
# tb.publish(if_exists='replace')

# %%
# CAGED ANTIGO PADRAO

tb = Table('microdados_antigo','br_me_caged')

# tb.create(
#     path='../data/caged/clean/caged_antigo/2019/',
#     if_table_exists='replace',
#     if_storage_data_exists='replace',
#     if_table_config_exists='pass'
# )


# for ano in range(2007,2019):
#     tb.append(
#         filepath=f'../data/caged/clean/caged_antigo/{ano}/',
#         partitions='ano=value/mes=value/sigla_uf=value',
#         if_exists='replace'
#     )
#     print(f'{ano} done!\n')
    
# tb.publish(if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-58-34aa7df48726> in <module>
#       2
#       3 tb = Table('microdados_antigo','br_me_caged')
# ----> 4 tb.update('prod')
#       5 # tb.create(
#       6 #     path='../data/caged/clean/caged_antigo/2019/',
#
# /mnt/AEB0CCA7B0CC777D/Jlab/gabinete_sv/bd+/mais_source/mais/python-package/basedosdados/table.py in update(self, mode, not_found_ok)
#     452
#     453             if m == "prod":
# --> 454                 table.schema = self._load_schema(m)
#     455
#     456                 self.client[f"bigquery_{m}"].update_table(
#
# /mnt/AEB0CCA7B0CC777D/Jlab/gabinete_sv/bd+/mais_source/mais/python-package/basedosdados/table.py in _load_schema(self, mode)
#      91             # raise if field is not in table_config
#      92             if not_in_columns:
# ---> 93                 raise Exception(
#      94                     "Column {error_columns} was not found in table_config.yalm. Are you sure that "
#      95                     "all your column names between table_config.yaml, publish.sql and "
#
# Exception: Column ['cnae_10', 'cnae_20', 'cnae_20_subclasse', 'raca'] was not found in table_config.yalm. Are you sure that all your column names between table_config.yaml, publish.sql and basedosdados-dev.br_me_caged.microdados_antigo are the same?

# %% [markdown]
# ### SOBE DADOS PARA BASEDOSDADOS | CAGED NOVO
