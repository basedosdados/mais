# %%
import basedosdados as bd
import pandas as pd
import os
import numpy as np

# %%
path = os.path.abspath(os.path.join('..', 'input'))

# %% [markdown]
# ### recursos

# %%
path_munic = os.path.join(path, 'MUNIC_2018_recursos.csv')
munic = pd.read_csv(path_munic)

# %%
munic_rec = munic[['Cod Municipio','MREH04']]
munic_rec['ano'] = 2018

# %%
def lab(munic_rec):
    if (munic_rec['MREH04'] == 'Recusa'):
        return 1
    elif (munic_rec['MREH04'] != 'Recusa'):
        return 0
munic_rec["recusa"] = munic_rec.apply(lambda munic_rec:lab(munic_rec),axis = 1)

# %%
munic_rec.rename(columns = {'Cod Municipio':'id_municipio' , 'MREH04':'existencia_priorizacao_cargo_mulher'}, inplace = True)

# %%
munic_rec['existencia_priorizacao_cargo_mulher'].replace('Sim',1, inplace = True)
munic_rec['existencia_priorizacao_cargo_mulher'].replace('Não', 0 , inplace = True)
munic_rec['existencia_priorizacao_cargo_mulher'].replace('Não informou', np.nan , inplace = True)
munic_rec['existencia_priorizacao_cargo_mulher'].replace('Recusa', np.nan , inplace = True)

# %%
munic_rec['existencia_priorizacao_cargo_mulher'] = munic_rec['existencia_priorizacao_cargo_mulher'].astype('float').astype('Int64')

# %%
munic_rec['tema'] = 'recursos_humanos'

# %%
munic_rec = munic_rec[['ano','id_municipio','tema','recusa','existencia_priorizacao_cargo_mulher']]
munic_rec
# Out:
#        ano  id_municipio              tema  recusa  \
# 0     2018       1100015  recursos_humanos       0
# 1     2018       1100023  recursos_humanos       0
# 2     2018       1100031  recursos_humanos       0
# 3     2018       1100049  recursos_humanos       0
# 4     2018       1100056  recursos_humanos       0
# ...    ...           ...               ...     ...
# 5565  2018       5222005  recursos_humanos       0
# 5566  2018       5222054  recursos_humanos       0
# 5567  2018       5222203  recursos_humanos       0
# 5568  2018       5222302  recursos_humanos       0
# 5569  2018       5300108  recursos_humanos       0
#
#       existencia_priorizacao_cargo_mulher
# 0                                    <NA>
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 5565                                    0
# ...

# %% [markdown]
# ### educação

# %%
path_munic = os.path.join(path, 'MUNIC_2018_Educação.csv')
munic_educ = pd.read_csv(path_munic)

# %%
def lab(munic_educ):
    if (munic_educ['MEDU491'] == 'Recusa'):
        return 1
    elif (munic_educ['MEDU491'] != 'Recusa'):
        return 0
munic_educ["recusa"] = munic_educ.apply(lambda munic_educ:lab(munic_educ),axis = 1)

# %%
munic_educ['ano'] = 2018

# %%
munic_educ = munic_educ[['ano',
                         'Cod Municipio',
                         'recusa',
                         'MEDU491',
                         'MEDU492',
                         'MEDU49211',
                         'MEDU49212',
                         'MEDU49213',
                         'MEDU49214',
                         'MEDU16',
                         'MEDU161A',
                         'MEDU161b',
                         'MEDU171',
                         'MEDU172',
                         'MEDU173',
                         'MEDU1731',
                         'MEDU1732',
                         'MEDU1733',
                         'MEDU1734',
                         'MEDU1735',
                         'MEDU174',
                         'MEDU175',
                         'MEDU176',
                         'MEDU177',
                         'MEDU21',
                         'MEDU211A',
                         'MEDU211B'
                        ]]

# %%
munic_educ.rename(columns = {'Cod Municipio' : 'id_municipio',
                         'MEDU491':'nomeacao_diretor_concurso_publico',
                         'MEDU492':'nomeacao_diretor_livre',
                         'MEDU49211':'nomeacao_diretor_livre_indicacao',
                         'MEDU49212':'nomeacao_diretor_livre_eleicao',
                         'MEDU49213':'nomeacao_diretor_livre_processo_seletivo',
                         'MEDU49214':'nomeacao_diretor_livre_outro',
                         'MEDU16':'plano_carreira_magisterio',
                         'MEDU161A':'lei_criacao_plano_carreira_magisterio',
                         'MEDU161b':'ano_criacao_plano_carreira_magisterio',
                         'MEDU171':'criterio_tempo_efetivo',
                         'MEDU172':'criterio_avaliacao_desempenho',
                         'MEDU173':'criterio_qualificacao',
                         'MEDU1731':'criterio_qualificacao_licenciatura',
                         'MEDU1732':'criterio_qualificacao_curso_aperfeicoamento',
                         'MEDU1733':'criterio_qualificacao_especializacao',
                         'MEDU1734':'criterio_qualificacao_mestrado',
                         'MEDU1735':'criterio_qualificacao_doutorado',
                         'MEDU174':'criterio_desempenho_prova_conhecimento',
                         'MEDU175':'criterio_desempenho_aluno',
                         'MEDU176':'criterio_incorporacao_permanente_remuneracao',
                         'MEDU177':'criterio_outro',
                         'MEDU21':'plano_carreira_nao_docente',
                         'MEDU211A':'lei_plano_carreira_nao_docente',
                         'MEDU211B':'ano_plano_carreira_nao_docente'
                        }, inplace = True)

# %%
munic_educ.replace('Sim',1, inplace = True)
munic_educ.replace('Não', 0 , inplace = True)
munic_educ.replace('Não informou', np.nan , inplace = True)
munic_educ.replace('Recusa', np.nan , inplace = True)
munic_educ.replace('-', np.nan , inplace = True)
munic_educ.replace('(*) Não soube informar', np.nan , inplace = True)

# %%
munic_educ['lei_criacao_plano_carreira_magisterio'] = munic_educ['lei_criacao_plano_carreira_magisterio'].astype('float').astype('Int64')
munic_educ['ano_criacao_plano_carreira_magisterio'] = munic_educ['ano_criacao_plano_carreira_magisterio'].astype('float').astype('Int64')
munic_educ['lei_plano_carreira_nao_docente'] = munic_educ['lei_plano_carreira_nao_docente'].astype('float').astype('Int64')
munic_educ['ano_plano_carreira_nao_docente'] = munic_educ['ano_plano_carreira_nao_docente'].astype('float').astype('Int64')

# %%
munic_educ = munic_educ.astype('Int64')

# %%
munic_educ['tema'] = 'educacao'

# %%
munic_educ
# Out:
#        ano  id_municipio  recusa  nomeacao_diretor_concurso_publico  \
# 0     2018       1100015       0                                  0
# 1     2018       1100023       0                                  0
# 2     2018       1100031       0                                  0
# 3     2018       1100049       0                                  0
# 4     2018       1100056       0                                  0
# ...    ...           ...     ...                                ...
# 5565  2018       5222005       0                                  0
# 5566  2018       5222054       0                                  0
# 5567  2018       5222203       0                                  0
# 5568  2018       5222302       0                                  0
# 5569  2018       5300108       0                                  0
#
#       nomeacao_diretor_livre  nomeacao_diretor_livre_indicacao  \
# 0                          1                                 1
# ...

# %% [markdown]
# ### juntando

# %%
munic_2018 = pd.concat([munic_rec, munic_educ]).reset_index(drop=True)

# %%
munic_2018
# Out:
#         ano  id_municipio              tema  recusa  \
# 0      2018       1100015  recursos_humanos       0
# 1      2018       1100023  recursos_humanos       0
# 2      2018       1100031  recursos_humanos       0
# 3      2018       1100049  recursos_humanos       0
# 4      2018       1100056  recursos_humanos       0
# ...     ...           ...               ...     ...
# 11135  2018       5222005          educacao       0
# 11136  2018       5222054          educacao       0
# 11137  2018       5222203          educacao       0
# 11138  2018       5222302          educacao       0
# 11139  2018       5300108          educacao       0
#
#        existencia_priorizacao_cargo_mulher  nomeacao_diretor_concurso_publico  \
# 0                                     <NA>                               <NA>
# 1                                        0                               <NA>
# 2                                        0                               <NA>
# ...

# %% [markdown]
# ## 2019

# %% [markdown]
# ### comunicação

# %%
path_munic = os.path.join(path, 'MUNIC_2019_comunicacao.csv')
munic_comunic = pd.read_csv(path_munic)

# %%
def lab(munic_comunic):
    if (munic_comunic['MTIC129'] == 'Recusa'):
        return 1
    elif (munic_comunic['MTIC129'] != 'Recusa'):
        return 0
munic_comunic["recusa"] = munic_comunic.apply(lambda munic_comunic:lab(munic_comunic),axis = 1)

# %%
munic_comunic["ano"]  = 2019

# %%
munic_comunic = munic_comunic[['ano',
        'CodMun',
         'recusa',                      
        'MTIC129',
        'MTIC1218',
        'MTIC128',
        'MTIC124',
        'MTIC251',
        'MTIC2511',
        'MTIC2512',
        'MTIC2513',
        'MTIC2514',
        'MTIC252',
        'MTIC2521',
        'MTIC2522',
        'MTIC2523',
        'MTIC2524',
        'MTIC253',
        'MTIC2531',
        'MTIC2532',
        'MTIC2533',
        'MTIC2534',
        'MTIC254',
        'MTIC2541',
        'MTIC2542',
        'MTIC2543',
        'MTIC2544',
        'MTIC071',
        'MTIC072',
        'MTIC073',
        'MTIC074',
        'MTIC075',
        'MTIC076',
        'MTIC077',
        'MTIC078' ]]

# %%
munic_comunic.rename(columns = {'CodMun':'id_municipio',
        'MTIC129':'pagina_internet_concurso_publico',
        'MTIC1218':'pagina_internet_pesquisa_satisfacao',
        'MTIC128':'pagina_internet_diario_ofical',
        'MTIC124':'pagina_internet_ouvidoria',
        'MTIC251':'consulta_publica',
        'MTIC2511':'consulta_publica_website_prefeitura',
        'MTIC2512':'consulta_publica_website_outro_orgao',
        'MTIC2513':'consulta_publica_rede_social',
        'MTIC2514':'consulta_publica_outro_website',
        'MTIC252': 'grupo_discussao',
        'MTIC2521':'grupo_discussao_website_prefeitura',
        'MTIC2522':'grupo_discussao_website_outro_orgao',
        'MTIC2523':'grupo_discussao_rede_social',
        'MTIC2524':'grupo_discussao_outro_website',
        'MTIC253':'enquete_online',
        'MTIC2531':'enquete_online_website_prefeitura',
        'MTIC2532':'enquete_online_website_outro_orgao',
        'MTIC2533':'enquete_online_rede_social',
        'MTIC2534':'enquete_online_outro_website',
        'MTIC254':'votacao_online',
        'MTIC2541':'votacao_online_website_prefeitura',
        'MTIC2542':'votacao_online_website_outro_orgao',
        'MTIC2543':'votacao_online_rede_social',
        'MTIC2544':'votacao_online_outro_website',
        'MTIC071':'funcionario_efetivo_ti',
        'MTIC072':'servidor_cedido_ti',
        'MTIC073':'estagiario_ti',
        'MTIC074':'comissionado_ti',
        'MTIC075':'terceirizado_ti',
        'MTIC076':'consultor_ti',
        'MTIC077':'outro_vinculo_ti',
        'MTIC078': 'nao_informado_ti'}, inplace = True)

# %%
munic_comunic
# Out:
#        ano  id_municipio  recusa pagina_internet_concurso_publico  \
# 0     2019       1100015       0                              Sim
# 1     2019       1100023       0                              Sim
# 2     2019       1100031       0                              Sim
# 3     2019       1100049       0                              Sim
# 4     2019       1100056       0                              Sim
# ...    ...           ...     ...                              ...
# 5565  2019       5222005       0                              Sim
# 5566  2019       5222054       0                              Sim
# 5567  2019       5222203       0                              Sim
# 5568  2019       5222302       0                              Sim
# 5569  2019       5300108       0                              Não
#
#      pagina_internet_pesquisa_satisfacao pagina_internet_diario_ofical  \
# 0                                    Sim                           Sim
# ...

# %%
munic_comunic.replace('Sim',1, inplace = True)
munic_comunic.replace('Não', 0 , inplace = True)
munic_comunic.replace('Não informou', np.nan , inplace = True)
munic_comunic.replace('Recusa', np.nan , inplace = True)
munic_comunic.replace('-', np.nan , inplace = True)
munic_comunic.replace('(*) Não soube informar', np.nan , inplace = True)

# %%
munic_comunic = munic_comunic.astype('Int64')

# %%
munic_comunic['tema'] = 'comunicacao_informatica'

# %%
munic_comunic = munic_comunic[['ano',
                        'id_municipio',
                        'recusa',
                        'tema',
                        "pagina_internet_concurso_publico",
                        "pagina_internet_pesquisa_satisfacao",
                        "pagina_internet_diario_ofical",
                        "pagina_internet_ouvidoria",
                        "consulta_publica",
                        "consulta_publica_website_prefeitura",
                        "consulta_publica_website_outro_orgao",
                        "consulta_publica_rede_social",
                        "consulta_publica_outro_website",
                        "grupo_discussao",
                        "grupo_discussao_website_prefeitura",
                        "grupo_discussao_website_outro_orgao",
                        "grupo_discussao_rede_social",
                        "grupo_discussao_outro_website",
                        "enquete_online",
                        "enquete_online_website_prefeitura",
                        "enquete_online_website_outro_orgao",
                        "enquete_online_rede_social",
                        "enquete_online_outro_website",
                        "votacao_online",
                        "votacao_online_website_prefeitura",
                        "votacao_online_website_outro_orgao",
                        "votacao_online_rede_social",
                        "votacao_online_outro_website",
                        "funcionario_efetivo_ti",
                        "servidor_cedido_ti",
                        "estagiario_ti",
                        "comissionado_ti",
                        "terceirizado_ti",
                        "consultor_ti",
                        "outro_vinculo_ti",
                        "nao_informado_ti"    
]]

# %%
munic_comunic
# Out:
#        ano  id_municipio  recusa                     tema  \
# 0     2019       1100015       0  comunicacao_informatica
# 1     2019       1100023       0  comunicacao_informatica
# 2     2019       1100031       0  comunicacao_informatica
# 3     2019       1100049       0  comunicacao_informatica
# 4     2019       1100056       0  comunicacao_informatica
# ...    ...           ...     ...                      ...
# 5565  2019       5222005       0  comunicacao_informatica
# 5566  2019       5222054       0  comunicacao_informatica
# 5567  2019       5222203       0  comunicacao_informatica
# 5568  2019       5222302       0  comunicacao_informatica
# 5569  2019       5300108       0  comunicacao_informatica
#
#       pagina_internet_concurso_publico  pagina_internet_pesquisa_satisfacao  \
# 0                                    1                                    1
# 1                                    1                                    0
# ...

# %% [markdown]
# ### governança

# %%
path_munic = os.path.join(path, 'MUNIC_2019_governanca.csv')
munic_gov = pd.read_csv(path_munic)

# %%
def lab(munic_gov):
    if (munic_gov['MGOV01'] == 'Recusa'):
        return 1
    elif (munic_gov['MGOV01'] != 'Recusa'):
        return 0
munic_gov["recusa"] = munic_gov.apply(lambda munic_gov:lab(munic_gov),axis = 1)

# %%
munic_gov['ano'] = 2019

# %%
munic_gov = munic_gov[['ano',
                        'CodMun',
                        'recusa',
                        'MGOV01',
                        'MGOV011A',
                        'MGOV011B',
                        'MGOV021',
                        'MGOV022',
                        'MGOV023',
                        'MGOV024',
                        'MGOV025',
                        'MGOV026',
                        'MGOV027',
                        'MGOV028',
                        'MGOV0775',
                        'MGOV0771',
                        'MGOV0772',
                        'MGOV0773',
                        'MGOV0774',
                        'MGOV081',
                        'MGOV082',
                        'MGOV083',
                        'MGOV084',
                        'MGOV085',
                        'MGOV086',
                        'MGOV087',
                        'MGOV088',
                        'MGOV089',
                        'MGOV0810',
                        'MGOV0811',
                        'MGOV26',
                        'MGOV271',
                        'MGOV272',
                        'MGOV273',
                        'MGOV274',
                        'MGOV181',
                        'MGOV182',
                        'MGOV183',
                        'MGOV184',
                        'MGOV185',
                        'MGOV186',
                        'MGOV187',
                        'MGOV188',
                        'MGOV189',
                        'MGOV1810',
                        'MGOV1811',
                        'MGOV1812',
                        'MGOV1813',
                        'MGOV1814',
                        'MGOV1815',
                        'MGOV1816',
                        'MGOV1817',
                        'MGOV1818',
                        'MGOV17',
                        'MGOV09',
                        'MGOV091',
                        'MGOV092A',
                        'MGOV092B']]

# %%
munic_gov.rename(columns = {'CodMun':'id_municipio',
'MGOV01':'legislacao_lai',
'MGOV011A':'lei_criacao_lai',
'MGOV011B':'ano_decreto_lai',
'MGOV021':'regulamentacao_lai_prazo',
'MGOV022':'regulamentacao_lai_informacao_sigilosa',
'MGOV023':'regulamentacao_lai_autoridade_monitoramento',
'MGOV024':'regulamentacao_lai_orgao_monitoramento',
'MGOV025':'regulamentacao_lai_relatorio_monitoramento',
'MGOV026':'regulamentacao_lai_instancia_recursal_interna',
'MGOV027':'regulamentacao_lai_instancia_recursal_autonoma',
'MGOV028':'regulamentacao_lai_omissao_resposta',
'MGOV0775':'dado_remuneracao_servidor',
'MGOV0771':'dado_remuneracao_servidor_csv_etc',
'MGOV0772':'dado_remuneracao_servidor_pdf_imagem',
'MGOV0773':'dado_remuneracao_servidor_outro_arquivo',
'MGOV0774':'dado_remuneracao_servidor_tempo_real',
'MGOV081':'internet_portal_transparencia_registro_competencia',
'MGOV082':'internet_portal_transparencia_estrutura_organizacional',
'MGOV083':'internet_portal_transparencia_endereco_telefone',
'MGOV084':'internet_portal_transparencia_horario_atendimento',
'MGOV085':'internet_portal_transparencia_vinculo',
'MGOV086':'internet_portal_transparencia_acompanhamento_programa',
'MGOV087':'internet_portal_transparencia_processo_licitatorio',
'MGOV088':'internet_portal_transparencia_resposta',
'MGOV089':'internet_portal_transparencia_repasse_transferencia',
'MGOV0810':'internet_portal_transparencia_nehuma_informacao',
'MGOV0811':'internet_portal_transparencia_nao_possui',
'MGOV26':'conselho_municipal_transparencia',
'MGOV271':'carater_conselho_municipal_transparencia_consultivo',
'MGOV272':'carater_conselho_municipal_transparencia_deliberativo',
'MGOV273':'carater_conselho_municipal_transparencia_normativo',
'MGOV274':'carater_conselho_municipal_transparencia_fiscalizador',
'MGOV181':'controle_interno_receita',
'MGOV182':'controle_interno_despesa',
'MGOV183':'controle_interno_administracao_pessoal',
'MGOV184':'controle_interno_estoque',
'MGOV185':'controle_interno_administracao_patrimonio',
'MGOV186':'controle_interno_ppa_programa_gov_orcamento',
'MGOV187':'controle_interno_meta_fiscal',
'MGOV188':'controle_interno_recurso_publico_direito_publico',
'MGOV189':'controle_interno_recurso_publico_direito_privado',
'MGOV1810':'controle_interno_limite_inscricao_despesa',
'MGOV1811':'controle_interno_cumprimento_legislacao',
'MGOV1812':'controle_interno_cumprimento_gasto',
'MGOV1813':'controle_interno_transferencia_legislativo_municipal',
'MGOV1814':'controle_interno_contabilidade',
'MGOV1815':'controle_interno_combate_corrupcao',
'MGOV1816':'controle_interno_transparencia',
'MGOV1817':'controle_interno_acesso_lai',
'MGOV1818':'controle_interno_nehuma_acao',
'MGOV17':'controlador_interno_carreira_especifica_auditor',
'MGOV09':'controle_interno_estrutura_organizacional',
'MGOV091':'controle_interno_instrumento_legal',
'MGOV092A':'controle_interno_numero_instrumento_legal',
'MGOV092B':'controle_interno_ano_instrumento_legal'   
}, inplace = True)

# %%
munic_gov['legislacao_lai'].unique()
#controle_interno_instrumento_legal
# Out:
# array(['Sim', 'Não', 'Recusa', 'Não informou'], dtype=object)

# %%
munic_gov.replace('Sim',1, inplace = True)
munic_gov.replace('Não', 0 , inplace = True)
munic_gov.replace('Não informou', np.nan , inplace = True)
munic_gov.replace('Recusa', np.nan , inplace = True)
munic_gov.replace('-', np.nan , inplace = True)
munic_gov.replace('(*) Não soube informar', np.nan , inplace = True)
munic_gov.replace('(*) Não soube informar ', np.nan , inplace = True)

# %%
munic_gov['controle_interno_estrutura_organizacional'].replace(0, 'Não', inplace = True)
munic_gov['controle_interno_numero_instrumento_legal'] = munic_gov['controle_interno_numero_instrumento_legal'].astype('float').astype('Int64')
munic_gov['controle_interno_ano_instrumento_legal'] = munic_gov['controle_interno_ano_instrumento_legal'].astype('float').astype('Int64')
munic_gov['lei_criacao_lai'] = munic_gov['lei_criacao_lai'].astype('float').astype('Int64')
munic_gov['ano_decreto_lai'] = munic_gov['ano_decreto_lai'].astype('float').astype('Int64')

# %%
df_remover_2 =  munic_gov[['id_municipio','controle_interno_instrumento_legal','controle_interno_estrutura_organizacional']]

# %%
df_remover =  munic_gov[['controle_interno_instrumento_legal','controle_interno_estrutura_organizacional']]

# %%
munic_novo = munic_gov.drop(df_remover, axis= 1).reset_index(drop=True)

# %%
munic_novo = munic_novo.astype('Int64')

# %%
munic_gov = pd.merge(munic_novo,df_remover_2,how = 'right', on=  'id_municipio' )

# %%
munic_gov['tema'] = 'governanca'

# %%
munic_gov = munic_gov[['ano',
                       'id_municipio',
                       'recusa',
                      'tema',
                    "legislacao_lai",
                "lei_criacao_lai",
                "ano_decreto_lai",
                "regulamentacao_lai_prazo",
                "regulamentacao_lai_informacao_sigilosa",
                "regulamentacao_lai_autoridade_monitoramento",
                "regulamentacao_lai_orgao_monitoramento",
                "regulamentacao_lai_relatorio_monitoramento",
                "regulamentacao_lai_instancia_recursal_interna",
                "regulamentacao_lai_instancia_recursal_autonoma",
                "regulamentacao_lai_omissao_resposta",
                "dado_remuneracao_servidor",
                "dado_remuneracao_servidor_csv_etc",
                "dado_remuneracao_servidor_pdf_imagem",
                "dado_remuneracao_servidor_outro_arquivo",
                "dado_remuneracao_servidor_tempo_real",
                "internet_portal_transparencia_registro_competencia",
                "internet_portal_transparencia_estrutura_organizacional",
                "internet_portal_transparencia_endereco_telefone",
                "internet_portal_transparencia_horario_atendimento",
                "internet_portal_transparencia_vinculo",
                "internet_portal_transparencia_acompanhamento_programa",
                "internet_portal_transparencia_processo_licitatorio",
                "internet_portal_transparencia_resposta",
                "internet_portal_transparencia_repasse_transferencia",
                "internet_portal_transparencia_nehuma_informacao",
                "internet_portal_transparencia_nao_possui",
                "conselho_municipal_transparencia",
                "carater_conselho_municipal_transparencia_consultivo",
                "carater_conselho_municipal_transparencia_deliberativo",
                "carater_conselho_municipal_transparencia_normativo",
                "carater_conselho_municipal_transparencia_fiscalizador",
                "controle_interno_receita",
                "controle_interno_despesa",
                "controle_interno_administracao_pessoal",
                "controle_interno_estoque",
                "controle_interno_administracao_patrimonio",
                "controle_interno_ppa_programa_gov_orcamento",
                "controle_interno_meta_fiscal",
                "controle_interno_recurso_publico_direito_publico",
                "controle_interno_recurso_publico_direito_privado",
                "controle_interno_limite_inscricao_despesa",
                "controle_interno_cumprimento_legislacao",
                "controle_interno_cumprimento_gasto",
                "controle_interno_transferencia_legislativo_municipal",
                "controle_interno_contabilidade",
                "controle_interno_combate_corrupcao",
                "controle_interno_transparencia",
                "controle_interno_acesso_lai",
                "controle_interno_nehuma_acao",
                "controlador_interno_carreira_especifica_auditor",
                "controle_interno_estrutura_organizacional",
                "controle_interno_instrumento_legal",
                "controle_interno_numero_instrumento_legal",
                "controle_interno_ano_instrumento_legal"

]]

# %% [markdown]
# ### segurança pública

# %%
path_munic = os.path.join(path, 'MUNIC_2019_seguranca.csv')
munic_seguranca = pd.read_csv(path_munic)

# %%
def lab(munic_seguranca):
    if (munic_seguranca['MSEG291'] == 'Recusa'):
        return 1
    elif (munic_seguranca['MSEG291'] != 'Recusa'):
        return 0
munic_seguranca["recusa"] = munic_seguranca.apply(lambda munic_seguranca:lab(munic_seguranca),axis = 1)

# %%
munic_seguranca['ano'] = 2019

# %%
munic_seguranca = munic_seguranca[['ano',
                                   'CodMun',
                                   'recusa',
                                   "MSEG291",
                                    "MSEG292",
                                    "MSEG293",
                                    "MSEG294",
                                    "MSEG295",
                                    "MSEG296",
                                    "MSEG34",
                                    "MSEG311",
                                    "MSEG312",
                                    "MSEG313",
                                    "MSEG314",
                                    "MSEG315",
                                    "MSEG316",
                                    "MSEG317",
                                    "MSEG318",
                                    "MSEG319",
                                    "MSEG3110",
                                    "MSEG3111",
                                    "MSEG3112",
                                    "MSEG3113",
                                    "MSEG3114",
                                    "MSEG3115",
                                    "MSEG3116",
                                    "MSEG3117",
                                    "MSEG3118",
                                    "MSEG3119",
                                    "MSEG3120",
                                    "MSEG3121",
                                    "MSEG3122",
                                    "MSEG3123",
                                    "MSEG281",
                                    "MSEG282",
                                    "MSEG283"                                  
    
]]

# %%
munic_seguranca.rename(columns = {'CodMun':'id_municipio',
                        "MSEG291":"curso_formacao_guarda_municipal",
                        "MSEG292":"curso_formacao_policia_militar",
                        "MSEG293":"curso_formacao_bombeiros",
                        "MSEG294":"curso_formacao_policia_civil",
                        "MSEG295":"curso_formacao_unidade_conveniada",
                        "MSEG296":"curso_formacao_nao_possui",
                        "MSEG34":"guarda_municipal_plano_carreira",
                        "MSEG311":"guarda_municipal_capacitacao_acao_socioeducativa",
                        "MSEG312":"guarda_municipal_capacitacao_arma_fogo",
                        "MSEG313":"guarda_municipal_capacitacao_arma_nao_letal",
                        "MSEG314":"guarda_municipal_capacitacao_atendimento_publico",
                        "MSEG315":"guarda_municipal_capacitacao_codigo_conduta",
                        "MSEG316":"guarda_municipal_capacitacao_conducao_viatura",
                        "MSEG317":"guarda_municipal_capacitacao_defesa_pessoal",
                        "MSEG318":"guarda_municipal_capacitacao_defesa_civil",
                        "MSEG319":"guarda_municipal_capacitacao_direcao_defensiva",
                        "MSEG3110":"guarda_municipal_capacitacao_educacao_ambiental",
                        "MSEG3111":"guarda_municipal_capacitacao_lgbtfobia",
                        "MSEG3112":"guarda_municipal_capacitacao_racismo",
                        "MSEG3113":"guarda_municipal_capacitacao_legislacao_transito",
                        "MSEG3114":"guarda_municipal_capacitacao_mediacao_conflito",
                        "MSEG3115":"guarda_municipal_capacitacao_policia_comunitaria",
                        "MSEG3116":"guarda_municipal_capacitacao_substancia_psicoativa",
                        "MSEG3117":"guarda_municipal_capacitacao_primeiro_socorro",
                        "MSEG3118":"guarda_municipal_capacitacao_uso_forca",
                        "MSEG3119":"guarda_municipal_capacitacao_violencia_domestica",
                        "MSEG3120":"guarda_municipal_capacitacao_violencia_escola",
                        "MSEG3121":"guarda_municipal_capacitacao_outro_tema",
                        "MSEG3122":"guarda_municipal_capacitacao_nao_ocorreu",
                        "MSEG3123":"guarda_municipal_capacitacao_nao_informado",
                        "MSEG281":"guarda_municipal_efetivo_homem",
                        "MSEG282":"guarda_municipal_efetivo_mulher",
                        "MSEG283":"guarda_municipal_efetivo_total"
                                 }, inplace =True)

# %%
munic_seguranca.replace('Sim', 1, inplace = True)
munic_seguranca.replace('Não', 0 , inplace = True)
munic_seguranca.replace('Não informou', np.nan , inplace = True)
munic_seguranca.replace('Recusa', np.nan , inplace = True)
munic_seguranca.replace('-', np.nan , inplace = True)
munic_seguranca.replace('Não soube informar', np.nan , inplace = True)

# %%
munic_seguranca["guarda_municipal_efetivo_homem"]  = munic_seguranca["guarda_municipal_efetivo_homem"].astype('float').astype('Int64')
munic_seguranca["guarda_municipal_efetivo_mulher"] = munic_seguranca["guarda_municipal_efetivo_mulher"].astype('float').astype('Int64')
munic_seguranca["guarda_municipal_efetivo_total"] = munic_seguranca["guarda_municipal_efetivo_total"].astype('float').astype('Int64')

# %%
munic_seguranca = munic_seguranca.astype('Int64')

# %%
munic_seguranca['tema'] = 'seguranca_publica'

# %%
munic_seguranca = munic_seguranca[[
                        'ano',
                        'id_municipio',
                        'recusa',
                        'tema',   
                        "curso_formacao_guarda_municipal",
                        "curso_formacao_policia_militar",
                        "curso_formacao_bombeiros",
                        "curso_formacao_policia_civil",
                        "curso_formacao_unidade_conveniada",
                        "curso_formacao_nao_possui",
                        "guarda_municipal_plano_carreira",
                        "guarda_municipal_capacitacao_acao_socioeducativa",
                        "guarda_municipal_capacitacao_arma_fogo",
                        "guarda_municipal_capacitacao_arma_nao_letal",
                        "guarda_municipal_capacitacao_atendimento_publico",
                        "guarda_municipal_capacitacao_codigo_conduta",
                        "guarda_municipal_capacitacao_conducao_viatura",
                        "guarda_municipal_capacitacao_defesa_pessoal",
                        "guarda_municipal_capacitacao_defesa_civil",
                        "guarda_municipal_capacitacao_direcao_defensiva",
                        "guarda_municipal_capacitacao_educacao_ambiental",
                        "guarda_municipal_capacitacao_lgbtfobia",
                        "guarda_municipal_capacitacao_racismo",
                        "guarda_municipal_capacitacao_legislacao_transito",
                        "guarda_municipal_capacitacao_mediacao_conflito",
                        "guarda_municipal_capacitacao_policia_comunitaria",
                        "guarda_municipal_capacitacao_substancia_psicoativa",
                        "guarda_municipal_capacitacao_primeiro_socorro",
                        "guarda_municipal_capacitacao_uso_forca",
                        "guarda_municipal_capacitacao_violencia_domestica",
                        "guarda_municipal_capacitacao_violencia_escola",
                        "guarda_municipal_capacitacao_outro_tema",
                        "guarda_municipal_capacitacao_nao_ocorreu",
                        "guarda_municipal_capacitacao_nao_informado",
                        "guarda_municipal_efetivo_homem",
                        "guarda_municipal_efetivo_mulher",
                        "guarda_municipal_efetivo_total"]]

# %%
munic_seguranca
# Out:
#        ano  id_municipio  recusa               tema  \
# 0     2019       1100015       0  seguranca_publica
# 1     2019       1100023       0  seguranca_publica
# 2     2019       1100031       0  seguranca_publica
# 3     2019       1100049       0  seguranca_publica
# 4     2019       1100056       0  seguranca_publica
# ...    ...           ...     ...                ...
# 5565  2019       5222005       0  seguranca_publica
# 5566  2019       5222054       0  seguranca_publica
# 5567  2019       5222203       0  seguranca_publica
# 5568  2019       5222302       0  seguranca_publica
# 5569  2019       5300108       0  seguranca_publica
#
#       curso_formacao_guarda_municipal  curso_formacao_policia_militar  \
# 0                                <NA>                            <NA>
# 1                                   1                               0
# 2                                <NA>                            <NA>
# ...

# %% [markdown]
# ### juntando 2019

# %%
munic_2019 = pd.concat([munic_comunic, munic_gov,munic_seguranca]).reset_index(drop=True)

# %%
munic_2019
# Out:
#         ano  id_municipio  recusa                     tema  \
# 0      2019       1100015       0  comunicacao_informatica
# 1      2019       1100023       0  comunicacao_informatica
# 2      2019       1100031       0  comunicacao_informatica
# 3      2019       1100049       0  comunicacao_informatica
# 4      2019       1100056       0  comunicacao_informatica
# ...     ...           ...     ...                      ...
# 16705  2019       5222005       0        seguranca_publica
# 16706  2019       5222054       0        seguranca_publica
# 16707  2019       5222203       0        seguranca_publica
# 16708  2019       5222302       0        seguranca_publica
# 16709  2019       5300108       0        seguranca_publica
#
#        pagina_internet_concurso_publico  pagina_internet_pesquisa_satisfacao  \
# 0                                     1                                    1
# 1                                     1                                    0
# ...

# %% [markdown]
# ## 2018/2019

# %%
munic_geral = pd.concat([munic_2018 ,munic_2019]).reset_index(drop = True)

# %%
munic_geral.columns.values
# Out:
# array(['ano', 'id_municipio', 'tema', 'recusa',
#        'existencia_priorizacao_cargo_mulher',
#        'nomeacao_diretor_concurso_publico', 'nomeacao_diretor_livre',
#        'nomeacao_diretor_livre_indicacao',
#        'nomeacao_diretor_livre_eleicao',
#        'nomeacao_diretor_livre_processo_seletivo',
#        'nomeacao_diretor_livre_outro', 'plano_carreira_magisterio',
#        'lei_criacao_plano_carreira_magisterio',
#        'ano_criacao_plano_carreira_magisterio', 'criterio_tempo_efetivo',
#        'criterio_avaliacao_desempenho', 'criterio_qualificacao',
#        'criterio_qualificacao_licenciatura',
#        'criterio_qualificacao_curso_aperfeicoamento',
#        'criterio_qualificacao_especializacao',
#        'criterio_qualificacao_mestrado',
#        'criterio_qualificacao_doutorado',
#        'criterio_desempenho_prova_conhecimento',
#        'criterio_desempenho_aluno',
#        'criterio_incorporacao_permanente_remuneracao', 'criterio_outro',
# ...

# %%
munic_geral
# Out:
#         ano  id_municipio               tema  recusa  \
# 0      2018       1100015   recursos_humanos       0
# 1      2018       1100023   recursos_humanos       0
# 2      2018       1100031   recursos_humanos       0
# 3      2018       1100049   recursos_humanos       0
# 4      2018       1100056   recursos_humanos       0
# ...     ...           ...                ...     ...
# 27845  2019       5222005  seguranca_publica       0
# 27846  2019       5222054  seguranca_publica       0
# 27847  2019       5222203  seguranca_publica       0
# 27848  2019       5222302  seguranca_publica       0
# 27849  2019       5300108  seguranca_publica       0
#
#        existencia_priorizacao_cargo_mulher  nomeacao_diretor_concurso_publico  \
# 0                                     <NA>                               <NA>
# 1                                        0                               <NA>
# 2                                        0                               <NA>
# ...

# %%
output = os.path.abspath(os.path.join('..', 'output'))

# %%
for ano in [*range(2018, 2020)]:
    particao = output + f'\\indicadores_gerais\\ano={ano}\\'
    if not os.path.exists(particao):
      os.makedirs(particao)

# %%
for ano in [*range(2018, 2020)]:
    df_particao = munic_geral[munic_geral['ano'] == ano].copy() # O .copy não é necessário é apenas uma boa prática
    df_particao.drop(['ano'], axis=1, inplace=True) # É preciso excluir as colunas utilizadas para partição 
    particao = output + f'\\indicadores_gerais\\ano={ano}\\indicadores_gerais.csv'
    df_particao.to_csv(particao, index=False, encoding='utf-8', na_rep='')
