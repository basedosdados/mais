# %%
#https://drive.google.com/drive/folders/1RaTqeT0vWMfVVgjLRpSxCNO2zAgjwoNl?usp=sharing
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np
import os
import glob

# %%
file = []
for filepath in glob.iglob(r'/content/gdrive/MyDrive/br_ms_sinasc/input/*.csv'):
    file.append(filepath)

ano=[]
for i in range(len(file)) : ano.append(int(file[i][-8:-4]))

dict_ano = dict(zip(ano, file))
dict_ano
# Out:
# {1994: '/content/gdrive/MyDrive/br_ms_sinasc/input/sinasc_1994.csv',
#  1995: '/content/gdrive/MyDrive/br_ms_sinasc/input/sinasc_1995.csv',
#  1996: '/content/gdrive/MyDrive/br_ms_sinasc/input/sinasc_1996.csv',
#  1997: '/content/gdrive/MyDrive/br_ms_sinasc/input/sinasc_1997.csv',
#  1998: '/content/gdrive/MyDrive/br_ms_sinasc/input/sinasc_1998.csv',
#  1999: '/content/gdrive/MyDrive/br_ms_sinasc/input/sinasc_1999.csv',
#  2000: '/content/gdrive/MyDrive/br_ms_sinasc/input/sinasc_2000.csv',
#  2001: '/content/gdrive/MyDrive/br_ms_sinasc/input/sinasc_2001.csv',
#  2002: '/content/gdrive/MyDrive/br_ms_sinasc/input/sinasc_2002.csv',
#  2003: '/content/gdrive/MyDrive/br_ms_sinasc/input/sinasc_2003.csv',
#  2004: '/content/gdrive/MyDrive/br_ms_sinasc/input/sinasc_2004.csv',
#  2005: '/content/gdrive/MyDrive/br_ms_sinasc/input/sinasc_2005.csv',
#  2006: '/content/gdrive/MyDrive/br_ms_sinasc/input/sinasc_2006.csv',
#  2007: '/content/gdrive/MyDrive/br_ms_sinasc/input/sinasc_2007.csv',
# ...

# %%
id_mun = pd.read_csv('/content/gdrive/MyDrive/br_ms_sinasc/id_mun.csv',dtype='string')

# %%
ufs = ['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG', 'MS', 'MT', 
       'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR', 'RS', 'SC', 'SE', 'SP', 'TO']

# %%
ordem = ['sigla_uf', 'sequencial_nascimento','id_municipio_nascimento', 'local_nascimento', 'codigo_estabelecimento', 'data_nascimento',
           'hora_nascimento', 'sexo', 'peso', 'raca_cor', 'apgar1', 'apgar5', 'id_anomalia', 'codigo_anomalia', 'semana_gestacao',
           'semana_gestacao_estimada', 'gestacao_agr', 'tipo_gravidez', 'tipo_parto', 'inicio_pre_natal', 'pre_natal', 'pre_natal_agr',
           'classificacao_pre_natal', 'quantidade_filhos_vivos', 'quantidade_filhos_mortos', 'id_pais_mae', 'id_uf_mae',  'id_municipio_mae',
           'id_pais_residencia', 'id_municipio_residencia', 'data_nascimento_mae', 'idade_mae', 'escolaridade_mae',  'serie_escolar_mae',  
           'escolaridade_2010_mae', 'escolaridade_2010_agr_mae', 'estado_civil_mae', 'ocupacao_mae', 'raca_cor_mae', 'gestacoes_ant', 'quantidade_parto_normal',
           'quantidade_parto_cesareo', 'data_ultima_menstruacao', 'tipo_apresentacao', 'inducao_parto', 'cesarea_antes_parto', 'tipo_robson',
           'idade_pai', 'cartorio', 'registro_cartorio', 'data_registro_cartorio', 'origem', 'numero_lote', 'versao_sistema', 'data_cadastro',
           'data_recebimento', 'data_recebimento_original', 'diferenca_data', 'data_declaracao', 'funcao_responsavel', 'documento_responsavel', 
           'formacao_profissional_responsavel', 'status_dn', 'status_dn_nova', 'paridade']

# %%
rename_94_95 = {'contador': 'sequencial_nascimento','CARTORIO':'cartorio', 'DATA_CART':'data_registro_cartorio', 'LOCAL_OCOR':'local_nascimento',
          'MUNI_OCOR':'id_municipio_nascimento', 'ESTAB_OCOR':'codigo_estabelecimento', 'DATA_NASC':'data_nascimento', 'SEXO':'sexo', 'PESO':'peso',
          'RACCOR':'raca_cor', 'APGAR1':'apgar1', 'APGAR5':'apgar5', 'GESTACAO':'gestacao_agr', 'TIPO_GRAV':'tipo_gravidez', 'TIPO_PARTO': 'tipo_parto',
          'PRE_NATAL': 'pre_natal_agr', 'IDADE_MAE':'idade_mae', 'INSTR_MAE':'escolaridade_mae', 'MUNI_MAE':'id_municipio_residencia', 'FIL_VIVOS':'quantidade_filhos_vivos',
          'FIL_MORTOS':'quantidade_filhos_mortos', 'FIL_ABORT':'quantidade_filhos_abortados', 'UFINFORM':'id_uf'}

# %%
add_94_95 = pd.DataFrame(columns=['hora_nascimento', 'id_anomalia', 'codigo_anomalia', 'semana_gestacao', 'semana_gestacao_estimada',
                                 'inicio_pre_natal', 'pre_natal', 'classificacao_pre_natal', 'id_pais_mae', 'id_uf_mae',  'id_municipio_mae',
                                 'id_pais_residencia', 'data_nascimento_mae', 'serie_escolar_mae', 'escolaridade_2010_mae', 'escolaridade_2010_agr_mae', 
                                 'estado_civil_mae', 'ocupacao_mae', 'raca_cor_mae', 'gestacoes_ant', 'quantidade_parto_normal', 'quantidade_parto_cesareo', 
                                 'data_ultima_menstruacao', 'tipo_apresentacao', 'inducao_parto', 'cesarea_antes_parto', 'tipo_robson', 'idade_pai', 
                                 'registro_cartorio', 'origem', 'numero_lote', 'versao_sistema', 'data_cadastro', 'data_recebimento', 'data_recebimento_original', 
                                 'diferenca_data', 'data_declaracao', 'funcao_responsavel', 'documento_responsavel', 'formacao_profissional_responsavel', 'status_dn', 
                                  'status_dn_nova', 'paridade'])

# %%
rename_96_19 = {'contador':'sequencial_nascimento', 'CONTADOR':'sequencial_nascimento','CODMUNNASC':'id_municipio_nascimento', 'LOCNASC':'local_nascimento', 'CODESTAB':'codigo_estabelecimento', 
           'DTNASC':'data_nascimento', 'HORANASC':'hora_nascimento', 'SEXO':'sexo', 'PESO':'peso', 'RACACOR':'raca_cor', 'APGAR1':'apgar1', 'APGAR5':'apgar5', 
           'IDANOMAL':'id_anomalia', 'CODANOMAL':'codigo_anomalia', 'SEMAGESTAC':'semana_gestacao', 'TPMETESTIM': 'semana_gestacao_estimada', 'GESTACAO':'gestacao_agr', 
           'GRAVIDEZ':'tipo_gravidez', 'PARTO':'tipo_parto', 'MESPRENAT':'inicio_pre_natal', 'CONSPRENAT':'pre_natal', 'CONSULTAS':'pre_natal_agr', 
           'KOTELCHUCK':'classificacao_pre_natal', 'QTDFILVIVO':'quantidade_filhos_vivos', 'QTDFILMORT':'quantidade_filhos_mortos', 'NATURALMAE':'id_pais_mae',
           'CODUFNATU':'id_uf_mae', 'CODMUNNATU':'id_municipio_mae', 'CODPAISRES':'id_pais_residencia', 'CODMUNRES':'id_municipio_residencia',
           'DTNASCMAE':'data_nascimento_mae', 'IDADEMAE':'idade_mae', 'ESCMAE':'escolaridade_mae', 'SERIESCMAE':'serie_escolar_mae','ESCMAE2010':'escolaridade_2010_mae',
           'ESCMAEAGR1':'escolaridade_2010_agr_mae', 'ESTCIVMAE':'estado_civil_mae','CODOCUPMAE':'ocupacao_mae', 'RACACORMAE':'raca_cor_mae', 'QTDGESTANT':'gestacoes_ant',
           'QTDPARTNOR':'quantidade_parto_normal', 'QTDPARTCES':'quantidade_parto_cesareo', 'DTULTMENST':'data_ultima_menstruacao', 'TPAPRESENT':'tipo_apresentacao', 
           'NUMREGCART':'registro_cartorio', 'CODCART':'cartorio','DTREGCART':'data_registro_cartorio', 'STTRABPART':'inducao_parto', 'STCESPARTO':'cesarea_antes_parto', 
           'TPROBSON':'tipo_robson', 'IDADEPAI':'idade_pai', 'ORIGEM':'origem', 'NUMEROLOTE':'numero_lote', 'VERSAOSIST':'versao_sistema', 'DTCADASTRO':'data_cadastro', 
           'DTRECEBIM':'data_recebimento', 'DTRECORIGA': 'data_recebimento_original', 'DTRECORIG': 'data_recebimento_original', 'DIFDATA':'diferenca_data', 
           'DTDECLARAC':'data_declaracao', 'TPFUNCRESP':'funcao_responsavel', 'TPDOCRESP':'documento_responsavel', 'TPNASCASSI':'formacao_profissional_responsavel', 
           'STDNEPIDEM':'status_dn', 'STDNNOVA':'status_dn_nova', 'PARIDADE':'paridade'}

# %%
add_96_99 = pd.DataFrame(columns=['codigo_estabelecimento', 'hora_nascimento', 'semana_gestacao', 'semana_gestacao_estimada', 'inicio_pre_natal', 'pre_natal',
                                  'classificacao_pre_natal', 'id_pais_mae', 'id_uf_mae', 'id_municipio_mae', 'id_pais_residencia', 'data_nascimento_mae', 
                                  'serie_escolar_mae', 'escolaridade_2010_mae', 'escolaridade_2010_agr_mae', 'raca_cor_mae', 'gestacoes_ant', 'quantidade_parto_normal',
                                  'quantidade_parto_cesareo', 'data_ultima_menstruacao', 'tipo_apresentacao', 'inducao_parto', 'cesarea_antes_parto', 'tipo_robson', 
                                  'idade_pai', 'cartorio', 'registro_cartorio', 'data_registro_cartorio', 'origem', 'numero_lote', 'versao_sistema', 'data_cadastro', 
                                  'data_recebimento', 'data_recebimento_original', 'diferenca_data', 'data_declaracao', 'funcao_responsavel', 'documento_responsavel', 
                                  'formacao_profissional_responsavel', 'status_dn', 'status_dn_nova', 'paridade'])

# %%
add_00_05 = pd.DataFrame(columns=['hora_nascimento', 'semana_gestacao', 'semana_gestacao_estimada',
                                  'inicio_pre_natal', 'pre_natal', 'classificacao_pre_natal', 'id_pais_mae',
                                  'id_uf_mae', 'id_municipio_mae', 'id_pais_residencia',
                                  'data_nascimento_mae', 'serie_escolar_mae', 'escolaridade_2010_mae',
                                  'escolaridade_2010_agr_mae', 'raca_cor_mae', 'gestacoes_ant',
                                  'quantidade_parto_normal', 'quantidade_parto_cesareo',
                                  'data_ultima_menstruacao', 'tipo_apresentacao', 'inducao_parto',
                                  'cesarea_antes_parto', 'tipo_robson', 'idade_pai', 'cartorio',
                                  'registro_cartorio', 'data_registro_cartorio', 'origem', 'numero_lote',
                                  'versao_sistema', 'data_cadastro', 'data_recebimento',
                                  'data_recebimento_original', 'diferenca_data', 'data_declaracao',
                                  'funcao_responsavel','documento_responsavel', 'status_dn', 'status_dn_nova',
                                  'paridade', 'formacao_profissional_responsavel'])

# %%
add_06_09 = pd.DataFrame(columns=['semana_gestacao', 'semana_gestacao_estimada', 
                                  'inicio_pre_natal', 'pre_natal', 'classificacao_pre_natal', 
                                  'id_pais_mae', 'id_uf_mae', 'id_municipio_mae',
                                  'id_pais_residencia', 'data_nascimento_mae', 'serie_escolar_mae',
                                  'escolaridade_2010_mae', 'escolaridade_2010_agr_mae', 'raca_cor_mae',
                                  'gestacoes_ant', 'quantidade_parto_normal', 'quantidade_parto_cesareo',
                                  'data_ultima_menstruacao', 'tipo_apresentacao', 'inducao_parto',
                                  'cesarea_antes_parto', 'tipo_robson', 'idade_pai', 'cartorio',
                                  'registro_cartorio', 'data_registro_cartorio', 'origem', 'numero_lote',
                                  'versao_sistema', 'data_recebimento_original', 'diferenca_data',
                                  'data_declaracao', 'funcao_responsavel', 'documento_responsavel', 'status_dn',                                 
                                  'status_dn_nova', 'paridade', 'formacao_profissional_responsavel'])

# %%
add_10 = pd.DataFrame(columns=['classificacao_pre_natal', 'id_uf_mae', 'escolaridade_2010_mae',
                               'escolaridade_2010_agr_mae', 'numero_lote', 'data_declaracao',
                               'funcao_responsavel', 'documento_responsavel', 'formacao_profissional_responsavel',
                               'paridade'])

# %%
add_11 = pd.DataFrame(columns=[ 'classificacao_pre_natal', 'id_uf_mae', 'escolaridade_2010_mae', 
                               'escolaridade_2010_agr_mae', 'data_declaracao', 'funcao_responsavel', 
                               'documento_responsavel', 'formacao_profissional_responsavel', 'paridade'])

# %%
add_12 = pd.DataFrame(columns=[ 'classificacao_pre_natal', 'id_uf_mae', 'escolaridade_2010_agr_mae',
                               'data_recebimento_original', 'data_declaracao', 'funcao_responsavel',
                               'documento_responsavel', 'formacao_profissional_responsavel', 'paridade'])

# %%
add_13 = pd.DataFrame(columns=[ 'pre_natal', 'classificacao_pre_natal', 'tipo_robson', 'data_declaracao',
                               'funcao_responsavel', 'documento_responsavel', 'paridade'])

# %%
add_14_19 = pd.DataFrame(columns=['cartorio', 'registro_cartorio' ,'data_registro_cartorio'])

# %% [markdown]
# #### Código Tratamento

# %%
for i in ano:
    if  i <= 1995:
        exec('{} = pd.DataFrame()'.format('sinasc_' + str(i)))
        ch=0
        for chunk in pd.read_csv(dict_ano[i],sep=',',chunksize = 100000, dtype='string'):
            ch = ch + 1
            print("fazendo chunck {} de {} ".format(ch,i))
            chunk.rename(columns=rename_94_95, inplace=True)
            chunk = pd.concat([chunk,add_94_95])
            chunk['quantidade_filhos_abortados'] = pd.to_numeric(chunk['quantidade_filhos_abortados'], downcast='integer', errors='coerce')
            chunk['quantidade_filhos_mortos'] = pd.to_numeric(chunk['quantidade_filhos_mortos'], downcast='integer', errors='coerce')
            chunk['quantidade_filhos_abortados'] = chunk['quantidade_filhos_abortados'] .replace([99],0)
            chunk['quantidade_filhos_mortos'] = chunk['quantidade_filhos_mortos'] .replace([99],0)
            chunk['total_natimorto'] = chunk['quantidade_filhos_abortados'] + chunk['quantidade_filhos_mortos']
            chunk['total_natimorto']= chunk['total_natimorto'].fillna(0)
            chunk['total_natimorto'] =  chunk['total_natimorto'].round(decimals=0).astype('int64')
            chunk.drop(['quantidade_filhos_mortos', 'quantidade_filhos_abortados'], axis=1, inplace=True)
            chunk.rename(columns={'total_natimorto':'quantidade_filhos_mortos'}, inplace=True)
            chunk['data_nascimento'] = pd.to_datetime(chunk['data_nascimento'], format ='%Y%m%d',errors='coerce').dt.date
            chunk['data_registro_cartorio'] = pd.to_datetime(chunk['data_registro_cartorio'], format ='%Y%m%d',errors='coerce').dt.date
            chunk['data_cadastro'] = pd.to_datetime(chunk['data_cadastro'], format ='%Y%m%d',errors='coerce').dt.date
            chunk = pd.merge(chunk, id_mun, how='left', left_on=['id_municipio_nascimento'], right_on=['id_municipio'])
            chunk.sort_values(['sequencial_nascimento', 'id_municipio_nascimento', 'data_nascimento'], inplace=True)
            chunk.drop_duplicates(subset=['sequencial_nascimento', 'id_municipio_nascimento', 'data_nascimento'], keep='first', inplace=True)
            chunk = chunk[ordem]
            exec('{} = {}.append(chunk)'.format('sinasc_' + str(i), 'sinasc_' + str(i)))
        exec('{}.to_csv("/content/gdrive/MyDrive/br_ms_sinasc/temp/{}.csv",index=False, encoding="utf-8", na_rep="", date_format="%Y-%m-%d")'.format('sinasc_' + str(i), 'sinasc_' + str(i)))
        exec('del {}'.format('sinasc_' + str(i)))
# Out:
# fazendo chunck 1 de 1994
# fazendo chunck 2 de 1994
# fazendo chunck 3 de 1994
# fazendo chunck 4 de 1994
# fazendo chunck 5 de 1994
# fazendo chunck 6 de 1994
# fazendo chunck 7 de 1994
# fazendo chunck 8 de 1994
# fazendo chunck 9 de 1994
# fazendo chunck 10 de 1994
# fazendo chunck 11 de 1994
# fazendo chunck 12 de 1994
# fazendo chunck 13 de 1994
# fazendo chunck 14 de 1994
# fazendo chunck 15 de 1994
# fazendo chunck 16 de 1994
# fazendo chunck 17 de 1994
# fazendo chunck 18 de 1994
# fazendo chunck 19 de 1994
# fazendo chunck 20 de 1994
# fazendo chunck 21 de 1994
# fazendo chunck 22 de 1994
# fazendo chunck 23 de 1994
# fazendo chunck 24 de 1994
# fazendo chunck 25 de 1994
# fazendo chunck 26 de 1994
# fazendo chunck 27 de 1994
# fazendo chunck 28 de 1994
# fazendo chunck 29 de 1994
# fazendo chunck 1 de 1995
# fazendo chunck 2 de 1995
# fazendo chunck 3 de 1995
# fazendo chunck 4 de 1995
# fazendo chunck 5 de 1995
# fazendo chunck 6 de 1995
# fazendo chunck 7 de 1995
# ...

# %%
for i in ano:
    if   1996 <= i <= 1999:
        exec('{} = pd.DataFrame()'.format('sinasc_' + str(i)))
        ch=0
        for chunk in pd.read_csv(dict_ano[i],sep=',',chunksize = 500000, dtype='string', encoding='latin-1'):
            ch = ch + 1
            print("fazendo chunck {} de {} ".format(ch,i))
            if i == 1996 or i == 1998:
                add_96_98 = pd.DataFrame(columns=['hora_nascimento','id_anomalia'])
                chunk = pd.concat([chunk,add_96_98])
            chunk.rename(columns=rename_96_19, inplace=True)
            chunk = pd.concat([chunk,add_96_99])
            chunk['data_nascimento'] = pd.to_datetime(chunk['data_nascimento'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_registro_cartorio'] = pd.to_datetime(chunk['data_registro_cartorio'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_cadastro'] = pd.to_datetime(chunk['data_cadastro'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_recebimento'] = pd.to_datetime(chunk['data_recebimento'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_recebimento_original'] = pd.to_datetime(chunk['data_recebimento_original'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_nascimento_mae'] = pd.to_datetime(chunk['data_nascimento_mae'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_ultima_menstruacao'] = pd.to_datetime(chunk['data_ultima_menstruacao'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_declaracao'] = pd.to_datetime(chunk['data_declaracao'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_nascimento_mae'] = pd.to_datetime(chunk['data_nascimento_mae'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['hora_nascimento'] = pd.to_datetime(chunk['hora_nascimento'],format='%H%M',errors='coerce').dt.time
            chunk = pd.merge(chunk, id_mun, how='left', left_on=['id_municipio_nascimento'], right_on=['id_municipio'])
            chunk = chunk[ordem]
            exec('{} = {}.append(chunk)'.format('sinasc_' + str(i), 'sinasc_' + str(i)))
        exec('{}.to_csv("/content/gdrive/MyDrive/br_ms_sinasc/temp/{}.csv",index=False, encoding="utf-8", na_rep="", date_format="%Y-%m-%d")'.format('sinasc_' + str(i), 'sinasc_' + str(i)))
        exec('del {}'.format('sinasc_' + str(i)))
# Out:
# fazendo chunck 1 de 1996
# fazendo chunck 2 de 1996
# fazendo chunck 3 de 1996
# fazendo chunck 4 de 1996
# fazendo chunck 5 de 1996
# fazendo chunck 6 de 1996
# fazendo chunck 1 de 1997
# fazendo chunck 2 de 1997
# fazendo chunck 3 de 1997
# fazendo chunck 4 de 1997
# fazendo chunck 5 de 1997
# fazendo chunck 6 de 1997
# fazendo chunck 7 de 1997
# fazendo chunck 1 de 1998
# fazendo chunck 2 de 1998
# fazendo chunck 3 de 1998
# fazendo chunck 4 de 1998
# fazendo chunck 5 de 1998
# fazendo chunck 6 de 1998
# fazendo chunck 7 de 1998
# fazendo chunck 1 de 1999
# fazendo chunck 2 de 1999
# fazendo chunck 3 de 1999
# fazendo chunck 4 de 1999
# fazendo chunck 5 de 1999
# fazendo chunck 6 de 1999
# fazendo chunck 7 de 1999

# %%
for i in ano:
    if 2000 <= i <= 2005:
        exec('{} = pd.DataFrame()'.format('sinasc_' + str(i)))
        ch=0
        for chunk in pd.read_csv(dict_ano[i],sep=',',chunksize = 300000, dtype='string', encoding='latin-1'):
            ch = ch + 1
            print("fazendo chunck {} de {} ".format(ch,i))
            chunk = pd.concat([chunk,add_00_05])
            chunk.rename(columns=rename_96_19, inplace=True)
            chunk['data_nascimento'] = pd.to_datetime(chunk['data_nascimento'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_registro_cartorio'] = pd.to_datetime(chunk['data_registro_cartorio'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_cadastro'] = pd.to_datetime(chunk['data_cadastro'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_recebimento'] = pd.to_datetime(chunk['data_recebimento'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_recebimento_original'] = pd.to_datetime(chunk['data_recebimento_original'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_nascimento_mae'] = pd.to_datetime(chunk['data_nascimento_mae'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_ultima_menstruacao'] = pd.to_datetime(chunk['data_ultima_menstruacao'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_declaracao'] = pd.to_datetime(chunk['data_declaracao'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_nascimento_mae'] = pd.to_datetime(chunk['data_nascimento_mae'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['hora_nascimento'] = pd.to_datetime(chunk['hora_nascimento'],format='%H%M',errors='coerce').dt.time
            chunk = pd.merge(chunk, id_mun, how='left', left_on=['id_municipio_nascimento'], right_on=['id_municipio'])
            chunk = chunk[ordem]
            exec('{} = {}.append(chunk)'.format('sinasc_' + str(i), 'sinasc_' + str(i)))
        exec('{}.to_csv("/content/gdrive/MyDrive/br_ms_sinasc/temp/{}.csv",index=False, encoding="utf-8", na_rep="", date_format="%Y-%m-%d")'.format('sinasc_' + str(i), 'sinasc_' + str(i)))
        exec('del {}'.format('sinasc_' + str(i)))
# Out:
# fazendo chunck 1 de 2005
# fazendo chunck 2 de 2005
# fazendo chunck 3 de 2005
# fazendo chunck 4 de 2005
# fazendo chunck 5 de 2005
# fazendo chunck 6 de 2005
# fazendo chunck 7 de 2005
# fazendo chunck 8 de 2005
# fazendo chunck 9 de 2005
# fazendo chunck 10 de 2005
# fazendo chunck 11 de 2005
# fazendo chunck 1 de 2000
# fazendo chunck 2 de 2000
# fazendo chunck 3 de 2000
# fazendo chunck 4 de 2000
# fazendo chunck 5 de 2000
# fazendo chunck 6 de 2000
# fazendo chunck 7 de 2000
# fazendo chunck 8 de 2000
# fazendo chunck 9 de 2000
# fazendo chunck 10 de 2000
# fazendo chunck 11 de 2000
# fazendo chunck 1 de 2001
# fazendo chunck 2 de 2001
# fazendo chunck 3 de 2001
# fazendo chunck 4 de 2001
# fazendo chunck 5 de 2001
# fazendo chunck 6 de 2001
# fazendo chunck 7 de 2001
# fazendo chunck 8 de 2001
# fazendo chunck 9 de 2001
# fazendo chunck 10 de 2001
# fazendo chunck 11 de 2001
# fazendo chunck 1 de 2002
# fazendo chunck 2 de 2002
# fazendo chunck 3 de 2002
# ...

# %%
for i in ano:
    if i >= 2006:
        exec('{} = pd.DataFrame()'.format('sinasc_' + str(i)))
        ch=0
        for chunk in pd.read_csv(dict_ano[i],sep=',',chunksize = 300000, dtype='string', encoding='latin-1'):
            ch = ch + 1
            print("fazendo chunck {} de {} ".format(ch,i))
            if 2006 <= i <= 2009:
                chunk = pd.concat([chunk,add_06_09])
            elif i == 2010:
                chunk = pd.concat([chunk,add_10])
            elif i == 2011:
                chunk = pd.concat([chunk,add_11])
            elif i == 2012:
                chunk = pd.concat([chunk,add_12]) 
            elif i == 2013:
                chunk = pd.concat([chunk,add_13])
            elif 2014 <= i <= 2019:
                chunk = pd.concat([chunk,add_14_19])
            chunk.rename(columns=rename_96_19, inplace=True)
            chunk['data_nascimento'] = pd.to_datetime(chunk['data_nascimento'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_registro_cartorio'] = pd.to_datetime(chunk['data_registro_cartorio'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_cadastro'] = pd.to_datetime(chunk['data_cadastro'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_recebimento'] = pd.to_datetime(chunk['data_recebimento'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_recebimento_original'] = pd.to_datetime(chunk['data_recebimento_original'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_nascimento_mae'] = pd.to_datetime(chunk['data_nascimento_mae'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_ultima_menstruacao'] = pd.to_datetime(chunk['data_ultima_menstruacao'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_declaracao'] = pd.to_datetime(chunk['data_declaracao'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['data_nascimento_mae'] = pd.to_datetime(chunk['data_nascimento_mae'], format ='%d%m%Y',errors='coerce').dt.date
            chunk['hora_nascimento'] = pd.to_datetime(chunk['hora_nascimento'],format='%H%M',errors='coerce').dt.time
            try:
                chunk = chunk.sort_values(by=['id_municipio_nascimento'])
                if len(chunk.iloc[0]['id_municipio_nascimento'])==6:
                    chunk = pd.merge(chunk, id_mun, how='left', left_on='id_municipio_nascimento', right_on= 'id_municipio_6', validate='many_to_one')
                    chunk.drop(columns=['id_municipio_nascimento', 'id_municipio_6', 'sigla_uf'], inplace=True)
                    chunk.rename(columns={'id_municipio':'id_municipio_nascimento'}, inplace=True)
                else:
                    pass
            except:pass
            try:
                chunk = chunk.sort_values(by=['id_municipio_mae'])
                if len(chunk.iloc[0]['id_municipio_mae'])==6:
                    chunk = pd.merge(chunk, id_mun, how='left', left_on='id_municipio_mae', right_on= 'id_municipio_6', validate='many_to_one')
                    chunk.drop(columns=['id_municipio_mae', 'id_municipio_6', 'sigla_uf'], inplace=True)
                    chunk.rename(columns={'id_municipio':'id_municipio_mae'}, inplace=True)
                else:
                    pass
            except:pass
            try:
                chunk = chunk.sort_values(by=['id_municipio_residencia'])
                if len(chunk.iloc[0]['id_municipio_residencia'])==6:
                    chunk = pd.merge(chunk, id_mun, how='left', left_on='id_municipio_residencia', right_on= 'id_municipio_6', validate='many_to_one')
                    chunk.drop(columns=['id_municipio_residencia', 'id_municipio_6'], inplace=True)
                    chunk.rename(columns={'id_municipio':'id_municipio_residencia'}, inplace=True)
                else:
                    pass
            except:pass
            chunk = chunk[ordem]
            exec('{} = {}.append(chunk)'.format('sinasc_' + str(i), 'sinasc_' + str(i)))
        exec('{}.to_csv("/content/gdrive/MyDrive/br_ms_sinasc/temp/{}.csv",index=False, encoding="utf-8", na_rep="", date_format="%Y-%m-%d")'.format('sinasc_' + str(i), 'sinasc_' + str(i)))
        exec('del {}'.format('sinasc_' + str(i)))
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# fazendo chunck 8 de 2002
# fazendo chunck 9 de 2002
# fazendo chunck 10 de 2002
# fazendo chunck 11 de 2002
# fazendo chunck 12 de 2002
# fazendo chunck 13 de 2002
# fazendo chunck 14 de 2002
# fazendo chunck 15 de 2002
# fazendo chunck 16 de 2002
# fazendo chunck 17 de 2002
# fazendo chunck 18 de 2002
# fazendo chunck 19 de 2002
# fazendo chunck 20 de 2002
# fazendo chunck 21 de 2002
# fazendo chunck 22 de 2002
# fazendo chunck 23 de 2002
# fazendo chunck 24 de 2002
# fazendo chunck 25 de 2002
# fazendo chunck 26 de 2002
# fazendo chunck 27 de 2002
# fazendo chunck 28 de 2002
# fazendo chunck 29 de 2002
# fazendo chunck 30 de 2002
# fazendo chunck 31 de 2002
# fazendo chunck 1 de 2003
# fazendo chunck 2 de 2003
# fazendo chunck 3 de 2003
# fazendo chunck 4 de 2003
# fazendo chunck 5 de 2003
# fazendo chunck 6 de 2003
# fazendo chunck 7 de 2003
# fazendo chunck 8 de 2003
# fazendo chunck 9 de 2003
# ...

# %% [markdown]
# #### Particionando por UF

# %%
temp = []
for filepath in glob.iglob(r'/content/gdrive/MyDrive/br_ms_sinasc/temp/*.csv'):
    temp.append(filepath)

anot=[]
for i in range(len(temp)) : anot.append(int(temp[i][-8:-4]))

dict_anot = dict(zip(anot, temp))
dict_anot
# Out:
# {1994: '/content/gdrive/MyDrive/br_ms_sinasc/temp/sinasc_1994.csv',
#  1995: '/content/gdrive/MyDrive/br_ms_sinasc/temp/sinasc_1995.csv',
#  1996: '/content/gdrive/MyDrive/br_ms_sinasc/temp/sinasc_1996.csv',
#  1997: '/content/gdrive/MyDrive/br_ms_sinasc/temp/sinasc_1997.csv',
#  1998: '/content/gdrive/MyDrive/br_ms_sinasc/temp/sinasc_1998.csv',
#  1999: '/content/gdrive/MyDrive/br_ms_sinasc/temp/sinasc_1999.csv',
#  2000: '/content/gdrive/MyDrive/br_ms_sinasc/temp/sinasc_2000.csv',
#  2001: '/content/gdrive/MyDrive/br_ms_sinasc/temp/sinasc_2001.csv',
#  2002: '/content/gdrive/MyDrive/br_ms_sinasc/temp/sinasc_2002.csv',
#  2003: '/content/gdrive/MyDrive/br_ms_sinasc/temp/sinasc_2003.csv',
#  2004: '/content/gdrive/MyDrive/br_ms_sinasc/temp/sinasc_2004.csv',
#  2005: '/content/gdrive/MyDrive/br_ms_sinasc/temp/sinasc_2005.csv',
#  2006: '/content/gdrive/MyDrive/br_ms_sinasc/temp/sinasc_2006.csv',
#  2007: '/content/gdrive/MyDrive/br_ms_sinasc/temp/sinasc_2007.csv',
# ...

# %%
for i in anot:
  for uf in ufs: 
    if i == 2010:
        exec('{} = pd.read_csv("/content/gdrive/MyDrive/br_ms_sinasc/temp/sinasc_{}.csv", sep=",", dtype="string")'.format('sinasc_' + str(i), str(i)))
        exec("{}.sort_values(['sequencial_nascimento', 'id_municipio_nascimento', 'data_nascimento'], inplace=True)".format('sinasc_' + str(i)))
        exec("{}.drop_duplicates(subset=['sequencial_nascimento', 'id_municipio_nascimento', 'data_nascimento'], keep='first', inplace=True)".format('sinasc_' + str(i)))
        exec("{} = {}[{}['sigla_uf']== uf]".format('sinasc_' + str(i), 'sinasc_' + str(i), 'sinasc_' + str(i)))
        exec("{}.drop(['sigla_uf', 'numero_lote.1'], axis=1, inplace=True)".format('sinasc_' + str(i)))
        print("Particionando {} de {}".format(uf, str(i)))
        exec('{}.to_csv("/content/gdrive/MyDrive/br_ms_sinasc/output/ano={}/sigla_uf={}/microdados.csv",index=False, encoding="utf-8", na_rep="", date_format="%Y-%m-%d")'.format('sinasc_' + str(i), str(i), uf))
        exec('del {}'.format('sinasc_' + str(i)))

# %%
for i in anot:
  for uf in ufs: 
    if i < 2010  or  i > 2010:
        exec('{} = pd.read_csv("/content/gdrive/MyDrive/br_ms_sinasc/temp/sinasc_{}.csv", sep=",", dtype="string")'.format('sinasc_' + str(i), str(i)))
        exec("{}.sort_values(['sequencial_nascimento', 'id_municipio_nascimento', 'data_nascimento'], inplace=True)".format('sinasc_' + str(i)))
        exec("{}.drop_duplicates(subset=['sequencial_nascimento', 'id_municipio_nascimento', 'data_nascimento'], keep='first', inplace=True)".format('sinasc_' + str(i)))
        exec("{} = {}[{}['sigla_uf']== uf]".format('sinasc_' + str(i), 'sinasc_' + str(i), 'sinasc_' + str(i)))
        exec("{}.drop('sigla_uf', axis=1, inplace=True)".format('sinasc_' + str(i)))
        print("Particionando {} de {}".format(uf, str(i)))
        exec('{}.to_csv("/content/gdrive/MyDrive/br_ms_sinasc/output/ano={}/sigla_uf={}/microdados.csv",index=False, encoding="utf-8", na_rep="", date_format="%Y-%m-%d")'.format('sinasc_' + str(i), str(i), uf))
        exec('del {}'.format('sinasc_' + str(i)))
# Out:
# Particionando AC de 2008
# Particionando AL de 2008
# Particionando AM de 2008
# Particionando AP de 2008
# Particionando BA de 2008
# Particionando CE de 2008
# Particionando DF de 2008
# Particionando ES de 2008
# Particionando GO de 2008
# Particionando MA de 2008
# Particionando MG de 2008
# Particionando MS de 2008
# Particionando MT de 2008
# Particionando PA de 2008
# Particionando PB de 2008
# Particionando PE de 2008
# Particionando PI de 2008
# Particionando PR de 2008
# Particionando RJ de 2008
# Particionando RN de 2008
# Particionando RO de 2008
# Particionando RR de 2008
# Particionando RS de 2008
# Particionando SC de 2008
# Particionando SE de 2008
# Particionando SP de 2008
# Particionando TO de 2008
# Particionando AC de 2009
# Particionando AL de 2009
# Particionando AM de 2009
# Particionando AP de 2009
# Particionando BA de 2009
# Particionando CE de 2009
# Particionando DF de 2009
# Particionando ES de 2009
# Particionando GO de 2009
# Particionando MA de 2009
# ...
