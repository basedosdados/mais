# %%
import basedosdados as bd
import pandas as pd
import numpy as np

# %%
#query para construir base excluindo ano de 2021 que sera atualizado

query = '''
(SELECT 
ano,
'Brasil' AS sigla_uf,
rede,
localizacao,
media_lp_2,
media_mt_2,
media_lp_5,
media_mt_5,
media_lp_9,
media_mt_9,
media_lp_3 AS media_lp_em,
media_mt_3 AS media_mt_em,
nivel_0_lp_2,
nivel_1_lp_2,
nivel_2_lp_2,
nivel_3_lp_2,
nivel_4_lp_2,
nivel_5_lp_2,
nivel_6_lp_2,
nivel_7_lp_2,
nivel_8_lp_2,
nivel_0_mt_2,
nivel_1_mt_2,
nivel_2_mt_2,
nivel_3_mt_2,
nivel_4_mt_2,
nivel_5_mt_2,
nivel_6_mt_2,
nivel_7_mt_2,
nivel_8_mt_2,
nivel_0_lp_5,
nivel_1_lp_5,
nivel_2_lp_5,
nivel_3_lp_5,
nivel_4_lp_5,
nivel_5_lp_5,
nivel_6_lp_5,
nivel_7_lp_5,
nivel_8_lp_5,
nivel_9_lp_5,
nivel_0_mt_5,
nivel_1_mt_5,
nivel_2_mt_5,
nivel_3_mt_5,
nivel_4_mt_5,
nivel_5_mt_5,
nivel_6_mt_5,
nivel_7_mt_5,
nivel_8_mt_5,
nivel_9_mt_5,
nivel_10_mt_5,
nivel_0_lp_9,
nivel_1_lp_9,
nivel_2_lp_9,
nivel_3_lp_9,
nivel_4_lp_9,
nivel_5_lp_9,
nivel_6_lp_9,
nivel_7_lp_9,
nivel_8_lp_9,
nivel_0_mt_9,
nivel_1_mt_9,
nivel_2_mt_9,
nivel_3_mt_9,
nivel_4_mt_9,
nivel_5_mt_9,
nivel_6_mt_9,
nivel_7_mt_9,
nivel_8_mt_9,
nivel_9_mt_9,
nivel_0_lp_3 AS nivel_0_lp_em,
nivel_1_lp_3 AS nivel_1_lp_em,
nivel_2_lp_3 AS nivel_2_lp_em,
nivel_3_lp_3 AS nivel_3_lp_em,
nivel_4_lp_3 AS nivel_4_lp_em,
nivel_5_lp_3 AS nivel_5_lp_em,
nivel_6_lp_3 AS nivel_6_lp_em,
nivel_7_lp_3 AS nivel_7_lp_em,
nivel_8_lp_3 AS nivel_8_lp_em,
nivel_0_mt_3 AS nivel_0_mt_em,
nivel_1_lp_3 AS nivel_1_mt_em,
nivel_2_lp_3 AS nivel_2_mt_em,
nivel_3_lp_3 AS nivel_3_mt_em,
nivel_4_lp_3 AS nivel_4_mt_em,
nivel_5_lp_3 AS nivel_5_mt_em,
nivel_6_lp_3 AS nivel_6_mt_em,
nivel_7_lp_3 AS nivel_7_mt_em,
nivel_8_lp_3 AS nivel_8_mt_em,
nivel_9_lp_3 AS nivel_9_mt_em,
nivel_10_lp_3 AS nivel_10_mt_em
FROM (
SELECT * FROM (
(WITH saeb AS (
SELECT
ano, 
disciplina, 
peso_aluno,
CASE
WHEN serie = 2 THEN 2
WHEN serie = 5 THEN 5
WHEN serie = 9 THEN 9
WHEN serie = 3 THEN 3
END AS serie,
CASE
WHEN rede = '1' THEN 'federal'
WHEN rede = '2' THEN 'estadual'
WHEN rede = '3' THEN 'municipal'
WHEN rede = '4' THEN 'privada'
END AS rede,
'total' AS localizacao,
proficiencia_saeb,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb < 650) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb < 125) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb < 200) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb < 650) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb < 125) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb < 200) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb < 225) THEN 1
ELSE 0
END AS nivel_0,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 650 AND proficiencia_saeb < 675) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 125 AND proficiencia_saeb < 150) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 200 AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 650 AND proficiencia_saeb < 675) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 125 AND proficiencia_saeb < 150) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 200 AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 2250) THEN 1
ELSE 0
END AS nivel_1,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 675 AND proficiencia_saeb < 700) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 150 AND proficiencia_saeb < 175) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 675 AND proficiencia_saeb < 700) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 150 AND proficiencia_saeb < 175) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
ELSE 0
END AS nivel_2,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 700 AND proficiencia_saeb < 725) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 175 AND proficiencia_saeb < 200) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 700 AND proficiencia_saeb < 725) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 175 AND proficiencia_saeb < 200) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
ELSE 0
END AS nivel_3,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 725 AND proficiencia_saeb < 750) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 200 AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 725 AND proficiencia_saeb < 750) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 200 AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
ELSE 0
END AS nivel_4,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 750 AND proficiencia_saeb < 775) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 750 AND proficiencia_saeb < 775) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
ELSE 0
END AS nivel_5,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 775 AND proficiencia_saeb < 800) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 350 AND proficiencia_saeb < 375) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 775 AND proficiencia_saeb < 800) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 350 AND proficiencia_saeb < 375) THEN 1
ELSE 0
END AS nivel_6,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 800 AND proficiencia_saeb < 825) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 350 AND proficiencia_saeb < 375) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 375 AND proficiencia_saeb < 400) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 800 AND proficiencia_saeb < 825) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 350 AND proficiencia_saeb < 375) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 375 AND proficiencia_saeb < 400) THEN 1
ELSE 0
END AS nivel_7,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 825) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 375) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 400) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 825) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 375 AND proficiencia_saeb < 400) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 400 AND proficiencia_saeb < 425) THEN 1
ELSE 0
END AS nivel_8,
CASE
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 325) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 400) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 425 AND proficiencia_saeb < 450) THEN 1
ELSE 0
END AS nivel_9,
CASE
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 350) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 450) THEN 1
ELSE 0
END AS nivel_10,
FROM `basedosdados.br_inep_saeb.proficiencia`
WHERE ano >= 2011
)
SELECT 
ano, 
rede,
localizacao, 
serie,
disciplina,
SUM (proficiencia_saeb * peso_aluno)/ SUM (peso_aluno) AS media,
100 * SUM(nivel_0 * peso_aluno) / SUM(peso_aluno) as nivel_0,
100 * SUM(nivel_1 * peso_aluno) / SUM(peso_aluno) as nivel_1,
100 * SUM(nivel_2 * peso_aluno) / SUM(peso_aluno) as nivel_2,
100 * SUM(nivel_3 * peso_aluno) / SUM(peso_aluno) as nivel_3,
100 * SUM(nivel_4 * peso_aluno) / SUM(peso_aluno) as nivel_4,
100 * SUM(nivel_5 * peso_aluno) / SUM(peso_aluno) as nivel_5,
100 * SUM(nivel_6 * peso_aluno) / SUM(peso_aluno) as nivel_6,
100 * SUM(nivel_7 * peso_aluno) / SUM(peso_aluno) as nivel_7,
100 * SUM(nivel_8 * peso_aluno) / SUM(peso_aluno) as nivel_8,
100 * SUM(nivel_9 * peso_aluno) / SUM(peso_aluno) as nivel_9,
100 * SUM(nivel_10 * peso_aluno) / SUM(peso_aluno) as nivel_10

FROM saeb
GROUP BY ano, rede, localizacao, serie, disciplina
)

UNION ALL

(WITH saeb AS (
SELECT
ano, 
disciplina, 
peso_aluno,
CASE
WHEN serie = 2 THEN 2
WHEN serie = 5 THEN 5
WHEN serie = 9 THEN 9
WHEN serie = 3 THEN 3
END AS serie,
CASE
WHEN rede = '1' OR rede = '2' OR rede = '3' OR rede = '4' THEN 'total - federal, estadual, municipal e privada'
END AS rede,
'total' AS localizacao,
proficiencia_saeb,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb < 650) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb < 125) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb < 200) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb < 650) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb < 125) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb < 200) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb < 225) THEN 1
ELSE 0
END AS nivel_0,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 650 AND proficiencia_saeb < 675) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 125 AND proficiencia_saeb < 150) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 200 AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 650 AND proficiencia_saeb < 675) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 125 AND proficiencia_saeb < 150) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 200 AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 2250) THEN 1
ELSE 0
END AS nivel_1,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 675 AND proficiencia_saeb < 700) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 150 AND proficiencia_saeb < 175) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 675 AND proficiencia_saeb < 700) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 150 AND proficiencia_saeb < 175) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
ELSE 0
END AS nivel_2,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 700 AND proficiencia_saeb < 725) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 175 AND proficiencia_saeb < 200) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 700 AND proficiencia_saeb < 725) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 175 AND proficiencia_saeb < 200) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
ELSE 0
END AS nivel_3,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 725 AND proficiencia_saeb < 750) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 200 AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 725 AND proficiencia_saeb < 750) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 200 AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
ELSE 0
END AS nivel_4,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 750 AND proficiencia_saeb < 775) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 750 AND proficiencia_saeb < 775) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
ELSE 0
END AS nivel_5,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 775 AND proficiencia_saeb < 800) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 350 AND proficiencia_saeb < 375) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 775 AND proficiencia_saeb < 800) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 350 AND proficiencia_saeb < 375) THEN 1
ELSE 0
END AS nivel_6,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 800 AND proficiencia_saeb < 825) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 350 AND proficiencia_saeb < 375) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 375 AND proficiencia_saeb < 400) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 800 AND proficiencia_saeb < 825) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 350 AND proficiencia_saeb < 375) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 375 AND proficiencia_saeb < 400) THEN 1
ELSE 0
END AS nivel_7,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 825) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 375) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 400) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 825) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 375 AND proficiencia_saeb < 400) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 400 AND proficiencia_saeb < 425) THEN 1
ELSE 0
END AS nivel_8,
CASE
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 325) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 400) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 425 AND proficiencia_saeb < 450) THEN 1
ELSE 0
END AS nivel_9,
CASE
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 350) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 450) THEN 1
ELSE 0
END AS nivel_10,
FROM `basedosdados.br_inep_saeb.proficiencia`
WHERE ano >= 2011
)
SELECT 
ano, 
rede,
localizacao, 
serie,
disciplina,
SUM (proficiencia_saeb * peso_aluno)/ SUM (peso_aluno) AS media,
100 * SUM(nivel_0 * peso_aluno) / SUM(peso_aluno) as nivel_0,
100 * SUM(nivel_1 * peso_aluno) / SUM(peso_aluno) as nivel_1,
100 * SUM(nivel_2 * peso_aluno) / SUM(peso_aluno) as nivel_2,
100 * SUM(nivel_3 * peso_aluno) / SUM(peso_aluno) as nivel_3,
100 * SUM(nivel_4 * peso_aluno) / SUM(peso_aluno) as nivel_4,
100 * SUM(nivel_5 * peso_aluno) / SUM(peso_aluno) as nivel_5,
100 * SUM(nivel_6 * peso_aluno) / SUM(peso_aluno) as nivel_6,
100 * SUM(nivel_7 * peso_aluno) / SUM(peso_aluno) as nivel_7,
100 * SUM(nivel_8 * peso_aluno) / SUM(peso_aluno) as nivel_8,
100 * SUM(nivel_9 * peso_aluno) / SUM(peso_aluno) as nivel_9,
100 * SUM(nivel_10 * peso_aluno) / SUM(peso_aluno) as nivel_10

FROM saeb
GROUP BY ano, rede, localizacao, serie, disciplina
)

UNION ALL

(WITH saeb AS (
SELECT
ano, 
disciplina, 
peso_aluno,
CASE
WHEN serie = 2 THEN 2
WHEN serie = 5 THEN 5
WHEN serie = 9 THEN 9
WHEN serie = 3 THEN 3
END AS serie,
CASE
WHEN rede = '1' OR rede = '2' OR rede = '3' THEN 'total - federal, estadual e municipal'
END AS rede,
'total' AS localizacao,
proficiencia_saeb,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb < 650) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb < 125) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb < 200) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb < 650) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb < 125) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb < 200) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb < 225) THEN 1
ELSE 0
END AS nivel_0,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 650 AND proficiencia_saeb < 675) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 125 AND proficiencia_saeb < 150) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 200 AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 650 AND proficiencia_saeb < 675) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 125 AND proficiencia_saeb < 150) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 200 AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 2250) THEN 1
ELSE 0
END AS nivel_1,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 675 AND proficiencia_saeb < 700) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 150 AND proficiencia_saeb < 175) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 675 AND proficiencia_saeb < 700) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 150 AND proficiencia_saeb < 175) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
ELSE 0
END AS nivel_2,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 700 AND proficiencia_saeb < 725) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 175 AND proficiencia_saeb < 200) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 700 AND proficiencia_saeb < 725) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 175 AND proficiencia_saeb < 200) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
ELSE 0
END AS nivel_3,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 725 AND proficiencia_saeb < 750) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 200 AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 725 AND proficiencia_saeb < 750) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 200 AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
ELSE 0
END AS nivel_4,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 750 AND proficiencia_saeb < 775) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 750 AND proficiencia_saeb < 775) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
ELSE 0
END AS nivel_5,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 775 AND proficiencia_saeb < 800) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 350 AND proficiencia_saeb < 375) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 775 AND proficiencia_saeb < 800) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 350 AND proficiencia_saeb < 375) THEN 1
ELSE 0
END AS nivel_6,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 800 AND proficiencia_saeb < 825) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 350 AND proficiencia_saeb < 375) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 375 AND proficiencia_saeb < 400) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 800 AND proficiencia_saeb < 825) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 350 AND proficiencia_saeb < 375) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 375 AND proficiencia_saeb < 400) THEN 1
ELSE 0
END AS nivel_7,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 825) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 375) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 400) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 825) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 375 AND proficiencia_saeb < 400) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 400 AND proficiencia_saeb < 425) THEN 1
ELSE 0
END AS nivel_8,
CASE
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 325) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 400) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 425 AND proficiencia_saeb < 450) THEN 1
ELSE 0
END AS nivel_9,
CASE
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 350) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 450) THEN 1
ELSE 0
END AS nivel_10,
FROM `basedosdados.br_inep_saeb.proficiencia`
WHERE ano >= 2011
)
SELECT 
ano, 
rede,
localizacao, 
serie,
disciplina,
SUM (proficiencia_saeb * peso_aluno)/ SUM (peso_aluno) AS media,
100 * SUM(nivel_0 * peso_aluno) / SUM(peso_aluno) as nivel_0,
100 * SUM(nivel_1 * peso_aluno) / SUM(peso_aluno) as nivel_1,
100 * SUM(nivel_2 * peso_aluno) / SUM(peso_aluno) as nivel_2,
100 * SUM(nivel_3 * peso_aluno) / SUM(peso_aluno) as nivel_3,
100 * SUM(nivel_4 * peso_aluno) / SUM(peso_aluno) as nivel_4,
100 * SUM(nivel_5 * peso_aluno) / SUM(peso_aluno) as nivel_5,
100 * SUM(nivel_6 * peso_aluno) / SUM(peso_aluno) as nivel_6,
100 * SUM(nivel_7 * peso_aluno) / SUM(peso_aluno) as nivel_7,
100 * SUM(nivel_8 * peso_aluno) / SUM(peso_aluno) as nivel_8,
100 * SUM(nivel_9 * peso_aluno) / SUM(peso_aluno) as nivel_9,
100 * SUM(nivel_10 * peso_aluno) / SUM(peso_aluno) as nivel_10

FROM saeb
GROUP BY ano, rede, localizacao, serie, disciplina
)

UNION ALL

(WITH saeb AS (
SELECT
ano, 
disciplina, 
peso_aluno,
CASE
WHEN serie = 2 THEN 2
WHEN serie = 5 THEN 5
WHEN serie = 9 THEN 9
WHEN serie = 3 THEN 3
END AS serie,
CASE
WHEN rede = '2' OR rede = '3' THEN 'total - estadual e municipal'
END AS rede,
'total' AS localizacao,
proficiencia_saeb,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb < 650) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb < 125) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb < 200) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb < 650) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb < 125) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb < 200) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb < 225) THEN 1
ELSE 0
END AS nivel_0,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 650 AND proficiencia_saeb < 675) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 125 AND proficiencia_saeb < 150) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 200 AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 650 AND proficiencia_saeb < 675) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 125 AND proficiencia_saeb < 150) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 200 AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 2250) THEN 1
ELSE 0
END AS nivel_1,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 675 AND proficiencia_saeb < 700) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 150 AND proficiencia_saeb < 175) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 675 AND proficiencia_saeb < 700) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 150 AND proficiencia_saeb < 175) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
ELSE 0
END AS nivel_2,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 700 AND proficiencia_saeb < 725) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 175 AND proficiencia_saeb < 200) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 700 AND proficiencia_saeb < 725) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 175 AND proficiencia_saeb < 200) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
ELSE 0
END AS nivel_3,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 725 AND proficiencia_saeb < 750) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 200 AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 725 AND proficiencia_saeb < 750) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 200 AND proficiencia_saeb < 225) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
ELSE 0
END AS nivel_4,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 750 AND proficiencia_saeb < 775) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 750 AND proficiencia_saeb < 775) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 225 AND proficiencia_saeb < 250) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
ELSE 0
END AS nivel_5,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 775 AND proficiencia_saeb < 800) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 350 AND proficiencia_saeb < 375) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 775 AND proficiencia_saeb < 800) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 250 AND proficiencia_saeb < 275) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 350 AND proficiencia_saeb < 375) THEN 1
ELSE 0
END AS nivel_6,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 800 AND proficiencia_saeb < 825) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 350 AND proficiencia_saeb < 375) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 375 AND proficiencia_saeb < 400) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 800 AND proficiencia_saeb < 825) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 275 AND proficiencia_saeb < 300) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 350 AND proficiencia_saeb < 375) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 375 AND proficiencia_saeb < 400) THEN 1
ELSE 0
END AS nivel_7,
CASE
WHEN (serie = 2 AND disciplina = 'LP' AND proficiencia_saeb >= 825) THEN 1
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 9 AND disciplina = 'LP' AND proficiencia_saeb >= 375) THEN 1
WHEN (serie = 3 AND disciplina = 'LP' AND proficiencia_saeb >= 400) THEN 1
WHEN (serie = 2 AND disciplina = 'MT' AND proficiencia_saeb >= 825) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 300 AND proficiencia_saeb < 325) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 375 AND proficiencia_saeb < 400) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 400 AND proficiencia_saeb < 425) THEN 1
ELSE 0
END AS nivel_8,
CASE
WHEN (serie = 5 AND disciplina = 'LP' AND proficiencia_saeb >= 325) THEN 1
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 325 AND proficiencia_saeb < 350) THEN 1
WHEN (serie = 9 AND disciplina = 'MT' AND proficiencia_saeb >= 400) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 425 AND proficiencia_saeb < 450) THEN 1
ELSE 0
END AS nivel_9,
CASE
WHEN (serie = 5 AND disciplina = 'MT' AND proficiencia_saeb >= 350) THEN 1
WHEN (serie = 3 AND disciplina = 'MT' AND proficiencia_saeb >= 450) THEN 1
ELSE 0
END AS nivel_10,
FROM `basedosdados.br_inep_saeb.proficiencia`
WHERE ano >= 2011
)
SELECT 
ano,
rede,
localizacao, 
serie,
disciplina,
SUM (proficiencia_saeb * peso_aluno)/ SUM (peso_aluno) AS media,
100 * SUM(nivel_0 * peso_aluno) / SUM(peso_aluno) as nivel_0,
100 * SUM(nivel_1 * peso_aluno) / SUM(peso_aluno) as nivel_1,
100 * SUM(nivel_2 * peso_aluno) / SUM(peso_aluno) as nivel_2,
100 * SUM(nivel_3 * peso_aluno) / SUM(peso_aluno) as nivel_3,
100 * SUM(nivel_4 * peso_aluno) / SUM(peso_aluno) as nivel_4,
100 * SUM(nivel_5 * peso_aluno) / SUM(peso_aluno) as nivel_5,
100 * SUM(nivel_6 * peso_aluno) / SUM(peso_aluno) as nivel_6,
100 * SUM(nivel_7 * peso_aluno) / SUM(peso_aluno) as nivel_7,
100 * SUM(nivel_8 * peso_aluno) / SUM(peso_aluno) as nivel_8,
100 * SUM(nivel_9 * peso_aluno) / SUM(peso_aluno) as nivel_9,
100 * SUM(nivel_10 * peso_aluno) / SUM(peso_aluno) as nivel_10

FROM saeb
GROUP BY ano, rede, localizacao, serie, disciplina
))
PIVOT (
MAX (media) AS media,
MAX (nivel_0) AS nivel_0,
MAX (nivel_1) AS nivel_1,
MAX (nivel_2) AS nivel_2,
MAX (nivel_3) AS nivel_3,
MAX (nivel_4) AS nivel_4,
MAX (nivel_5) AS nivel_5,
MAX (nivel_6) AS nivel_6,
MAX (nivel_7) AS nivel_7,
MAX (nivel_8) AS nivel_8,
MAX (nivel_9) AS nivel_9,
MAX (nivel_10) AS nivel_10
FOR disciplina IN
('LP', 'MT')
)
)
PIVOT (
MAX (media_LP) AS media_LP,
MAX (media_MT) AS media_MT,
MAX (nivel_0_LP) AS nivel_0_LP,
MAX (nivel_1_LP) AS nivel_1_LP,
MAX (nivel_2_LP) AS nivel_2_LP,
MAX (nivel_3_LP) AS nivel_3_LP,
MAX (nivel_4_LP) AS nivel_4_LP,
MAX (nivel_5_LP) AS nivel_5_LP,
MAX (nivel_6_LP) AS nivel_6_LP,
MAX (nivel_7_LP) AS nivel_7_LP,
MAX (nivel_8_LP) AS nivel_8_LP,
MAX (nivel_9_LP) AS nivel_9_LP,
MAX (nivel_10_LP) AS nivel_10_LP,
MAX (nivel_0_MT) AS nivel_0_MT,
MAX (nivel_1_MT) AS nivel_1_MT,
MAX (nivel_2_MT) AS nivel_2_MT,
MAX (nivel_3_MT) AS nivel_3_MT,
MAX (nivel_4_MT) AS nivel_4_MT,
MAX (nivel_5_MT) AS nivel_5_MT,
MAX (nivel_6_MT) AS nivel_6_MT,
MAX (nivel_7_MT) AS nivel_7_MT,
MAX (nivel_8_MT) AS nivel_8_MT,
MAX (nivel_9_MT) AS nivel_9_MT,
MAX (nivel_10_MT) AS nivel_10_MT
FOR serie IN
(2,5,9,3)
)
WHERE rede IS NOT NULL
)

UNION ALL

(SELECT 
ano,
sigla_uf,
rede,
localizacao,
media_lp_2,
media_mt_2,
media_lp_5,
media_mt_5,
media_lp_9,
media_mt_9,
media_lp_em,
media_mt_em,
nivel_0_lp_2,
nivel_1_lp_2,
nivel_2_lp_2,
nivel_3_lp_2,
nivel_4_lp_2,
nivel_5_lp_2,
nivel_6_lp_2,
nivel_7_lp_2,
nivel_8_lp_2,
nivel_0_mt_2,
nivel_1_mt_2,
nivel_2_mt_2,
nivel_3_mt_2,
nivel_4_mt_2,
nivel_5_mt_2,
nivel_6_mt_2,
nivel_7_mt_2,
nivel_8_mt_2,
nivel_0_lp_5,
nivel_1_lp_5,
nivel_2_lp_5,
nivel_3_lp_5,
nivel_4_lp_5,
nivel_5_lp_5,
nivel_6_lp_5,
nivel_7_lp_5,
nivel_8_lp_5,
nivel_9_lp_5,
nivel_0_mt_5,
nivel_1_mt_5,
nivel_2_mt_5,
nivel_3_mt_5,
nivel_4_mt_5,
nivel_5_mt_5,
nivel_6_mt_5,
nivel_7_mt_5,
nivel_8_mt_5,
nivel_9_mt_5,
nivel_10_mt_5,
nivel_0_lp_9,
nivel_1_lp_9,
nivel_2_lp_9,
nivel_3_lp_9,
nivel_4_lp_9,
nivel_5_lp_9,
nivel_6_lp_9,
nivel_7_lp_9,
nivel_8_lp_9,
nivel_0_mt_9,
nivel_1_mt_9,
nivel_2_mt_9,
nivel_3_mt_9,
nivel_4_mt_9,
nivel_5_mt_9,
nivel_6_mt_9,
nivel_7_mt_9,
nivel_8_mt_9,
nivel_9_mt_9,
nivel_0_lp_em,
nivel_1_lp_em,
nivel_2_lp_em,
nivel_3_lp_em,
nivel_4_lp_em,
nivel_5_lp_em,
nivel_6_lp_em,
nivel_7_lp_em,
nivel_8_lp_em,
nivel_0_mt_em,
nivel_1_mt_em,
nivel_2_mt_em,
nivel_3_mt_em,
nivel_4_mt_em,
nivel_5_mt_em,
nivel_6_mt_em,
nivel_7_mt_em,
nivel_8_mt_em,
nivel_9_mt_em,
nivel_10_mt_em
FROM `projeto-basedosdados-fl.tabelas.saeb_uf_2021`)

UNION ALL

(SELECT 
ano,
sigla_uf,
rede,
localizacao,
media_lp_2,
media_mt_2,
media_lp_5,
media_mt_5,
media_lp_9,
media_mt_9,
media_lp_em,
media_mt_em,
nivel_0_lp_2,
nivel_1_lp_2,
nivel_2_lp_2,
nivel_3_lp_2,
nivel_4_lp_2,
nivel_5_lp_2,
nivel_6_lp_2,
nivel_7_lp_2,
nivel_8_lp_2,
nivel_0_mt_2,
nivel_1_mt_2,
nivel_2_mt_2,
nivel_3_mt_2,
nivel_4_mt_2,
nivel_5_mt_2,
nivel_6_mt_2,
nivel_7_mt_2,
nivel_8_mt_2,
nivel_0_lp_5,
nivel_1_lp_5,
nivel_2_lp_5,
nivel_3_lp_5,
nivel_4_lp_5,
nivel_5_lp_5,
nivel_6_lp_5,
nivel_7_lp_5,
nivel_8_lp_5,
nivel_9_lp_5,
nivel_0_mt_5,
nivel_1_mt_5,
nivel_2_mt_5,
nivel_3_mt_5,
nivel_4_mt_5,
nivel_5_mt_5,
nivel_6_mt_5,
nivel_7_mt_5,
nivel_8_mt_5,
nivel_9_mt_5,
nivel_10_mt_5,
nivel_0_lp_9,
nivel_1_lp_9,
nivel_2_lp_9,
nivel_3_lp_9,
nivel_4_lp_9,
nivel_5_lp_9,
nivel_6_lp_9,
nivel_7_lp_9,
nivel_8_lp_9,
nivel_0_mt_9,
nivel_1_mt_9,
nivel_2_mt_9,
nivel_3_mt_9,
nivel_4_mt_9,
nivel_5_mt_9,
nivel_6_mt_9,
nivel_7_mt_9,
nivel_8_mt_9,
nivel_9_mt_9,
nivel_0_lp_em,
nivel_1_lp_em,
nivel_2_lp_em,
nivel_3_lp_em,
nivel_4_lp_em,
nivel_5_lp_em,
nivel_6_lp_em,
nivel_7_lp_em,
nivel_8_lp_em,
nivel_0_mt_em,
nivel_1_mt_em,
nivel_2_mt_em,
nivel_3_mt_em,
nivel_4_mt_em,
nivel_5_mt_em,
nivel_6_mt_em,
nivel_7_mt_em,
nivel_8_mt_em,
nivel_9_mt_em,
nivel_10_mt_em
FROM `projeto-basedosdados-fl.tabelas.saeb_br_2021`)
ORDER BY ano, rede, localizacao
'''

saeb_bq_br = bd.read_sql(query, billing_project_id='')

#corrige problema no erro de preenchimento da categoria de rede
saeb_bq_br['rede'] = saeb_bq_br['rede'].replace('total -federal, estadual, municipal e privada', 'total - federal, estadual, municipal e privada')

#so em 2021 diferencia tipos de ensino medio, para compatibilizar com a série existênte a diferença será desconsiderada.
saeb_bq_br = saeb_bq_br[saeb_bq_br['ano'] != 2021]

# %%
#importa dados do saeb baixados do ibge
#https://www.gov.br/inep/pt-br/areas-de-atuacao/avaliacao-e-exames-educacionais/saeb/resultados#:~:text=Planilhas%20de%20Resultados%20(Brasil%2C%20estados%20e%20municípios)%20%7C%20Saeb%202021%20(Atualizado%20em%2026/12/2022%20–%20retificação%20de%20erros%20secundários%20nos%20resultados%20amostrais)
#05/03/2023
saeb_br = pd.read_excel(r'C:\Users\gabri\OneDrive\vida_profissional\Projetos\base_dos_dados\br_inep_saeb\saeb_2021_brasil_estados_municipios.xlsx', dtype=str, sheet_name='Brasil')
saeb_br.drop(0, axis=0, inplace=True)

#Desconsidera diferença entre capital e interior, filtrando valor total
saeb_br = saeb_br[saeb_br['CAPITAL'] == 'Total']

# %%
#renomear colunas
rename = {'ANO_SAEB': 'ano',
          'DEPENDENCIA_ADM':'rede', 
          'LOCALIZACAO':'localizacao', 
          'CAPITAL':'capital',
          'MEDIA_2_LP':'media_lp_2',
          'MEDIA_2_MT':'media_mt_2',
          'MEDIA_5_LP':'media_lp_5',
          'MEDIA_5_MT':'media_mt_5', 
          'MEDIA_9_LP':'media_lp_9', 
          'MEDIA_9_MT':'media_mt_9', 
          'MEDIA_12_LP':'media_lp_em', 
          'MEDIA_12_MT':'media_mt_em',
          'MEDIA_13_LP':'media_lp_em_integral',
          'MEDIA_13_MT':'media_mt_em_integral',
          'MEDIA_14_LP':'media_lp_em_regular',
          'MEDIA_14_MT':'media_mt_em_regular',
          'nivel_0_LP2':'nivel_0_lp_2', 
          'nivel_1_LP2':'nivel_1_lp_2', 
          'nivel_2_LP2':'nivel_2_lp_2', 
          'nivel_3_LP2':'nivel_3_lp_2',
          'nivel_4_LP2':'nivel_4_lp_2', 
          'nivel_5_LP2':'nivel_5_lp_2', 
          'nivel_6_LP2':'nivel_6_lp_2', 
          'nivel_7_LP2':'nivel_7_lp_2',
          'nivel_8_LP2':'nivel_8_lp_2', 
          'nivel_0_MT2':'nivel_0_mt_2', 
          'nivel_1_MT2':'nivel_1_mt_2',
          'nivel_2_MT2':'nivel_2_mt_2', 
          'nivel_3_MT2':'nivel_3_mt_2', 
          'nivel_4_MT2':'nivel_4_mt_2', 
          'nivel_5_MT2':'nivel_5_mt_2',
          'nivel_6_MT2':'nivel_6_mt_2', 
          'nivel_7_MT2':'nivel_7_mt_2', 
          'nivel_8_MT2':'nivel_8_mt_2',
          'nivel_0_LP5':'nivel_0_lp_5', 
          'nivel_1_LP5':'nivel_1_lp_5', 
          'nivel_2_LP5':'nivel_2_lp_5', 
          'nivel_3_LP5':'nivel_3_lp_5',
          'nivel_4_LP5':'nivel_4_lp_5', 
          'nivel_5_LP5':'nivel_5_lp_5', 
          'nivel_6_LP5':'nivel_6_lp_5', 
          'nivel_7_LP5':'nivel_7_lp_5',
          'nivel_8_LP5':'nivel_8_lp_5', 
          'nivel_9_LP5':'nivel_9_lp_5', 
          'nivel_0_MT5':'nivel_0_mt_5', 
          'nivel_1_MT5':'nivel_1_mt_5',
          'nivel_2_MT5':'nivel_2_mt_5', 
          'nivel_3_MT5':'nivel_3_mt_5', 
          'nivel_4_MT5':'nivel_4_mt_5', 
          'nivel_5_MT5':'nivel_5_mt_5',
          'nivel_6_MT5':'nivel_6_mt_5', 
          'nivel_7_MT5':'nivel_7_mt_5', 
          'nivel_8_MT5':'nivel_8_mt_5', 
          'nivel_9_MT5':'nivel_9_mt_5',
          'nivel_10_MT5':'nivel_10_mt_5', 
          'nivel_0_LP9':'nivel_0_lp_9', 
          'nivel_1_LP9':'nivel_1_lp_9', 
          'nivel_2_LP9':'nivel_2_lp_9',
          'nivel_3_LP9':'nivel_3_lp_9', 
          'nivel_4_LP9':'nivel_4_lp_9', 
          'nivel_5_LP9':'nivel_5_lp_9', 
          'nivel_6_LP9':'nivel_6_lp_9',
          'nivel_7_LP9':'nivel_7_lp_9', 
          'nivel_8_LP9':'nivel_8_lp_9', 
          'nivel_0_MT9':'nivel_0_mt_9', 
          'nivel_1_MT9':'nivel_1_mt_9',
          'nivel_2_MT9':'nivel_2_mt_9', 
          'nivel_3_MT9':'nivel_3_mt_9', 
          'nivel_4_MT9':'nivel_4_mt_9', 
          'nivel_5_MT9':'nivel_5_mt_9',
          'nivel_6_MT9':'nivel_6_mt_9', 
          'nivel_7_MT9':'nivel_7_mt_9', 
          'nivel_8_MT9':'nivel_8_mt_9', 
          'nivel_9_MT9':'nivel_9_mt_9',
          'nivel_0_LP12':'nivel_0_lp_em', 
          'nivel_1_LP12':'nivel_1_lp_em', 
          'nivel_2_LP12':'nivel_2_lp_em', 
          'nivel_3_LP12':'nivel_3_lp_em',
          'nivel_4_LP12':'nivel_4_lp_em', 
          'nivel_5_LP12':'nivel_5_lp_em', 
          'nivel_6_LP12':'nivel_6_lp_em', 
          'nivel_7_LP12':'nivel_7_lp_em',
          'nivel_8_LP12':'nivel_8_lp_em', 
          'nivel_0_MT12':'nivel_0_mt_em', 
          'nivel_1_MT12':'nivel_1_mt_em', 
          'nivel_2_MT12':'nivel_2_mt_em',
          'nivel_3_MT12':'nivel_3_mt_em', 
          'nivel_4_MT12':'nivel_4_mt_em', 
          'nivel_5_MT12':'nivel_5_mt_em', 
          'nivel_6_MT12':'nivel_6_mt_em',
          'nivel_7_MT12':'nivel_7_mt_em', 
          'nivel_8_MT12':'nivel_8_mt_em', 
          'nivel_9_MT12':'nivel_9_mt_em', 
          'nivel_10_MT12':'nivel_10_mt_em',
          'nivel_0_LP13':'nivel_0_lp_em_integral', 
          'nivel_1_LP13':'nivel_1_lp_em_integral', 
          'nivel_2_LP13':'nivel_2_lp_em_integral', 
          'nivel_3_LP13':'nivel_3_lp_em_integral',
          'nivel_4_LP13':'nivel_4_lp_em_integral', 
          'nivel_5_LP13':'nivel_5_lp_em_integral', 
          'nivel_6_LP13':'nivel_6_lp_em_integral', 
          'nivel_7_LP13':'nivel_7_lp_em_integral',
          'nivel_8_LP13':'nivel_8_lp_em_integral', 
          'nivel_0_MT13':'nivel_0_mt_em_integral', 
          'nivel_1_MT13':'nivel_1_mt_em_integral', 
          'nivel_2_MT13':'nivel_2_mt_em_integral',
          'nivel_3_MT13':'nivel_3_mt_em_integral', 
          'nivel_4_MT13':'nivel_4_mt_em_integral', 
          'nivel_5_MT13':'nivel_5_mt_em_integral', 
          'nivel_6_MT13':'nivel_6_mt_em_integral',
          'nivel_7_MT13':'nivel_7_mt_em_integral', 
          'nivel_8_MT13':'nivel_8_mt_em_integral', 
          'nivel_9_MT13':'nivel_9_mt_em_integral', 
          'nivel_10_MT13':'nivel_10_mt_em_integral',
          'nivel_0_LP14':'nivel_0_lp_em_regular', 
          'nivel_1_LP14':'nivel_1_lp_em_regular', 
          'nivel_2_LP14':'nivel_2_lp_em_regular', 
          'nivel_3_LP14':'nivel_3_lp_em_regular',
          'nivel_4_LP14':'nivel_4_lp_em_regular', 
          'nivel_5_LP14':'nivel_5_lp_em_regular', 
          'nivel_6_LP14':'nivel_6_lp_em_regular', 
          'nivel_7_LP14':'nivel_7_lp_em_regular',
          'nivel_8_LP14':'nivel_8_lp_em_regular', 
          'nivel_0_MT14':'nivel_0_mt_em_regular', 
          'nivel_1_MT14':'nivel_1_mt_em_regular', 
          'nivel_2_MT14':'nivel_2_mt_em_regular',
          'nivel_3_MT14':'nivel_3_mt_em_regular', 
          'nivel_4_MT14':'nivel_4_mt_em_regular', 
          'nivel_5_MT14':'nivel_5_mt_em_regular', 
          'nivel_6_MT14':'nivel_6_mt_em_regular',
          'nivel_7_MT14':'nivel_7_mt_em_regular', 
          'nivel_8_MT14':'nivel_8_mt_em_regular', 
          'nivel_9_MT14':'nivel_9_mt_em_regular', 
          'nivel_10_MT14':'nivel_10_mt_em_regular'}
  


saeb_br.rename(columns=rename, inplace=True)

# %%
#ordenar colunas
ordem_br = ['ano', 'rede','localizacao', 'media_lp_2','media_mt_2','media_lp_5', 'media_mt_5','media_lp_9', 'media_mt_9',
           'media_lp_em', 'media_mt_em','media_lp_em_integral', 'media_mt_em_integral', 
          'media_lp_em_regular', 'media_mt_em_regular',
          'nivel_0_lp_2','nivel_1_lp_2', 'nivel_2_lp_2', 'nivel_3_lp_2','nivel_4_lp_2','nivel_5_lp_2','nivel_6_lp_2',
          'nivel_7_lp_2','nivel_8_lp_2', 'nivel_0_mt_2','nivel_1_mt_2','nivel_2_mt_2','nivel_3_mt_2',
          'nivel_4_mt_2','nivel_5_mt_2', 'nivel_6_mt_2','nivel_7_mt_2', 'nivel_8_mt_2',
          'nivel_0_lp_5','nivel_1_lp_5', 
          'nivel_2_lp_5', 'nivel_3_lp_5','nivel_4_lp_5','nivel_5_lp_5','nivel_6_lp_5','nivel_7_lp_5','nivel_8_lp_5', 
          'nivel_9_lp_5', 'nivel_0_mt_5','nivel_1_mt_5','nivel_2_mt_5','nivel_3_mt_5','nivel_4_mt_5','nivel_5_mt_5',
          'nivel_6_mt_5','nivel_7_mt_5', 'nivel_8_mt_5', 'nivel_9_mt_5','nivel_10_mt_5','nivel_0_lp_9', 
          'nivel_1_lp_9', 'nivel_2_lp_9','nivel_3_lp_9','nivel_4_lp_9','nivel_5_lp_9','nivel_6_lp_9','nivel_7_lp_9', 
          'nivel_8_lp_9', 'nivel_0_mt_9','nivel_1_mt_9','nivel_2_mt_9','nivel_3_mt_9','nivel_4_mt_9', 'nivel_5_mt_9',
          'nivel_6_mt_9', 'nivel_7_mt_9','nivel_8_mt_9', 'nivel_9_mt_9',  'nivel_0_lp_em','nivel_1_lp_em','nivel_2_lp_em',
          'nivel_3_lp_em','nivel_4_lp_em','nivel_5_lp_em','nivel_6_lp_em', 'nivel_7_lp_em','nivel_8_lp_em','nivel_0_mt_em', 
          'nivel_1_mt_em','nivel_2_mt_em','nivel_3_mt_em','nivel_4_mt_em','nivel_5_mt_em','nivel_6_mt_em','nivel_7_mt_em',
          'nivel_8_mt_em','nivel_9_mt_em','nivel_10_mt_em',
          'nivel_0_lp_em_integral','nivel_1_lp_em_integral','nivel_2_lp_em_integral',
          'nivel_3_lp_em_integral','nivel_4_lp_em_integral','nivel_5_lp_em_integral','nivel_6_lp_em_integral', 'nivel_7_lp_em_integral',
          'nivel_8_lp_em_integral','nivel_0_mt_em_integral', 'nivel_1_mt_em_integral','nivel_2_mt_em_integral','nivel_3_mt_em_integral',
          'nivel_4_mt_em_integral','nivel_5_mt_em_integral','nivel_6_mt_em_integral','nivel_7_mt_em_integral', 'nivel_8_mt_em_integral',
          'nivel_9_mt_em_integral','nivel_10_mt_em_integral', 'nivel_0_lp_em_regular','nivel_1_lp_em_regular','nivel_2_lp_em_regular',
          'nivel_3_lp_em_regular','nivel_4_lp_em_regular','nivel_5_lp_em_regular','nivel_6_lp_em_regular', 'nivel_7_lp_em_regular',
          'nivel_8_lp_em_regular','nivel_0_mt_em_regular', 'nivel_1_mt_em_regular','nivel_2_mt_em_regular','nivel_3_mt_em_regular',
          'nivel_4_mt_em_regular','nivel_5_mt_em_regular','nivel_6_mt_em_regular','nivel_7_mt_em_regular', 'nivel_8_mt_em_regular',
          'nivel_9_mt_em_regular','nivel_10_mt_em_regular']

saeb_br = saeb_br[ordem_br]

# %%
# todo: adicionar coluna de sigla uf que nao vem nos dados do inep

#selecionar da base original
#infos do 5,3,9
#renomear
#criar coluna de materia (LP,lp)
#criar coluna de serie (5,3,9)
#adicionar sigla uf
#criar loop para fazer esse processo e criar uma base unica para dar append na saeb municipio
#seleciona as variáveis por disciplina e série {materia}_{serie}

#? lista com series
# ! Para as avaliações de lp não existem niveis 9 e 10. O nivel de LP só vai até 8 para em
l_series = [
            'em_regular', 'em_integral', 'em','5','9','2'
            ]
#? lista com materias
l_materias = [  
              'mt','lp' 
              ]
#? lista vazia para armazenar dados
data2021 = []
#em e 5 mt
#9 mt
#5 lp
#9 ee m lp
#? para cada serie
for serie in l_series:
    #? para cada materia
    for materia in l_materias:


            #mt em ano ate 10 criar nada
            #mt 5 ano ate 10 criar nada  
        if  materia == 'mt' and (serie == '5' or serie =='em' or serie =='em_integral' or serie =='em_regular'): 
            print(f'fazendo serie_{serie} e materia_{materia}')
            #? extrai dados da planilha do ibge, de uma materia de uma serie
            data = saeb_br[['ano', 'rede' ,'localizacao',
                  f'media_{materia}_{serie}',  
                  f'nivel_0_{materia}_{serie}', 
                  f'nivel_1_{materia}_{serie}', 
                  f'nivel_2_{materia}_{serie}', 
                  f'nivel_3_{materia}_{serie}', 
                  f'nivel_4_{materia}_{serie}', 
                  f'nivel_5_{materia}_{serie}',
                  f'nivel_6_{materia}_{serie}', 
                  f'nivel_7_{materia}_{serie}', 
                  f'nivel_8_{materia}_{serie}', 
                  f'nivel_9_{materia}_{serie}', 
                  f'nivel_10_{materia}_{serie}']]
            

        elif materia == 'mt' and serie == '9':
        #mt 9 ano ate 9 criar nivel_10_mt_9
            print(f'fazendo serie_{serie} e materia_{materia}')
            #? extrai dados da planilha do ibge, de uma materia de uma serie
            data = saeb_br[['ano', 'rede' ,'localizacao',
                    f'media_{materia}_{serie}',  
                    f'nivel_0_{materia}_{serie}', 
                    f'nivel_1_{materia}_{serie}', 
                    f'nivel_2_{materia}_{serie}', 
                    f'nivel_3_{materia}_{serie}', 
                    f'nivel_4_{materia}_{serie}', 
                    f'nivel_5_{materia}_{serie}',
                    f'nivel_6_{materia}_{serie}', 
                    f'nivel_7_{materia}_{serie}', 
                    f'nivel_8_{materia}_{serie}', 
                    f'nivel_9_{materia}_{serie}']]
           
            data[f'nivel_10_{materia}_{serie}'] = np.nan

             
        elif materia == 'lp' and serie == '5':    
        #lp 5 ano ate 9 criar  nivel_10_lp_5
            print(f'fazendo serie_{serie} e materia_{materia}')
            #? extrai dados da planilha do ibge, de uma materia de uma serie
            data = saeb_br[['ano', 'rede' ,'localizacao' ,
                    f'media_{materia}_{serie}',  
                    f'nivel_0_{materia}_{serie}', 
                    f'nivel_1_{materia}_{serie}', 
                    f'nivel_2_{materia}_{serie}', 
                    f'nivel_3_{materia}_{serie}', 
                    f'nivel_4_{materia}_{serie}', 
                    f'nivel_5_{materia}_{serie}',
                    f'nivel_6_{materia}_{serie}', 
                    f'nivel_7_{materia}_{serie}', 
                    f'nivel_8_{materia}_{serie}', 
                    f'nivel_9_{materia}_{serie}']]
            
            data[f'nivel_10_{materia}_{serie}'] = np.nan


         #lp 9 ano ate 8 criar nivel_9_lp_9 nivel_10_lp_9
         #lp em ano ate 8 criar  nivel_9_lp_em nivel_10_lp_em
        
        elif materia == 'lp' and (serie == '9' or serie == '2' or serie == 'em' or serie == 'em_integral' or serie =='em_regular'):
            
            print(f'fazendo serie_{serie} e materia_{materia}')
            #? extrai dados da planilha do ibge, de uma materia de uma serie
            data = saeb_br[['ano', 'rede' ,'localizacao' ,
                    f'media_{materia}_{serie}',  
                    f'nivel_0_{materia}_{serie}', 
                    f'nivel_1_{materia}_{serie}', 
                    f'nivel_2_{materia}_{serie}', 
                    f'nivel_3_{materia}_{serie}', 
                    f'nivel_4_{materia}_{serie}', 
                    f'nivel_5_{materia}_{serie}',
                    f'nivel_6_{materia}_{serie}', 
                    f'nivel_7_{materia}_{serie}', 
                    f'nivel_8_{materia}_{serie}']]
            
            data[f'nivel_9_{materia}_{serie}'] = np.nan
            data[f'nivel_10_{materia}_{serie}'] = np.nan       
            
        elif materia == 'mt' and serie == '2':
            
            print(f'fazendo serie_{serie} e materia_{materia}')
            #? extrai dados da planilha do ibge, de uma materia de uma serie
            data = saeb_br[['ano', 'rede' ,'localizacao' ,
                    f'media_{materia}_{serie}',  
                    f'nivel_0_{materia}_{serie}', 
                    f'nivel_1_{materia}_{serie}', 
                    f'nivel_2_{materia}_{serie}', 
                    f'nivel_3_{materia}_{serie}', 
                    f'nivel_4_{materia}_{serie}', 
                    f'nivel_5_{materia}_{serie}',
                    f'nivel_6_{materia}_{serie}', 
                    f'nivel_7_{materia}_{serie}', 
                    f'nivel_8_{materia}_{serie}']]
            
            data[f'nivel_9_{materia}_{serie}'] = np.nan
            data[f'nivel_10_{materia}_{serie}'] = np.nan 
        
        print(data.columns.values)
        # ? compatibilizando colunas do saeb inep com o saeb padronizado da bd
        data.rename(columns={f'media_{materia}_{serie}':'media',
                             f'nivel_0_{materia}_{serie}':'nivel_0', 
                             f'nivel_1_{materia}_{serie}':'nivel_1', 
                             f'nivel_2_{materia}_{serie}':'nivel_2',
                             f'nivel_3_{materia}_{serie}':'nivel_3',
                             f'nivel_4_{materia}_{serie}':'nivel_4', 
                             f'nivel_5_{materia}_{serie}':'nivel_5',
                             f'nivel_6_{materia}_{serie}':'nivel_6', 
                             f'nivel_7_{materia}_{serie}':'nivel_7', 
                             f'nivel_8_{materia}_{serie}':'nivel_8',
                             f'nivel_9_{materia}_{serie}':'nivel_9',
                             f'nivel_10_{materia}_{serie}':'nivel_10'},
                               inplace=True)

        # todo: cria variavel de disciplina
        data['disciplina'] = f'{materia}'
        data['disciplina'] = data['disciplina'].str.upper() 
        # todo: criar variavel de série (3 series: )
        data['serie'] = f'{serie}'    
                
            
        #depois é só juntar com append os saeb_mu_serie_discplina

        #trocar a serie em para 3  
        data['serie'].replace('em', '3', inplace=True) 
        data['serie'].replace('em_regular', '13', inplace=True) 
        data['serie'].replace('em_integral', '12', inplace=True) 
        
        #data.reset_index(inplace=True, drop=True)

        data2021.append(data)
        print(f'tabela {materia}__{serie} feita!')

# ! para finalizar, dar append na serie
#saeb_bq_br.reset_index(inplace=True, drop=True)

saeb_br = saeb_bq_br.append(data2021)

saeb_br.to_csv("br.csv",
                          index=False,
                          sep = ',',
                          na_rep= '',
                          encoding = 'utf-8')
