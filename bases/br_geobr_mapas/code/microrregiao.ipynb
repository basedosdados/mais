# %%
pip install geobr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geobr
#   Downloading geobr-0.1.10-py2.py3-none-any.whl (33 kB)
# Collecting geopandas<0.8.0,>=0.7.0
#   Downloading geopandas-0.7.0-py2.py3-none-any.whl (928 kB)
#      |████████████████████████████████| 928 kB 8.0 MB/s
# Requirement already satisfied: shapely<2.0.0,>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from geobr) (1.8.2)
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from geopandas<0.8.0,>=0.7.0->geobr) (1.3.5)
# Collecting fiona
#   Downloading Fiona-1.8.21-cp37-cp37m-manylinux2014_x86_64.whl (16.7 MB)
#      |████████████████████████████████| 16.7 MB 479 kB/s
# Collecting pyproj>=2.2.0
#   Downloading pyproj-3.2.1-cp37-cp37m-manylinux2010_x86_64.whl (6.3 MB)
#      |████████████████████████████████| 6.3 MB 43.9 MB/s
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.0->geopandas<0.8.0,>=0.7.0->geobr) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.0->geopandas<0.8.0,>=0.7.0->geobr) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23.0->geopandas<0.8.0,>=0.7.0->geobr) (2022.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from pyproj>=2.2.0->geopandas<0.8.0,>=0.7.0->geobr) (2022.6.15)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23.0->geopandas<0.8.0,>=0.7.0->geobr) (1.15.0)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona->geopandas<0.8.0,>=0.7.0->geobr) (7.1.2)
# Collecting cligj>=0.5
#   Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona->geopandas<0.8.0,>=0.7.0->geobr) (57.4.0)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona->geopandas<0.8.0,>=0.7.0->geobr) (21.4.0)
# Collecting click-plugins>=1.0
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Installing collected packages: munch, cligj, click-plugins, pyproj, fiona, geopandas, geobr
# Successfully installed click-plugins-1.1.1 cligj-0.7.2 fiona-1.8.21 geobr-0.1.10 geopandas-0.7.0 munch-2.5.0 pyproj-3.2.1

# %%
import geobr
import pandas as pd
import numpy as np

# %%
micro = geobr.read_micro_region(year=2020)
# Out:
# /usr/local/lib/python3.7/dist-packages/geopandas/array.py:93: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   aout[:] = out

# %%
micro
# Out:
#      code_state abbrev_state        name_state  code_micro        name_micro  \
# 0          11.0           RO          Rondônia     11001.0       Porto Velho
# 1          11.0           RO          Rondônia     11002.0     Guajará-Mirim
# 2          11.0           RO          Rondônia     11003.0         Ariquemes
# 3          11.0           RO          Rondônia     11004.0         Ji-Paraná
# 4          11.0           RO          Rondônia     11005.0  Alvorada D'oeste
# ..          ...          ...               ...         ...               ...
# 553        52.0           GO             Goiás     52015.0        Meia Ponte
# 554        52.0           GO             Goiás     52016.0      Pires Do Rio
# 555        52.0           GO             Goiás     52017.0           Catalão
# 556        52.0           GO             Goiás     52018.0      Quirinópolis
# 557        53.0           DF  Distrito Federal     53001.0          Brasília
#
#                                               geometry
# 0    MULTIPOLYGON (((-63.09956 -9.48078, -63.10231 ...
# 1    MULTIPOLYGON (((-64.59455 -12.21570, -64.60819...
# 2    MULTIPOLYGON (((-63.07681 -9.52497, -63.00059 ...
# 3    MULTIPOLYGON (((-62.66994 -10.28821, -62.61753...
# 4    MULTIPOLYGON (((-63.60484 -11.60206, -63.60307...
# ..                                                 ...
# 553  MULTIPOLYGON (((-49.82553 -17.58520, -49.82204...
# 554  MULTIPOLYGON (((-48.78747 -16.83600, -48.79014...
# 555  MULTIPOLYGON (((-47.40791 -18.14187, -47.41194...
# 556  MULTIPOLYGON (((-50.10789 -18.32532, -50.10621...
# 557  MULTIPOLYGON (((-47.41734 -15.54655, -47.41402...
#
# [558 rows x 6 columns]

# %%
micro['code_state'] = micro['code_state'].astype(np.int64)
micro['code_micro'] = micro['code_micro'].astype(np.int64)

# %%
micro
# Out:
#      code_state abbrev_state        name_state  code_micro        name_micro  \
# 0            11           RO          Rondônia       11001       Porto Velho
# 1            11           RO          Rondônia       11002     Guajará-Mirim
# 2            11           RO          Rondônia       11003         Ariquemes
# 3            11           RO          Rondônia       11004         Ji-Paraná
# 4            11           RO          Rondônia       11005  Alvorada D'oeste
# ..          ...          ...               ...         ...               ...
# 553          52           GO             Goiás       52015        Meia Ponte
# 554          52           GO             Goiás       52016      Pires Do Rio
# 555          52           GO             Goiás       52017           Catalão
# 556          52           GO             Goiás       52018      Quirinópolis
# 557          53           DF  Distrito Federal       53001          Brasília
#
#                                               geometry
# 0    MULTIPOLYGON (((-63.09956 -9.48078, -63.10231 ...
# 1    MULTIPOLYGON (((-64.59455 -12.21570, -64.60819...
# 2    MULTIPOLYGON (((-63.07681 -9.52497, -63.00059 ...
# 3    MULTIPOLYGON (((-62.66994 -10.28821, -62.61753...
# 4    MULTIPOLYGON (((-63.60484 -11.60206, -63.60307...
# ..                                                 ...
# 553  MULTIPOLYGON (((-49.82553 -17.58520, -49.82204...
# 554  MULTIPOLYGON (((-48.78747 -16.83600, -48.79014...
# 555  MULTIPOLYGON (((-47.40791 -18.14187, -47.41194...
# 556  MULTIPOLYGON (((-50.10789 -18.32532, -50.10621...
# 557  MULTIPOLYGON (((-47.41734 -15.54655, -47.41402...
#
# [558 rows x 6 columns]

# %%
micro=micro.rename({'code_state':'id_uf', 'abbrev_state':'sigla_uf', 'code_micro':'id_microrregiao','geometry':'geometria', 'name_micro': 'nome_microrregiao'},axis='columns')

# %%
micro=micro.filter(items=['id_uf', 'sigla_uf', 'id_microrregiao', 'nome_microrregiao', 'geometria'])

# %%
micro
# Out:
#      id_uf sigla_uf  id_microrregiao nome_microrregiao  \
# 0       11       RO            11001       Porto Velho
# 1       11       RO            11002     Guajará-Mirim
# 2       11       RO            11003         Ariquemes
# 3       11       RO            11004         Ji-Paraná
# 4       11       RO            11005  Alvorada D'oeste
# ..     ...      ...              ...               ...
# 553     52       GO            52015        Meia Ponte
# 554     52       GO            52016      Pires Do Rio
# 555     52       GO            52017           Catalão
# 556     52       GO            52018      Quirinópolis
# 557     53       DF            53001          Brasília
#
#                                              geometria
# 0    MULTIPOLYGON (((-63.09956 -9.48078, -63.10231 ...
# 1    MULTIPOLYGON (((-64.59455 -12.21570, -64.60819...
# 2    MULTIPOLYGON (((-63.07681 -9.52497, -63.00059 ...
# 3    MULTIPOLYGON (((-62.66994 -10.28821, -62.61753...
# 4    MULTIPOLYGON (((-63.60484 -11.60206, -63.60307...
# ..                                                 ...
# 553  MULTIPOLYGON (((-49.82553 -17.58520, -49.82204...
# 554  MULTIPOLYGON (((-48.78747 -16.83600, -48.79014...
# 555  MULTIPOLYGON (((-47.40791 -18.14187, -47.41194...
# 556  MULTIPOLYGON (((-50.10789 -18.32532, -50.10621...
# 557  MULTIPOLYGON (((-47.41734 -15.54655, -47.41402...
#
# [558 rows x 5 columns]

# %%
from posixpath import sep

# %%
micro.to_csv('microrregiao.csv', sep=',', index=False, header=True)

# %%
vars(micro)
# Out:
# {'_attrs': {},
#  '_crs': None,
#  '_flags': <Flags(allows_duplicate_labels=True)>,
#  '_geometry_column_name': 'geometry',
#  '_is_copy': None,
#  '_item_cache': {},
#  '_mgr': BlockManager
#  Items: Index(['id_uf', 'sigla_uf', 'id_microrregiao', 'nome_microrregiao',
#         'geometria'],
#        dtype='object')
#  Axis 1: RangeIndex(start=0, stop=558, step=1)
#  NumericBlock: slice(0, 4, 2), 2 x 558, dtype: int64
#  ObjectBlock: slice(1, 5, 2), 2 x 558, dtype: object
#  ExtensionBlock: slice(4, 5, 1), 1 x 558, dtype: geometry,
#  '_sindex': None,
#  '_sindex_generated': False}
