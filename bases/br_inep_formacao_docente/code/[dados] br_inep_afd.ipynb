# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import os
import zipfile
from zipfile import ZipFile

# %%
geo = ['BRASIL', 'REGIOES', 'UFS', 'BRASIL_REGIOES_UFS', 'MUNICIPIOS', 'ESCOLAS']

anos = [2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %%
#escolas
rename_e= {'Ano':'ano', 'Unnamed: 1':'regiao', 'no_cod':'regiao', 'SIGLA':'sigla_uf', 'PK_COD_MUNICIPIO':'id_municipio', 'PK_COD_ENTIDADE':'id_escola', 
         'TIPOLOCA':'tipo_localizacao', 'Dependad':'rede', 'AFD_INF1':'educacao_infantil_grupo_1', 'AFD_INF2':'educacao_infantil_grupo_2',
         'AFD_INF3':'educacao_infantil_grupo_3', 'AFD_INF4':'educacao_infantil_grupo_4', 'AFD_INF5':'educacao_infantil_grupo_5',
         'AFD_FUN1':'ensino_fundamental_total_grupo_1', 'AFD_FUN2':'ensino_fundamental_total_grupo_2', 'AFD_FUN3':'ensino_fundamental_total_grupo_3',
         'AFD_FUN4':'ensino_fundamental_total_grupo_4', 'AFD_FUN5':'ensino_fundamental_total_grupo_5', 'AFD_F141':'ensino_fundamental_anos_iniciais_grupo_1', 
         'AFD_F142':'ensino_fundamental_anos_iniciais_grupo_2',  'AFD_F143':'ensino_fundamental_anos_iniciais_grupo_3',
         'AFD_F144':'ensino_fundamental_anos_iniciais_grupo_4', 'AFD_F145':'ensino_fundamental_anos_iniciais_grupo_5', 
         'AFD_F581':'ensino_fundamental_anos_finais_grupo_1', 'AFD_F582':'ensino_fundamental_anos_finais_grupo_2', 
         'AFD_F583':'ensino_fundamental_anos_finais_grupo_3', 'AFD_F584':'ensino_fundamental_anos_finais_grupo_4',
         'AFD_F585':'ensino_fundamental_anos_finais_grupo_5', 'AFD_MED1':'ensino_medio_total_grupo_1', 'AFD_MED2':'ensino_medio_total_grupo_2',
         'AFD_MED3':'ensino_medio_total_grupo_3', 'AFD_MED4':'ensino_medio_total_grupo_4', 'AFD_MED5':'ensino_medio_total_grupo_5', 
         'AFD_EJAF1':'eja_ensino_fundamental_grupo_1', 'AFD_EJAF2':'eja_ensino_fundamental_grupo_2', 'AFD_EJAF3':'eja_ensino_fundamental_grupo_3',
         'AFD_EJAF4':'eja_ensino_fundamental_grupo_4', 'AFD_EJAF5':'eja_ensino_fundamental_grupo_5', 'AFD_EJAM1':'eja_ensino_medio_grupo_1',
         'AFD_EJAM2':'eja_ensino_medio_grupo_2', 'AFD_EJAM3':'eja_ensino_medio_grupo_3', 'AFD_EJAM4':'eja_ensino_medio_grupo_4', 
         'AFD_EJAM5':'eja_ensino_medio_grupo_5',
#2019
         'NU_ANO_CENSO':'ano', 'NO_REGIAO':'regiao', 'SG_UF':'sigla_uf', 'CO_MUNICIPIO':'id_municipio', 'CO_ENTIDADE':'id_escola', 
         'NO_CATEGORIA':'tipo_localizacao', 'NO_DEPENDENCIA':'rede', 'ED_INF_CAT_1':'educacao_infantil_grupo_1', 'ED_INF_CAT_2':'educacao_infantil_grupo_2',
         'ED_INF_CAT_3':'educacao_infantil_grupo_3', 'ED_INF_CAT_4':'educacao_infantil_grupo_4', 'ED_INF_CAT_5':'educacao_infantil_grupo_5',
         'FUN_CAT_1':'ensino_fundamental_total_grupo_1', 'FUN_CAT_2':'ensino_fundamental_total_grupo_2', 'FUN_CAT_3':'ensino_fundamental_total_grupo_3',
         'FUN_CAT_4':'ensino_fundamental_total_grupo_4', 'FUN_CAT_5':'ensino_fundamental_total_grupo_5', 'FUN_AI_CAT_1':'ensino_fundamental_anos_iniciais_grupo_1', 
         'FUN_AI_CAT_2':'ensino_fundamental_anos_iniciais_grupo_2',  'FUN_AI_CAT_3':'ensino_fundamental_anos_iniciais_grupo_3',
         'FUN_AI_CAT_4':'ensino_fundamental_anos_iniciais_grupo_4', 'FUN_AI_CAT_5':'ensino_fundamental_anos_iniciais_grupo_5', 
         'FUN_AF_CAT_1':'ensino_fundamental_anos_finais_grupo_1', 'FUN_AF_CAT_2':'ensino_fundamental_anos_finais_grupo_2', 
         'FUN_AF_CAT_3':'ensino_fundamental_anos_finais_grupo_3', 'FUN_AF_CAT_4':'ensino_fundamental_anos_finais_grupo_4',
         'FUN_AF_CAT_5':'ensino_fundamental_anos_finais_grupo_5', 'MED_CAT_1':'ensino_medio_total_grupo_1', 'MED_CAT_2':'ensino_medio_total_grupo_2',
         'MED_CAT_3':'ensino_medio_total_grupo_3', 'MED_CAT_4':'ensino_medio_total_grupo_4', 'MED_CAT_5':'ensino_medio_total_grupo_5', 
         'EJA_FUN_CAT_1':'eja_ensino_fundamental_grupo_1', 'EJA_FUN_CAT_2':'eja_ensino_fundamental_grupo_2', 'EJA_FUN_CAT_3':'eja_ensino_fundamental_grupo_3',
         'EJA_FUN_CAT_4':'eja_ensino_fundamental_grupo_4', 'EJA_FUN_CAT_5':'eja_ensino_fundamental_grupo_5', 'EJA_MED_CAT_1':'eja_ensino_medio_grupo_1',
         'EJA_MED_CAT_2':'eja_ensino_medio_grupo_2', 'EJA_MED_CAT_3':'eja_ensino_medio_grupo_3', 'EJA_MED_CAT_4':'eja_ensino_medio_grupo_4', 
         'EJA_MED_CAT_5':'eja_ensino_medio_grupo_5'}

ordem_e = ['ano', 'regiao', 'sigla_uf', 'id_municipio', 'id_escola', 'tipo_localizacao', 'rede', 'educacao_infantil_grupo_1', 'educacao_infantil_grupo_2',
          'educacao_infantil_grupo_3', 'educacao_infantil_grupo_4', 'educacao_infantil_grupo_5', 'ensino_fundamental_total_grupo_1', 
          'ensino_fundamental_total_grupo_2', 'ensino_fundamental_total_grupo_3', 'ensino_fundamental_total_grupo_4', 'ensino_fundamental_total_grupo_5', 
          'ensino_fundamental_anos_iniciais_grupo_1', 'ensino_fundamental_anos_iniciais_grupo_2', 'ensino_fundamental_anos_iniciais_grupo_3',
          'ensino_fundamental_anos_iniciais_grupo_4', 'ensino_fundamental_anos_iniciais_grupo_5', 'ensino_fundamental_anos_finais_grupo_1', 
          'ensino_fundamental_anos_finais_grupo_2', 'ensino_fundamental_anos_finais_grupo_3', 'ensino_fundamental_anos_finais_grupo_4',
          'ensino_fundamental_anos_finais_grupo_5', 'ensino_medio_total_grupo_1', 'ensino_medio_total_grupo_2', 'ensino_medio_total_grupo_3', 
          'ensino_medio_total_grupo_4', 'ensino_medio_total_grupo_5', 'eja_ensino_fundamental_grupo_1', 'eja_ensino_fundamental_grupo_2', 
          'eja_ensino_fundamental_grupo_3', 'eja_ensino_fundamental_grupo_4', 'eja_ensino_fundamental_grupo_5', 'eja_ensino_medio_grupo_1',
          'eja_ensino_medio_grupo_2', 'eja_ensino_medio_grupo_3', 'eja_ensino_medio_grupo_4', 'eja_ensino_medio_grupo_5']

#municipio
rename_m= {'Unnamed: 1':'regiao', 'no_cod':'regiao', 'sigla':'sigla_uf', 'pk_cod_municipio':'id_municipio',  
         'TIPOLOCA':'tipo_localizacao', 'Dependad':'rede', 'AFD_INF1':'educacao_infantil_grupo_1', 'AFD_INF2':'educacao_infantil_grupo_2',
         'AFD_INF3':'educacao_infantil_grupo_3', 'AFD_INF4':'educacao_infantil_grupo_4', 'AFD_INF5':'educacao_infantil_grupo_5',
         'AFD_FUN1':'ensino_fundamental_total_grupo_1', 'AFD_FUN2':'ensino_fundamental_total_grupo_2', 'AFD_FUN3':'ensino_fundamental_total_grupo_3',
         'AFD_FUN4':'ensino_fundamental_total_grupo_4', 'AFD_FUN5':'ensino_fundamental_total_grupo_5', 'AFD_F141':'ensino_fundamental_anos_iniciais_grupo_1', 
         'AFD_F142':'ensino_fundamental_anos_iniciais_grupo_2',  'AFD_F143':'ensino_fundamental_anos_iniciais_grupo_3',
         'AFD_F144':'ensino_fundamental_anos_iniciais_grupo_4', 'AFD_F145':'ensino_fundamental_anos_iniciais_grupo_5', 
         'AFD_F581':'ensino_fundamental_anos_finais_grupo_1', 'AFD_F582':'ensino_fundamental_anos_finais_grupo_2', 
         'AFD_F583':'ensino_fundamental_anos_finais_grupo_3', 'AFD_F584':'ensino_fundamental_anos_finais_grupo_4',
         'AFD_F585':'ensino_fundamental_anos_finais_grupo_5', 'AFD_MED1':'ensino_medio_total_grupo_1', 'AFD_MED2':'ensino_medio_total_grupo_2',
         'AFD_MED3':'ensino_medio_total_grupo_3', 'AFD_MED4':'ensino_medio_total_grupo_4', 'AFD_MED5':'ensino_medio_total_grupo_5', 
         'AFD_EJAF1':'eja_ensino_fundamental_grupo_1', 'AFD_EJAF2':'eja_ensino_fundamental_grupo_2', 'AFD_EJAF3':'eja_ensino_fundamental_grupo_3',
         'AFD_EJAF4':'eja_ensino_fundamental_grupo_4', 'AFD_EJAF5':'eja_ensino_fundamental_grupo_5', 'AFD_EJAM1':'eja_ensino_medio_grupo_1',
         'AFD_EJAM2':'eja_ensino_medio_grupo_2', 'AFD_EJAM3':'eja_ensino_medio_grupo_3', 'AFD_EJAM4':'eja_ensino_medio_grupo_4', 
         'AFD_EJAM5':'eja_ensino_medio_grupo_5',
#2019
         'NU_ANO_CENSO':'ano', 'NO_REGIAO':'regiao', 'SG_UF':'sigla_uf', 'CO_MUNICIPIO':'id_municipio', 'NO_CATEGORIA':'tipo_localizacao', 
         'NO_DEPENDENCIA':'rede', 'ED_INF_CAT_1':'educacao_infantil_grupo_1', 'ED_INF_CAT_2':'educacao_infantil_grupo_2',
         'ED_INF_CAT_3':'educacao_infantil_grupo_3', 'ED_INF_CAT_4':'educacao_infantil_grupo_4', 'ED_INF_CAT_5':'educacao_infantil_grupo_5',
         'FUN_CAT_1':'ensino_fundamental_total_grupo_1', 'FUN_CAT_2':'ensino_fundamental_total_grupo_2', 'FUN_CAT_3':'ensino_fundamental_total_grupo_3',
         'FUN_CAT_4':'ensino_fundamental_total_grupo_4', 'FUN_CAT_5':'ensino_fundamental_total_grupo_5', 'FUN_AI_CAT_1':'ensino_fundamental_anos_iniciais_grupo_1', 
         'FUN_AI_CAT_2':'ensino_fundamental_anos_iniciais_grupo_2',  'FUN_AI_CAT_3':'ensino_fundamental_anos_iniciais_grupo_3',
         'FUN_AI_CAT_4':'ensino_fundamental_anos_iniciais_grupo_4', 'FUN_AI_CAT_5':'ensino_fundamental_anos_iniciais_grupo_5', 
         'FUN_AF_CAT_1':'ensino_fundamental_anos_finais_grupo_1', 'FUN_AF_CAT_2':'ensino_fundamental_anos_finais_grupo_2', 
         'FUN_AF_CAT_3':'ensino_fundamental_anos_finais_grupo_3', 'FUN_AF_CAT_4':'ensino_fundamental_anos_finais_grupo_4',
         'FUN_AF_CAT_5':'ensino_fundamental_anos_finais_grupo_5', 'MED_CAT_1':'ensino_medio_total_grupo_1', 'MED_CAT_2':'ensino_medio_total_grupo_2',
         'MED_CAT_3':'ensino_medio_total_grupo_3', 'MED_CAT_4':'ensino_medio_total_grupo_4', 'MED_CAT_5':'ensino_medio_total_grupo_5', 
         'EJA_FUN_CAT_1':'eja_ensino_fundamental_grupo_1', 'EJA_FUN_CAT_2':'eja_ensino_fundamental_grupo_2', 'EJA_FUN_CAT_3':'eja_ensino_fundamental_grupo_3',
         'EJA_FUN_CAT_4':'eja_ensino_fundamental_grupo_4', 'EJA_FUN_CAT_5':'eja_ensino_fundamental_grupo_5', 'EJA_MED_CAT_1':'eja_ensino_medio_grupo_1',
         'EJA_MED_CAT_2':'eja_ensino_medio_grupo_2', 'EJA_MED_CAT_3':'eja_ensino_medio_grupo_3', 'EJA_MED_CAT_4':'eja_ensino_medio_grupo_4', 
         'EJA_MED_CAT_5':'eja_ensino_medio_grupo_5'}

ordem_m = ['ano', 'regiao', 'sigla_uf', 'id_municipio', 'tipo_localizacao', 'rede', 'educacao_infantil_grupo_1', 'educacao_infantil_grupo_2',
          'educacao_infantil_grupo_3', 'educacao_infantil_grupo_4', 'educacao_infantil_grupo_5', 'ensino_fundamental_total_grupo_1', 
          'ensino_fundamental_total_grupo_2', 'ensino_fundamental_total_grupo_3', 'ensino_fundamental_total_grupo_4', 'ensino_fundamental_total_grupo_5', 
          'ensino_fundamental_anos_iniciais_grupo_1', 'ensino_fundamental_anos_iniciais_grupo_2', 'ensino_fundamental_anos_iniciais_grupo_3',
          'ensino_fundamental_anos_iniciais_grupo_4', 'ensino_fundamental_anos_iniciais_grupo_5', 'ensino_fundamental_anos_finais_grupo_1', 
          'ensino_fundamental_anos_finais_grupo_2', 'ensino_fundamental_anos_finais_grupo_3', 'ensino_fundamental_anos_finais_grupo_4',
          'ensino_fundamental_anos_finais_grupo_5', 'ensino_medio_total_grupo_1', 'ensino_medio_total_grupo_2', 'ensino_medio_total_grupo_3', 
          'ensino_medio_total_grupo_4', 'ensino_medio_total_grupo_5', 'eja_ensino_fundamental_grupo_1', 'eja_ensino_fundamental_grupo_2', 
          'eja_ensino_fundamental_grupo_3', 'eja_ensino_fundamental_grupo_4', 'eja_ensino_fundamental_grupo_5', 'eja_ensino_medio_grupo_1',
          'eja_ensino_medio_grupo_2', 'eja_ensino_medio_grupo_3', 'eja_ensino_medio_grupo_4', 'eja_ensino_medio_grupo_5']

#uf
rename_uf= {'TIPOLOCA':'tipo_localizacao', 'Dependad':'rede', 'AFD_INF1':'educacao_infantil_grupo_1', 'AFD_INF2':'educacao_infantil_grupo_2',
         'AFD_INF3':'educacao_infantil_grupo_3', 'AFD_INF4':'educacao_infantil_grupo_4', 'AFD_INF5':'educacao_infantil_grupo_5',
         'AFD_FUN1':'ensino_fundamental_total_grupo_1', 'AFD_FUN2':'ensino_fundamental_total_grupo_2', 'AFD_FUN3':'ensino_fundamental_total_grupo_3',
         'AFD_FUN4':'ensino_fundamental_total_grupo_4', 'AFD_FUN5':'ensino_fundamental_total_grupo_5', 'AFD_F141':'ensino_fundamental_anos_iniciais_grupo_1', 
         'AFD_F142':'ensino_fundamental_anos_iniciais_grupo_2',  'AFD_F143':'ensino_fundamental_anos_iniciais_grupo_3',
         'AFD_F144':'ensino_fundamental_anos_iniciais_grupo_4', 'AFD_F145':'ensino_fundamental_anos_iniciais_grupo_5', 
         'AFD_F581':'ensino_fundamental_anos_finais_grupo_1', 'AFD_F582':'ensino_fundamental_anos_finais_grupo_2', 
         'AFD_F583':'ensino_fundamental_anos_finais_grupo_3', 'AFD_F584':'ensino_fundamental_anos_finais_grupo_4',
         'AFD_F585':'ensino_fundamental_anos_finais_grupo_5', 'AFD_MED1':'ensino_medio_total_grupo_1', 'AFD_MED2':'ensino_medio_total_grupo_2',
         'AFD_MED3':'ensino_medio_total_grupo_3', 'AFD_MED4':'ensino_medio_total_grupo_4', 'AFD_MED5':'ensino_medio_total_grupo_5', 
         'AFD_EJAF1':'eja_ensino_fundamental_grupo_1', 'AFD_EJAF2':'eja_ensino_fundamental_grupo_2', 'AFD_EJAF3':'eja_ensino_fundamental_grupo_3',
         'AFD_EJAF4':'eja_ensino_fundamental_grupo_4', 'AFD_EJAF5':'eja_ensino_fundamental_grupo_5', 'AFD_EJAM1':'eja_ensino_medio_grupo_1',
         'AFD_EJAM2':'eja_ensino_medio_grupo_2', 'AFD_EJAM3':'eja_ensino_medio_grupo_3', 'AFD_EJAM4':'eja_ensino_medio_grupo_4', 
         'AFD_EJAM5':'eja_ensino_medio_grupo_5',
#2019
         'NU_ANO_CENSO':'ano', 'UNIDGEO':'nome_uf', 'NO_CATEGORIA':'tipo_localizacao', 
         'NO_DEPENDENCIA':'rede', 'ED_INF_CAT_1':'educacao_infantil_grupo_1', 'ED_INF_CAT_2':'educacao_infantil_grupo_2',
         'ED_INF_CAT_3':'educacao_infantil_grupo_3', 'ED_INF_CAT_4':'educacao_infantil_grupo_4', 'ED_INF_CAT_5':'educacao_infantil_grupo_5',
         'FUN_CAT_1':'ensino_fundamental_total_grupo_1', 'FUN_CAT_2':'ensino_fundamental_total_grupo_2', 'FUN_CAT_3':'ensino_fundamental_total_grupo_3',
         'FUN_CAT_4':'ensino_fundamental_total_grupo_4', 'FUN_CAT_5':'ensino_fundamental_total_grupo_5', 'FUN_AI_CAT_1':'ensino_fundamental_anos_iniciais_grupo_1', 
         'FUN_AI_CAT_2':'ensino_fundamental_anos_iniciais_grupo_2',  'FUN_AI_CAT_3':'ensino_fundamental_anos_iniciais_grupo_3',
         'FUN_AI_CAT_4':'ensino_fundamental_anos_iniciais_grupo_4', 'FUN_AI_CAT_5':'ensino_fundamental_anos_iniciais_grupo_5', 
         'FUN_AF_CAT_1':'ensino_fundamental_anos_finais_grupo_1', 'FUN_AF_CAT_2':'ensino_fundamental_anos_finais_grupo_2', 
         'FUN_AF_CAT_3':'ensino_fundamental_anos_finais_grupo_3', 'FUN_AF_CAT_4':'ensino_fundamental_anos_finais_grupo_4',
         'FUN_AF_CAT_5':'ensino_fundamental_anos_finais_grupo_5', 'MED_CAT_1':'ensino_medio_total_grupo_1', 'MED_CAT_2':'ensino_medio_total_grupo_2',
         'MED_CAT_3':'ensino_medio_total_grupo_3', 'MED_CAT_4':'ensino_medio_total_grupo_4', 'MED_CAT_5':'ensino_medio_total_grupo_5', 
         'EJA_FUN_CAT_1':'eja_ensino_fundamental_grupo_1', 'EJA_FUN_CAT_2':'eja_ensino_fundamental_grupo_2', 'EJA_FUN_CAT_3':'eja_ensino_fundamental_grupo_3',
         'EJA_FUN_CAT_4':'eja_ensino_fundamental_grupo_4', 'EJA_FUN_CAT_5':'eja_ensino_fundamental_grupo_5', 'EJA_MED_CAT_1':'eja_ensino_medio_grupo_1',
         'EJA_MED_CAT_2':'eja_ensino_medio_grupo_2', 'EJA_MED_CAT_3':'eja_ensino_medio_grupo_3', 'EJA_MED_CAT_4':'eja_ensino_medio_grupo_4', 
         'EJA_MED_CAT_5':'eja_ensino_medio_grupo_5'}

ordem_uf = ['ano', 'regiao', 'sigla_uf', 'tipo_localizacao', 'rede', 'educacao_infantil_grupo_1', 'educacao_infantil_grupo_2',
          'educacao_infantil_grupo_3', 'educacao_infantil_grupo_4', 'educacao_infantil_grupo_5', 'ensino_fundamental_total_grupo_1', 
          'ensino_fundamental_total_grupo_2', 'ensino_fundamental_total_grupo_3', 'ensino_fundamental_total_grupo_4', 'ensino_fundamental_total_grupo_5', 
          'ensino_fundamental_anos_iniciais_grupo_1', 'ensino_fundamental_anos_iniciais_grupo_2', 'ensino_fundamental_anos_iniciais_grupo_3',
          'ensino_fundamental_anos_iniciais_grupo_4', 'ensino_fundamental_anos_iniciais_grupo_5', 'ensino_fundamental_anos_finais_grupo_1', 
          'ensino_fundamental_anos_finais_grupo_2', 'ensino_fundamental_anos_finais_grupo_3', 'ensino_fundamental_anos_finais_grupo_4',
          'ensino_fundamental_anos_finais_grupo_5', 'ensino_medio_total_grupo_1', 'ensino_medio_total_grupo_2', 'ensino_medio_total_grupo_3', 
          'ensino_medio_total_grupo_4', 'ensino_medio_total_grupo_5', 'eja_ensino_fundamental_grupo_1', 'eja_ensino_fundamental_grupo_2', 
          'eja_ensino_fundamental_grupo_3', 'eja_ensino_fundamental_grupo_4', 'eja_ensino_fundamental_grupo_5', 'eja_ensino_medio_grupo_1',
          'eja_ensino_medio_grupo_2', 'eja_ensino_medio_grupo_3', 'eja_ensino_medio_grupo_4', 'eja_ensino_medio_grupo_5']

#brasil e regioes
rename_br= {'no_cod':'regiao', 'TIPOLOCA':'tipo_localizacao', 'Dependad':'rede', 'AFD_INF1':'educacao_infantil_grupo_1', 'AFD_INF2':'educacao_infantil_grupo_2',
         'AFD_INF3':'educacao_infantil_grupo_3', 'AFD_INF4':'educacao_infantil_grupo_4', 'AFD_INF5':'educacao_infantil_grupo_5',
         'AFD_FUN1':'ensino_fundamental_total_grupo_1', 'AFD_FUN2':'ensino_fundamental_total_grupo_2', 'AFD_FUN3':'ensino_fundamental_total_grupo_3',
         'AFD_FUN4':'ensino_fundamental_total_grupo_4', 'AFD_FUN5':'ensino_fundamental_total_grupo_5', 'AFD_F141':'ensino_fundamental_anos_iniciais_grupo_1', 
         'AFD_F142':'ensino_fundamental_anos_iniciais_grupo_2',  'AFD_F143':'ensino_fundamental_anos_iniciais_grupo_3',
         'AFD_F144':'ensino_fundamental_anos_iniciais_grupo_4', 'AFD_F145':'ensino_fundamental_anos_iniciais_grupo_5', 
         'AFD_F581':'ensino_fundamental_anos_finais_grupo_1', 'AFD_F582':'ensino_fundamental_anos_finais_grupo_2', 
         'AFD_F583':'ensino_fundamental_anos_finais_grupo_3', 'AFD_F584':'ensino_fundamental_anos_finais_grupo_4',
         'AFD_F585':'ensino_fundamental_anos_finais_grupo_5', 'AFD_MED1':'ensino_medio_total_grupo_1', 'AFD_MED2':'ensino_medio_total_grupo_2',
         'AFD_MED3':'ensino_medio_total_grupo_3', 'AFD_MED4':'ensino_medio_total_grupo_4', 'AFD_MED5':'ensino_medio_total_grupo_5', 
         'AFD_EJAF1':'eja_ensino_fundamental_grupo_1', 'AFD_EJAF2':'eja_ensino_fundamental_grupo_2', 'AFD_EJAF3':'eja_ensino_fundamental_grupo_3',
         'AFD_EJAF4':'eja_ensino_fundamental_grupo_4', 'AFD_EJAF5':'eja_ensino_fundamental_grupo_5', 'AFD_EJAM1':'eja_ensino_medio_grupo_1',
         'AFD_EJAM2':'eja_ensino_medio_grupo_2', 'AFD_EJAM3':'eja_ensino_medio_grupo_3', 'AFD_EJAM4':'eja_ensino_medio_grupo_4', 
         'AFD_EJAM5':'eja_ensino_medio_grupo_5',
#2019
         'NU_ANO_CENSO':'ano', 'UNIDGEO':'regiao', 'NO_CATEGORIA':'tipo_localizacao', 
         'NO_DEPENDENCIA':'rede', 'ED_INF_CAT_1':'educacao_infantil_grupo_1', 'ED_INF_CAT_2':'educacao_infantil_grupo_2',
         'ED_INF_CAT_3':'educacao_infantil_grupo_3', 'ED_INF_CAT_4':'educacao_infantil_grupo_4', 'ED_INF_CAT_5':'educacao_infantil_grupo_5',
         'FUN_CAT_1':'ensino_fundamental_total_grupo_1', 'FUN_CAT_2':'ensino_fundamental_total_grupo_2', 'FUN_CAT_3':'ensino_fundamental_total_grupo_3',
         'FUN_CAT_4':'ensino_fundamental_total_grupo_4', 'FUN_CAT_5':'ensino_fundamental_total_grupo_5', 'FUN_AI_CAT_1':'ensino_fundamental_anos_iniciais_grupo_1', 
         'FUN_AI_CAT_2':'ensino_fundamental_anos_iniciais_grupo_2',  'FUN_AI_CAT_3':'ensino_fundamental_anos_iniciais_grupo_3',
         'FUN_AI_CAT_4':'ensino_fundamental_anos_iniciais_grupo_4', 'FUN_AI_CAT_5':'ensino_fundamental_anos_iniciais_grupo_5', 
         'FUN_AF_CAT_1':'ensino_fundamental_anos_finais_grupo_1', 'FUN_AF_CAT_2':'ensino_fundamental_anos_finais_grupo_2', 
         'FUN_AF_CAT_3':'ensino_fundamental_anos_finais_grupo_3', 'FUN_AF_CAT_4':'ensino_fundamental_anos_finais_grupo_4',
         'FUN_AF_CAT_5':'ensino_fundamental_anos_finais_grupo_5', 'MED_CAT_1':'ensino_medio_total_grupo_1', 'MED_CAT_2':'ensino_medio_total_grupo_2',
         'MED_CAT_3':'ensino_medio_total_grupo_3', 'MED_CAT_4':'ensino_medio_total_grupo_4', 'MED_CAT_5':'ensino_medio_total_grupo_5', 
         'EJA_FUN_CAT_1':'eja_ensino_fundamental_grupo_1', 'EJA_FUN_CAT_2':'eja_ensino_fundamental_grupo_2', 'EJA_FUN_CAT_3':'eja_ensino_fundamental_grupo_3',
         'EJA_FUN_CAT_4':'eja_ensino_fundamental_grupo_4', 'EJA_FUN_CAT_5':'eja_ensino_fundamental_grupo_5', 'EJA_MED_CAT_1':'eja_ensino_medio_grupo_1',
         'EJA_MED_CAT_2':'eja_ensino_medio_grupo_2', 'EJA_MED_CAT_3':'eja_ensino_medio_grupo_3', 'EJA_MED_CAT_4':'eja_ensino_medio_grupo_4', 
         'EJA_MED_CAT_5':'eja_ensino_medio_grupo_5'}

ordem_br = ['ano', 'regiao', 'tipo_localizacao', 'rede', 'educacao_infantil_grupo_1', 'educacao_infantil_grupo_2',
          'educacao_infantil_grupo_3', 'educacao_infantil_grupo_4', 'educacao_infantil_grupo_5', 'ensino_fundamental_total_grupo_1', 
          'ensino_fundamental_total_grupo_2', 'ensino_fundamental_total_grupo_3', 'ensino_fundamental_total_grupo_4', 'ensino_fundamental_total_grupo_5', 
          'ensino_fundamental_anos_iniciais_grupo_1', 'ensino_fundamental_anos_iniciais_grupo_2', 'ensino_fundamental_anos_iniciais_grupo_3',
          'ensino_fundamental_anos_iniciais_grupo_4', 'ensino_fundamental_anos_iniciais_grupo_5', 'ensino_fundamental_anos_finais_grupo_1', 
          'ensino_fundamental_anos_finais_grupo_2', 'ensino_fundamental_anos_finais_grupo_3', 'ensino_fundamental_anos_finais_grupo_4',
          'ensino_fundamental_anos_finais_grupo_5', 'ensino_medio_total_grupo_1', 'ensino_medio_total_grupo_2', 'ensino_medio_total_grupo_3', 
          'ensino_medio_total_grupo_4', 'ensino_medio_total_grupo_5', 'eja_ensino_fundamental_grupo_1', 'eja_ensino_fundamental_grupo_2', 
          'eja_ensino_fundamental_grupo_3', 'eja_ensino_fundamental_grupo_4', 'eja_ensino_fundamental_grupo_5', 'eja_ensino_medio_grupo_1',
          'eja_ensino_medio_grupo_2', 'eja_ensino_medio_grupo_3', 'eja_ensino_medio_grupo_4', 'eja_ensino_medio_grupo_5']

# %%
id_uf = pd.read_csv('/content/id_uf (1).csv')

# %%
for g in geo:
  for a in anos:
    if g == 'ESCOLAS':
      exec("df = pd.read_excel('/content/drive/MyDrive/br_inep_afd/input/AFD_{}_{}.xlsx', skiprows=10, skipfooter=5, dtype='string')".format(g, str(a)))
      df.rename(columns=rename_e, inplace=True)
      df.dropna(subset=['ano'], inplace=True)
      df['regiao'] = df['regiao'].apply(lambda x: str(x).replace('Centro_Oeste','Centro-Oeste'))
      df['rede'] = df['rede'].str.lower()
      df['tipo_localizacao'] = df['tipo_localizacao'].str.lower()
      df = df[ordem_e]
      id_var = ['ano', 'regiao', 'sigla_uf', 'id_municipio', 'id_escola', 'tipo_localizacao', 'rede']
      value_var = df.drop(columns=id_var, axis=1).columns
      df = pd.melt(df, id_vars=id_var, value_vars=value_var, var_name='modalidade_grupo', value_name='percentual')
      df = df.applymap(lambda x: np.nan if x == '--' else x).dropna(subset=['percentual'])
      df['modalidade'] = df['modalidade_grupo'].str[:-8]
      df['modalidade'] = df['modalidade'].apply(lambda x: str(x).replace('_',' '))
      df['grupo'] = df['modalidade_grupo'].str[-1:]
      df = df[['regiao', 'sigla_uf', 'id_municipio', 'id_escola', 'tipo_localizacao', 'rede', 'modalidade', 'grupo', 'percentual']]
      df.sort_values(['id_escola', 'modalidade'], inplace=True)
      exec('df.to_csv("/content/drive/MyDrive/br_inep_afd/output/afd_escola_{}.csv", index=False, na_rep="")'.format(a))
      print('AFD Escola {} pronto'.format(a))
      del df

    if g == 'MUNICIPIOS':
      exec("df = pd.read_excel('/content/drive/MyDrive/br_inep_afd/input/AFD_{}_{}.xlsx', skiprows=10, skipfooter=5, dtype='string')".format(g, str(a)))
      df.rename(columns=rename_m, inplace=True)
      df.dropna(subset=['ano'], inplace=True)
      df['regiao'] = df['regiao'].apply(lambda x: str(x).replace('Centro_Oeste','Centro-Oeste'))
      df['rede'] = df['rede'].str.lower()
      df['tipo_localizacao'] = df['tipo_localizacao'].str.lower()
      df = df[ordem_m]
      id_var = ['ano', 'regiao', 'sigla_uf', 'id_municipio', 'tipo_localizacao', 'rede']
      value_var = df.drop(columns=id_var, axis=1).columns
      df = pd.melt(df, id_vars=id_var, value_vars=value_var, var_name='modalidade_grupo', value_name='percentual')
      df = df.applymap(lambda x: np.nan if x == '--' else x).dropna(subset=['percentual'])
      df['modalidade'] = df['modalidade_grupo'].str[:-8]
      df['modalidade'] = df['modalidade'].apply(lambda x: str(x).replace('_',' '))
      df['grupo'] = df['modalidade_grupo'].str[-1:]
      df = df[['regiao', 'sigla_uf', 'id_municipio', 'tipo_localizacao', 'rede', 'modalidade', 'grupo', 'percentual']]
      df.sort_values(['id_municipio', 'modalidade'], inplace=True)
      exec('df.to_csv("/content/drive/MyDrive/br_inep_afd/output/afd_municipio_{}.csv", index=False, na_rep="", encoding="utf-8")'.format(a))
      print('AFD Município {} pronto'.format(a))
      del df

    if g == 'UFS' and a <= 2016 or g == 'BRASIL_REGIOES_UFS' and a >= 2017:
      exec("df = pd.read_excel('/content/drive/MyDrive/br_inep_afd/input/AFD_{}_{}.xlsx', skiprows=10, skipfooter=5, dtype='string')".format(g, str(a)))
      if a <= 2016:
        df.rename(columns={'no_uf':'nome_uf'}, inplace=True)
        df.drop(columns='no_cod', axis=1, inplace=True)
      if a >= 2017:
        df.rename(columns={'no_cod':'nome_uf'}, inplace=True)
      df.rename(columns=rename_uf, inplace=True)
      df.dropna(subset=['ano'], inplace=True)
      df['rede'] = df['rede'].str.lower()
      df['tipo_localizacao'] = df['tipo_localizacao'].str.lower()
      df = pd.merge(df, id_uf, how='left', left_on=['nome_uf'], right_on=['nome'])
      df.dropna(subset=['sigla_uf'], inplace=True)
      df = df[ordem_uf]
      id_var = ['ano', 'regiao', 'sigla_uf', 'tipo_localizacao', 'rede']
      value_var = df.drop(columns=id_var, axis=1).columns
      df = pd.melt(df, id_vars=id_var, value_vars=value_var, var_name='modalidade_grupo', value_name='percentual')
      if a != 2019 and a == 2019:
        df = df.applymap(lambda x: np.nan if x == '--' else x).dropna(subset=['percentual'])
        df.dropna(subset=['percentual'], inplace=True)
      df['modalidade'] = df['modalidade_grupo'].str[:-8]
      df['modalidade'] = df['modalidade'].apply(lambda x: str(x).replace('_',' '))
      df['grupo'] = df['modalidade_grupo'].str[-1:]
      df = df[['regiao', 'sigla_uf', 'tipo_localizacao', 'rede', 'modalidade', 'grupo', 'percentual']]
      df.sort_values(['sigla_uf', 'modalidade'], inplace=True)
      exec('df.to_csv("/content/drive/MyDrive/br_inep_afd/output/afd_uf_{}.csv", index=False, na_rep="", encoding="utf-8")'.format(a))
      print('AFD UF {} pronto'.format(a))
      del df

    if g == 'REGIOES' and a <= 2016 or g == 'BRASIL_REGIOES_UFS' and a >= 2017:
      exec("df = pd.read_excel('/content/drive/MyDrive/br_inep_afd/input/AFD_{}_{}.xlsx', skiprows=10, skipfooter=5, dtype='string')".format(g, str(a)))
      df.rename(columns=rename_br, inplace=True)
      df.dropna(subset=['ano'], inplace=True)
      df['rede'] = df['rede'].str.lower()
      df['tipo_localizacao'] = df['tipo_localizacao'].str.lower()
      df = df[df.regiao.isin(['Norte', 'Nordeste', 'Sudeste', 'Sul', 'Centro-Oeste'])]
      df = df[ordem_br]
      id_var = ['ano', 'regiao', 'tipo_localizacao', 'rede']
      value_var = df.drop(columns=id_var, axis=1).columns
      df = pd.melt(df, id_vars=id_var, value_vars=value_var, var_name='modalidade_grupo', value_name='percentual')
      if a != 2019 and a == 2019:
        df = df.applymap(lambda x: np.nan if x == '--' else x).dropna(subset=['percentual'])
        df.dropna(subset=['percentual'], inplace=True)
      df['modalidade'] = df['modalidade_grupo'].str[:-8]
      df['modalidade'] = df['modalidade'].apply(lambda x: str(x).replace('_',' '))
      df['grupo'] = df['modalidade_grupo'].str[-1:]
      df = df[['regiao', 'tipo_localizacao', 'rede', 'modalidade', 'grupo', 'percentual']]
      df.sort_values(['regiao', 'modalidade'], inplace=True)
      exec('df.to_csv("/content/drive/MyDrive/br_inep_afd/output/afd_regiao_{}.csv", index=False, na_rep="", encoding="utf-8")'.format(a))
      print('AFD região {} pronto'.format(a))
      del df

    if g == 'BRASIL' and a <= 2016 or g == 'BRASIL_REGIOES_UFS' and a >= 2017:
      exec("df = pd.read_excel('/content/drive/MyDrive/br_inep_afd/input/AFD_{}_{}.xlsx', skiprows=10, skipfooter=5, dtype='string')".format(g, str(a)))
      df.rename(columns=rename_br, inplace=True)
      df.dropna(subset=['ano'], inplace=True)
      df['rede'] =df['rede'].str.lower()
      df['tipo_localizacao'] = df['tipo_localizacao'].str.lower()
      df = df[df.regiao.isin(['Brasil'])]
      df = df[ordem_br]
      id_var = ['ano', 'regiao', 'tipo_localizacao', 'rede']
      value_var = df.drop(columns=id_var, axis=1).columns
      df = pd.melt(df, id_vars=id_var, value_vars=value_var, var_name='modalidade_grupo', value_name='percentual')
      if a != 2019 and a == 2019:
        df = df.applymap(lambda x: np.nan if x == '--' else x).dropna(subset=['percentual'])
        df.dropna(subset=['percentual'], inplace=True)
      df['modalidade'] = df['modalidade_grupo'].str[:-8]
      df['modalidade'] = df['modalidade'].apply(lambda x: str(x).replace('_',''))
      df['grupo'] = df['modalidade_grupo'].str[-1:]
      df = df[['tipo_localizacao', 'rede', 'modalidade', 'grupo', 'percentual']]
      df.sort_values(['modalidade'], inplace=True)
      exec('df.to_csv("/content/drive/MyDrive/br_inep_afd/output/afd_brasil_{}.csv", index=False, na_rep="", encoding="utf-8")'.format(a))
      print('AFD Brasil {} pronto'.format(a))
      del df
