# %%
import pandas as pd
import numpy as np
df = pd.read_csv('/content/drive/Shareddrives/Base dos Dados - Geral/Dados/Conjuntos/world_spi/input/2022_social_progress_index_dataset-1663250377csv.csv', sep = ';', encoding='latin1', dtype=str)
# Visualizando todas as colunas do DataFrame. 
# Importante quando for trabalhar com muitas colunas
pd.set_option('display.max_columns', None)

# %%
#Renomeando as colunas

df.rename(columns= {'SPI \nRank':'rank',
'Country':'country',
'SPI country code':'country_id_iso_3',
'SPI \nyear':'year',
'Status':'status',
'Social Progress Index':'social_progress_index',
'Basic Human Needs':'basic_human_needs',
'Foundations of Wellbeing':'wellbeing',
'Opportunity':'opportunity',
'Nutrition & Basic Medical Care':'nutrition_basic_medical_care',
'Water & Sanitation':'water_sanitation',
'Shelter':'shelter',
'Personal Safety':'personal_safety',
'Access to Basic Knowledge':'access_basic_knowledge',
'Access to Information & Communications':'access_infomation_communication',
'Health & Wellness ':'health_wellness',
'Environmental Quality':'environmental_quality',
'Personal Rights':'personal_rights',
'Personal Freedom & Choice':'personal_freedom_choice',
'Inclusiveness':'inclusiveness',
'Access to Advanced Education':'access_advanced_education',
'Child stunting (0=low risk; 100=high risk) ':'child_stunting',
'Infectious diseases (DALYs/100,000)':'infectious_diseases',
'Maternal mortality rate (deaths/100,000 live births) ':'maternal_mortality_rate',
'Child mortality rate (deaths/1,000 live births) ':'child_mortality_rate',
'Undernourishment (% of pop.) ':'undernourishment',
'Diet low in fruits and vegetables (0=low risk; 100=high risk) ':'diet_low_fruit_vegetable',
'Unsafe water, sanitation and hygiene (DALYs/100,000)':'unsafe_water_sanitation_hygiene',
'Access to improved sanitation (proportion of pop.) ':'access_improved_sanitation',
'Access to improved water source (proportion of pop.) ':'access_improved_water_source',
'Satisfaction with water quality (proportion of pop.) ':'satisfaction_water_quality',
'Household air pollution (DALYs/100,000)':'household_air_pollution',
'Dissatisfaction with housing affordability  (proportion of pop.) ':'dissatisfaction_housing_affordability',
'Access to electricity  (% of pop.) ':'access_electricity',
'Usage of clean fuels and technology for cooking  (% of pop.) ':'usage_clean_fuels_technology_cooking',
'Political killings and torture  (0=low freedom; 1=high freedom)':'political_killings_torture',
'Interpersonal violence   (DALYs/100,000)':'interpesoal_violence',
'Transportation related injuries  (DALYs/100,000)':'transportation_related_injuries',
'Intimate Partner Violence (% of women aged 15+) ':'intimate_partner_violence',
'Money Stolen (proportion of pop.) ':'money_stolen',
'Equal access to quality education  (0=unequal; 4=equal) ':'equal_access_quality_education',
'Population with no schooling  (proportion of pop.) ':'population_no_schooling',
'Secondary school attainment  (% of pop. aged 25+) ':'secondary_school_attainment',
'Primary school enrollment  (% of children) ':'primary_school_enrollment',
'Gender parity in secondary attainment  (distance from parity) ':'gender_parity_secondary_attainment',
'Alternative sources of information index (0=low; 1=high)':'alternative_source_information_index',
'Mobile telephone subscriptions  (subscriptions/1,000 people) ':'mobile_telephone_subscription',
'Internet users  (% of pop.) ':'internet_user',
'Access to online governance  (0=low; 1=high)':'access_online_governance',
'Equal access to quality healthcare  (0=unequal; 4=equal) ':'equal_access_quality_healthcare',
'Life expectancy at 60  (years)':'life_expectancy_60',
'Premature deaths from non-communicable diseases  (deaths/100,000)':'premature_death_non_communicable_disease',
'Access to essential health services  (0=none; 100=full coverage)':'access_essential_health_service',
'Satisfaction with availability of quality healthcare (proportion of pop.) ':'satisfaction_availability_quality_healthcare',
'Outdoor air pollution (DALYs/100,000)':'outdoor_air_pollution',
'Lead exposure  (DALYs/100,000)':'lead_exposure',
'Particulate matter pollution  (mean annual exposure, µg/m3)':'particulate_matter_pollution',
'Species protection  (0=low; 100=high)':'specie_protection',
'Freedom of religion  (0=no freedom; 4=full freedom) ':'freedom_religion',
'Property rights for women  (0=no rights; 5=full rights) ':'property_rights_women',
'Freedom of peaceful assembly  (0=no freedom; 4=full freedom) ':'freedom_peaceful_assembly',
'Access to justice  (0=nonexistent; 1=observed)':'access_justice',
'Freedom of discussion (0=low; 1=high)':'freedom_discussion',
'Political rights  (0 and lower=no rights; 40=full rights)':'political_right',
'Freedom of domestic movement (0=low; 1=high)':'freedom_domestic_movement',
'Early marriage  (% of married women aged 15-19)':'early_marriage',
'Satisfied demand for contraception  (% satisfied demand)':'satisfied_demand_contraception',
'Young people not in education, employment or training  (% of youth)':'young_not_education_employment_training',
'Vulnerable employment  (% of total employment) ':'vulnerable_employment',
'Perception of corruption  (0=high corruption; 100=low corruption)':'perception_corruption',
'Equal protection index (0=low; 1=high)':'equal_protection_index',
'Equal access index (0=low; 1=high)':'equal_access_index',
'Power distributed by sexual orientation (0=extremely unequal; 3=equal) ':'power_distributed_sexual_orientation',
'Access to public services distributed by social group (0=extremely unequal; 4=equal) ':'access_public_service_social_group',
'Acceptance of gays and lesbians  (proportion of pop.) ':'acceptance_gay_lesbian',
'Discrimination and violence against minorities  (0=low; 10=high)':'discrimination_violence_against_minority',
'Academic freedom (0=low; 1=high)':'academic_freedom',
'Women with advanced education (proportion of females) ':'women_advanced_education',
'Expected years of tertiary schooling (years)':'expected_year_tertiary_schooling',
'Citable documents (documents/1,000 people)':'citable_document',
'Quality weighted universities (points)':'quality_weighted_university'}, inplace=True)

# Reorganizando as colunas

df = df[['year',
'country',
'country_id_iso_3',
'rank',
'status',
'social_progress_index',
'basic_human_needs',
'wellbeing',
'opportunity',
'nutrition_basic_medical_care',
'water_sanitation',
'shelter',
'personal_safety',
'access_basic_knowledge',
'access_infomation_communication',
'health_wellness',
'environmental_quality',
'personal_rights',
'personal_freedom_choice',
'inclusiveness',
'access_advanced_education',
'child_stunting',
'infectious_diseases',
'maternal_mortality_rate',
'child_mortality_rate',
'undernourishment',
'diet_low_fruit_vegetable',
'unsafe_water_sanitation_hygiene',
'access_improved_sanitation',
'access_improved_water_source',
'satisfaction_water_quality',
'household_air_pollution',
'dissatisfaction_housing_affordability',
'access_electricity',
'usage_clean_fuels_technology_cooking',
'political_killings_torture',
'interpesoal_violence',
'transportation_related_injuries',
'intimate_partner_violence',
'money_stolen',
'equal_access_quality_education',
'population_no_schooling',
'secondary_school_attainment',
'primary_school_enrollment',
'gender_parity_secondary_attainment',
'alternative_source_information_index',
'mobile_telephone_subscription',
'internet_user',
'access_online_governance',
'equal_access_quality_healthcare',
'life_expectancy_60',
'premature_death_non_communicable_disease',
'access_essential_health_service',
'satisfaction_availability_quality_healthcare',
'outdoor_air_pollution',
'lead_exposure',
'particulate_matter_pollution',
'specie_protection',
'freedom_religion',
'property_rights_women',
'freedom_peaceful_assembly',
'access_justice',
'freedom_discussion',
'political_right',
'freedom_domestic_movement',
'early_marriage',
'satisfied_demand_contraception',
'young_not_education_employment_training',
'vulnerable_employment',
'perception_corruption',
'equal_protection_index',
'equal_access_index',
'power_distributed_sexual_orientation',
'access_public_service_social_group',
'acceptance_gay_lesbian',
'discrimination_violence_against_minority',
'academic_freedom',
'women_advanced_education',
'expected_year_tertiary_schooling',
'citable_document',
'quality_weighted_university']]

# Replace em , para substituir os .

lista = ['social_progress_index',
'basic_human_needs',
'wellbeing',
'opportunity',
'nutrition_basic_medical_care',
'water_sanitation',
'shelter',
'personal_safety',
'access_basic_knowledge',
'access_infomation_communication',
'health_wellness',
'environmental_quality',
'personal_rights',
'personal_freedom_choice',
'inclusiveness',
'access_advanced_education',
'child_stunting',
'infectious_diseases',
'maternal_mortality_rate',
'child_mortality_rate',
'undernourishment',
'diet_low_fruit_vegetable',
'unsafe_water_sanitation_hygiene',
'access_improved_sanitation',
'access_improved_water_source',
'satisfaction_water_quality',
'household_air_pollution',
'dissatisfaction_housing_affordability',
'access_electricity',
'usage_clean_fuels_technology_cooking',
'political_killings_torture',
'interpesoal_violence',
'transportation_related_injuries',
'intimate_partner_violence',
'money_stolen',
'equal_access_quality_education',
'population_no_schooling',
'secondary_school_attainment',
'primary_school_enrollment',
'gender_parity_secondary_attainment',
'alternative_source_information_index',
'mobile_telephone_subscription',
'internet_user',
'access_online_governance',
'equal_access_quality_healthcare',
'life_expectancy_60',
'premature_death_non_communicable_disease',
'access_essential_health_service',
'satisfaction_availability_quality_healthcare',
'outdoor_air_pollution',
'lead_exposure',
'particulate_matter_pollution',
'specie_protection',
'freedom_religion',
'property_rights_women',
'freedom_peaceful_assembly',
'access_justice',
'freedom_discussion',
'political_right',
'freedom_domestic_movement',
'early_marriage',
'satisfied_demand_contraception',
'young_not_education_employment_training',
'vulnerable_employment',
'perception_corruption',
'equal_protection_index',
'equal_access_index',
'power_distributed_sexual_orientation',
'access_public_service_social_group',
'acceptance_gay_lesbian',
'discrimination_violence_against_minority',
'academic_freedom',
'women_advanced_education',
'expected_year_tertiary_schooling',
'citable_document',
'quality_weighted_university']

for x in lista:
    df[x] = df[x].apply(lambda x: str(x).replace(',','.'))

df = df.query('country != "World"')
df = df.replace(np.nan, '')
df['status'] = df['status'].str.lower()


df.to_csv('/content/drive/Shareddrives/Base dos Dados - Geral/Dados/Conjuntos/world_spi/output/global_indicators.csv', index=False, na_rep='')

# %%
df.shape
# Out:
# (2352, 81)
