# %%
pip install basedosdados==1.6.10b1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import basedosdados as bd
import pandas as pd
import numpy as np

from google.colab import drive
drive.mount('/content/drive')

path = '/content/drive/Shareddrives/Base dos Dados - Geral/Dados/Conjuntos/br_ibge_estadic'
input = path + '/input/'
output = path + '/output/'

df_2018 = pd.read_csv(input + 'estadic.educacao/2018.csv', dtype = str)
df_2014 = pd.read_csv(input + 'estadic.educacao/2014.csv', dtype = str)

pd.set_option('display.max_columns', None)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cod_uf = bd.read_table(dataset_id='br_bd_diretorios_brasil',
table_id='uf',
billing_project_id="basedosdados-374415")
# Out:
# Downloading: 100%|██████████| 27/27 [00:00<00:00, 130.69rows/s]

# %% [markdown]
# ## 2014

# %%
df_2014.rename(columns={
'A1' : 'id_uf',
'A148':'caracterizacao_orgao_gestor',
'A151':'gestor_sexo',
'A152':'gestor_idade',
'A149':'gestor_escolaridade',
'A150':'gestor_escolaridade_formacao',
'A153':'capacitacao_gestao_educacional',
'A154':'programa_curso',
'A155':'recursos_humanos_educacao_total',
'A156':'recursos_educacao_estatutario',
'A157':'recursos_educacao_celetista',
'A158':'recursos_educacao_comissionado',
'A159':'recursos_educacao_estagiario',
'A160':'recursos_educacao_sem_vinculo_permanente',
'A161':'recursos_educacao_total_professor',
'A162':'recursos_educacao_professor_infantil',
'st':'recursos_educacao_professor_fundamental',
'A164':'recursos_educacao_professor_ensino_medio',
'A165':'creche_mantida_exclusivamente_estado',
'A166':'creche_integrada_sistema_estadual_federal',
'A167':'creche_recebe_pcd',
'A168':'pre_escola_mantida_exclusivamente_estado',
'A169':'pre_escola_integrada_sistema_estadual_federal',
'A170':'pre_escola_recebe_pcd',
'A171':'ensino_fundamental_mantida_exclusivamente_estado',
'A172':'ensino_fundamental_integrada_sistema_estadual_federal',
'A173':'ensino_fundamental_recebe_pcd',
'A174':'ensino_medio_mantida_exclusivamente_estado',
'A175':'ensino_medio_integrada_sistema_estadual_federal',
'A176':'ensino_medio_recebe_pcd',
'A177':'ensino_superior_mantida_exclusivamente_estado',
'A178':'ensino_superior_integrada_sistema_estadual_federal',
'A179':'ensino_superior_recebe_pcd',
'A180':'prioridade_acessibilidade',
'A181':'prioridade_sala_recurso_multifuncional',
'A182':'prioridade_elevacao_escolaridade_professor',
'A183':'prioridade_formacao_continuada_professor',
'A184':'prioridade_concurso_publico',
'A185':'prioridade_participacao_comunidade_gestao_escolar',
'A186':'prioridade_chamada_publica_matricula',
'A187':'prioridade_organizacao_administrativa',
'A188':'prioridade_saude_escolar',
'A189':'prioridade_inclusao_aluno_deficiencia',
'A191':'prioridade_combate_discriminacao',
'A190':'prioridade_combate_violencia_escola',
'A196':'prioridade_enfrentamento_atraso_escolar',
'A192':'prioridade_alfabetizacao_idade_certa',
'A193':'prioridade_melhoria_alimentacao_escolar',
'A194':'prioridade_melhoria_transporte_escolar',
'A197':'prioridade_elevacao_desempenho_avaliacao_nacional',
'A198':'prioridade_educacao_direitos_humanos',
'A199':'prioridade_educacao_campo_indigena_quilombola',
'A200':'prioridade_educacao_jovem_adulto',
'A201':'prioridade_educacao_profissional',
'A202':'prioridade_acompanhamento_avaliacao_creche_pre_escola',
'A195':'prioridade_diminuicao_evasao_escolar',
'A203':'prioridade_programa_mediacao_resolucao_conflito_escolar',
'A204':'plano_estadual_educacao',
'A205':'ano_atual_pee',
'A206':'plano_carreira_magisterio',
'A207':'ano_criacao_plano_carreira_magisterio',
'A208':'conselho_educacao',
'A209':'lei_criacao_conselho_educacao',
'A210':'formacao_conselho_educacao',
'A211':'carater_conselho_educacao_consultivo',
'A212':'carater_conselho_educacao_deliberativo',
'A213':'carater_conselho_educacao_normativo',
'A214':'carater_conselho_educacao_fiscalizador',
'A215':'conselho_educacao_reuniao_12_meses',
'A216':'composicao_conselho_educacao_pais_alunos',
'A217':'composicao_conselho_educacao_assembleia_legislativa',
'A218':'composicao_conselho_educacao_diretor_escola_rede_estadual',
'A219':'composicao_conselho_educacao_servidor_escola_rede_estadual',
'A220':'composicao_conselho_educacao_conselho_tutelar',
'A221':'composicao_conselho_educacao_escola_privada',
'A222':'composicao_conselho_educacao_instituicao_ensino_superior',
'A223':'composicao_conselho_educacao_sindicato_educacao',
'A224':'composicao_conselho_educacao_outro',
'A225':'conselho_fundeb',
'A226':'ano_criacao_conselho_fundeb',
'A227':'conselho_fundeb_reuniao_12_meses',
'A228':'conselho_alimentacao_escolar',
'A229':'ano_criacao_conselho_alimentacao_escolar',
'A230':'formacao_alimentacao_escolar',
'A231':'carater_conselho_alimentacao_escolar_consultivo',
'A232':'carater_conselho_alimentacao_escolar_deliberativo',
'A233':'carater_conselho_alimentacao_escolar_normativo',
'A234':'carater_conselho_alimentacao_escolar_fiscalizador',
'A235':'conselho_alimentacao_escolar_reuniao_12_meses',
'A236':'conselho_transporte_escolar',
'A237':'ano_criacao_conselho_transporte_escolar',
'A238':'formacao_conselho_transporte_escolar',
'A239':'carater_conselho_transporte_escolar_consultivo',
'A240':'carater_conselho_transporte_escolar_deliberativo',
'A241':'carater_conselho_transporte_escolar_normativo',
'A242':'carater_conselho_transporte_escolar_fiscalizador',
'A243':'conselho_transporte_escolar_reuniao_12_meses',
'A244':'percentual_receita_municipio_destinado_ensino',
'A245':'responsabilidade_recurso_financeiro',
'A246':'nomeacao_diretor_indicacao',
'A247':'nomeacao_diretor_eleicao',
'A248':'nomeacao_diretor_processo_seletivo',
'A249':'nomeacao_diretor_outro',
'A250':'programa_formacao_gestao_escolar_exercer_cargo',
'A251':'tipo_programa'}, inplace=True)

df_2014['ano'] = '2014'

# %% [markdown]
# ## 2018

# %%
df_2018.rename(columns={
'Cod Uf':'id_uf',
'EEDU01':'caracterizacao_orgao_gestor',
'EEDU03':'gestor_sexo',
'EEDU04':'gestor_idade',
'EEDU05':'gestor_raca_cor',
'EEDU051':'raca_cor_autodeclarado',
'EEDU06':'gestor_escolaridade',
'EEDU07':'gestor_escolaridade_formacao',
'EEDU07111':'(deletado)',
'EEDU08':'capacitacao_gestao_educacional',
'EEDU081':'programa_curso',
'EEDU111':'prioridade_acessibilidade',
'EEDU112':'prioridade_sala_recurso_multifuncional',
'EEDU1110':'prioridade_formacao_continuada_professor',
'EEDU113':'prioridade_inclusao_aluno_deficiencia',
'EEDU114':'prioridade_combate_violencia_escola',
'EEDU115':'prioridade_constituicao_conselho_escolar',
'EEDU116':'prioridade_integracao_escola_comunidade',
'EEDU117':'prioridade_formacao_docente',
'EEDU118':'prioridade_constituicao_gremio_estudantil',
'EEDU119':'prioridade_reducao_falta_docente',
'EEDU1111':'prioridade_enfrentamento_atraso_escolar',
'EEDU1112':'prioridade_alfabetizacao_idade_certa',
'EEDU1113':'prioridade_elevacao_desempenho_avaliacao_nacional',
'EEDU1114':'prioridade_diminuicao_evasao_escolar',
'EEDU1115':'prioridade_chamada_publica_matricula',
'EEDU1116':'prioridade_ampliacao_jornada_escolar',
'EEDU1117':'prioridade_uso_tecnologia',
'EEDU1118':'prioridade_combate_bulliyng',
'EEDU121':'combate_discriminacao_racial',
'EEDU122':'combate_discriminacao_religiosa',
'EEDU123':'combate_homofobia',
'EEDU124':'combate_outros_tipos_discriminacao',
'EEDU125':'nenhum_tipo_combate',
'EEDU131':'projeto_educacao_campo',
'EEDU132':'projeto_educacao_indigena',
'EEDU133':'projeto_comunidade_quilombola',
'EEDU134':'projeto_comunidade_tradicional',
'EEDU135':'nenhum_projeto_educacional',
'EEDU14':'plano_estadual_educacao',
'EEDU141A':'lei_atual_pee',
'EEDU141B':'ano_atual_pee',
'EEDU15':'constituicao_forum_permanente_educacao',
'EEDU151':'ano_constituicao_forum_permanente_educacao',
'EEDU152':'instrumento_constituicao',
'EEDU16':'plano_carreira_magisterio',
'EEDU161A':'lei_criacao_plano_carreira_magisterio',
'EEDU161B':'ano_criacao_plano_carreira_magisterio',
'EEDU171':'criterio_tempo_efetivo',
'EEDU172':'criterio_avaliacao_desempenho',
'EEDU173':'criterio_qualificacao',
'EEDU1731':'criterio_qualificacao_licenciatura',
'EEDU1732':'criterio_qualificacao_curso_aperfeicoamento',
'EEDU1733':'criterio_qualificacao_especializacao',
'EEDU1734':'criterio_qualificacao_mestrado',
'EEDU1735':'criterio_qualificacao_doutorado',
'EEDU174':'criterio_desempenho_prova_conhecimento',
'EEDU175':'criterio_desempenho_aluno',
'EEDU176':'criterio_incorporacao_permanente_remuneracao',
'EEDU177':'criterio_outro',
'EEDU18':'lei_carga_horaria_interacao_aluno',
'EEDU191':'carga_horaria_semanal_opcao_1',
'EEDU192':'carga_horaria_semanal_opcao_2',
'EEDU193':'carga_horaria_semanal_opcao_3',
'EEDU194':'carga_horaria_semanal_opcao_4',
'EEDU195':'carga_horaria_semanal_opcao_5',
'EEDU20':'piso_salarial_definido_magisterio_publico',
'EEDU21':'plano_carreira_nao_docente',
'EEDU211A':'lei_plano_carreira_nao_docente',
'EEDU211B':'ano_plano_carreira_nao_docente',
'EEDU22':'conselho_educacao',
'EEDU221A':'lei_criacao_conselho_educacao',
'EEDU221B':'ano_criacao_conselho_educacao',
'EEDU222':'formacao_conselho_educacao',
'EEDU231':'carater_conselho_educacao_consultivo',
'EEDU232':'carater_conselho_educacao_deliberativo',
'EEDU233':'carater_conselho_educacao_normativo',
'EEDU234':'carater_conselho_educacao_fiscalizador',
'EEDU24':'conselho_educacao_reuniao_12_meses',
'EEDU25':'conselho_educacao_integrante',
'EEDU261':'conselho_educacao_capacitacao_periodicamente',
'EEDU262':'conselho_educacao_capacitacao_ocasionalmente',
'EEDU263':'conselho_educacao_nao_realiza_capacitacao',
'EEDU27':'conselho_educacao_infraestrutura',
'EEDU2711':'conselho_educacao_infraestrutura_sala',
'EEDU2712':'conselho_educacao_infraestrutura_computador',
'EEDU2713':'conselho_educacao_infraestrutura_impressora',
'EEDU2714':'conselho_educacao_infraestrutura_acesso_internet',
'EEDU2715':'conselho_educacao_infraestrutura_veiculo',
'EEDU2716':'conselho_educacao_infraestrutura_telefone',
'EEDU2717':'conselho_educacao_infraestrutura_diarias',
'EEDU2718':'conselho_educacao_infraestrutura_dotacao_orcamentaria_propria',
'EEDU281':'composicao_conselho_educacao_pais_alunos',
'EEDU282':'composicao_conselho_educacao_assembleia_legislativa',
'EEDU283':'composicao_conselho_educacao_diretor_escola_rede_estadual',
'EEDU284':'composicao_conselho_educacao_servidor_escola_rede_estadual',
'EEDU285':'composicao_conselho_educacao_conselho_tutelar',
'EEDU286':'composicao_conselho_educacao_escola_privada',
'EEDU287':'composicao_conselho_educacao_instituicao_ensino_superior',
'EEDU288':'composicao_conselho_educacao_sindicato_educacao',
'EEDU289':'composicao_conselho_educacao_secretaria_educacao',
'EEDU2810':'composicao_conselho_educacao_movimento_negro',
'EEDU2811':'composicao_conselho_educacao_comunidade_quilombola',
'EEDU2812':'composicao_conselho_educacao_povo_indigena',
'EEDU2813':'composicao_conselho_educacao_comunidade_tradicional',
'EEDU2814':'composicao_conselho_educacao_outro',
'EEDU29':'funcao_gestor_educacao_conselho_educacao',
'EEDU30':'conselho_fundeb',
'EEDU301A':'lei_criacao_conselho_fundeb',
'EEDU301B':'ano_criacao_conselho_fundeb',
'EEDU302':'formacao_conselho_fundeb',
'EEDU31':'conselho_fundeb_reuniao_12_meses',
'EEDU32':'conselho_fundeb_integrantes',
'EEDU331':'conselho_fundeb_capacitacao_periodicamente',
'EEDU332':'conselho_fundeb_capacitacao_ocasionalmente',
'EEDU333':'conselho_fundeb_nao_realiza_capacitacao',
'EEDU34':'conselho_fundeb_infraestrutura',
'EEDU3411':'conselho_fundeb_infraestrutura_sala_propria',
'EEDU3412':'conselho_fundeb_infraestrutura_computador',
'EEDU3413':'conselho_fundeb_infraestrutura_impressora',
'EEDU3414':'conselho_fundeb_infraestrutura_acesso_internet',
'EEDU3415':'conselho_fundeb_infraestrutura_veiculo',
'EEDU3416':'conselho_fundeb_infraestrutura_telefone',
'EEDU3417':'conselho_fundeb_infraestrutura_diarias',
'EEDU3418':'conselho_fundeb_infraestrutura_dotacao_orcamentaria_propria',
'EEDU35':'conselho_alimentacao_escolar',
'EEDU351A':'lei_criacao_conselho_alimentacao_escolar',
'EEDU351B':'ano_criacao_conselho_alimentacao_escolar',
'EEDU352':'formacao_alimentacao_escolar',
'EEDU361':'carater_conselho_alimentacao_escolar_consultivo',
'EEDU362':'carater_conselho_alimentacao_escolar_deliberativo',
'EEDU363':'carater_conselho_alimentacao_escolar_normativo',
'EEDU364':'carater_conselho_alimentacao_escolar_fiscalizador',
'EEDU37':'conselho_alimentacao_escolar_reuniao_12_meses',
'EEDU38':'conselho_alimentacao_escolar_integrantes',
'EEDU391':'conselho_alimentacao_escolar_capacitacao_periodicamente',
'EEDU392':'conselho_alimentacao_escolar_capacitacao_ocasionalmente',
'EEDU393':'conselho_alimentacao_escolar_nao_realiza_capacitacao',
'EEDU40':'conselho_alimentacao_escolar_infraestrutura',
'EEDU4011':'conselho_alimentacao_escolar_infraestrutura_sala_propria',
'EEDU4012':'conselho_alimentacao_escolar_infraestrutura_computador',
'EEDU4013':'conselho_alimentacao_escolar_infraestrutura_impressora',
'EEDU4014':'conselho_alimentacao_escolar_infraestrutura_acesso_internet',
'EEDU4015':'conselho_alimentacao_escolar_infraestrutura_veiculo',
'EEDU4016':'conselho_alimentacao_escolar_infraestrutura_telefone',
'EEDU4017':'conselho_alimentacao_escolar_infraestrutura_diarias',
'EEDU4018':'conselho_alimentacao_escolar_infraestrutura_dotacao_orcamentaria_propria',
'EEDU41':'conselho_transporte_escolar',
'EEDU411A':'lei_criacao_conselho_transporte_escolar',
'EEDU411B':'ano_criacao_conselho_transporte_escolar',
'EEDU412':'formacao_conselho_transporte_escolar',
'EEDU421':'carater_conselho_transporte_escolar_consultivo',
'EEDU422':'carater_conselho_transporte_escolar_deliberativo',
'EEDU423':'carater_conselho_transporte_escolar_normativo',
'EEDU424':'carater_conselho_transporte_escolar_fiscalizador',
'EEDU43':'conselho_transporte_escolar_reuniao_12_meses',
'EEDU44':'conselho_transporte_escolar_integrantes',
'EEDU451':'conselho_transporte_escolar_capacitacao_periodicamente',
'EEDU452':'conselho_transporte_escolar_capacitacao_ocasionalmente',
'EEDU453':'conselho_transporte_escolar_nao_realiza_capacitacao',
'EEDU46':'conselho_transporte_escolar_infraestrutura',
'EEDU4611':'conselho_transporte_escolar_infraestrutura_sala_propria',
'EEDU4612':'conselho_transporte_escolar_infraestrutura_computador',
'EEDU4613':'conselho_transporte_escolar_infraestrutura_impressora',
'EEDU4614':'conselho_transporte_escolar_infraestrutura_acesso_internet',
'EEDU4615':'conselho_transporte_escolar_infraestrutura_veiculo_proprio',
'EEDU4616':'conselho_transporte_escolar_infraestrutura_telefone',
'EEDU4617':'conselho_transporte_escolar_infraestrutura_diarias',
'EEDU4618':'conselho_transporte_escolar_infraestrutura_dotacao_orcamentaria_propria',
'EEDU47':'lei_estadual_criacao_conselho_escolar',
'EEDU471A':'lei_conselho_escolar',
'EEDU471B':'ano_conselho_escolar',
'EEDU472':'formacao_conselho_escolar',
'EEDU48':'ordenacao_despesas_educacao',
'EEDU491':'nomeacao_diretor_concurso_publico',
'EEDU492':'nomeacao_diretor_livre',
'EEDU49211':'nomeacao_diretor_indicacao',
'EEDU49212':'nomeacao_diretor_eleicao',
'EEDU49213':'nomeacao_diretor_processo_seletivo',
'EEDU49214':'nomeacao_diretor_outro'}, inplace=True)

df_2018['ano'] = '2018'
df = df_2014.append(df_2018, ignore_index=True)

# %%
df_completo = pd.merge(cod_uf, df, how = 'left', on = 'id_uf')
df_completo.rename(columns={'sigla' : 'sigla_uf'}, inplace=True)
df_completo.drop(['nome', 'regiao', '(deletado)'], axis=1)


# Realocando as colunas
df_completo = df_completo[['ano',
'sigla_uf',
'caracterizacao_orgao_gestor',
'gestor_sexo',
'gestor_idade',
'gestor_raca_cor',
'raca_cor_autodeclarado',
'gestor_escolaridade',
'gestor_escolaridade_formacao',
'capacitacao_gestao_educacional',
'programa_curso',
'recursos_humanos_educacao_total',
'recursos_educacao_estatutario',
'recursos_educacao_celetista',
'recursos_educacao_comissionado',
'recursos_educacao_estagiario',
'recursos_educacao_sem_vinculo_permanente',
'recursos_educacao_total_professor',
'recursos_educacao_professor_infantil',
'recursos_educacao_professor_fundamental',
'recursos_educacao_professor_ensino_medio',
'creche_mantida_exclusivamente_estado',
'creche_integrada_sistema_estadual_federal',
'creche_recebe_pcd',
'pre_escola_mantida_exclusivamente_estado',
'pre_escola_integrada_sistema_estadual_federal',
'pre_escola_recebe_pcd',
'ensino_fundamental_mantida_exclusivamente_estado',
'ensino_fundamental_integrada_sistema_estadual_federal',
'ensino_fundamental_recebe_pcd',
'ensino_medio_mantida_exclusivamente_estado',
'ensino_medio_integrada_sistema_estadual_federal',
'ensino_medio_recebe_pcd',
'ensino_superior_mantida_exclusivamente_estado',
'ensino_superior_integrada_sistema_estadual_federal',
'ensino_superior_recebe_pcd',
'prioridade_acessibilidade',
'prioridade_sala_recurso_multifuncional',
'prioridade_elevacao_escolaridade_professor',
'prioridade_formacao_continuada_professor',
'prioridade_concurso_publico',
'prioridade_participacao_comunidade_gestao_escolar',
'prioridade_organizacao_administrativa',
'prioridade_saude_escolar',
'prioridade_inclusao_aluno_deficiencia',
'prioridade_combate_discriminacao',
'prioridade_combate_violencia_escola',
'prioridade_constituicao_conselho_escolar',
'prioridade_integracao_escola_comunidade',
'prioridade_formacao_docente',
'prioridade_constituicao_gremio_estudantil',
'prioridade_reducao_falta_docente',
'prioridade_enfrentamento_atraso_escolar',
'prioridade_alfabetizacao_idade_certa',
'prioridade_melhoria_alimentacao_escolar',
'prioridade_melhoria_transporte_escolar',
'prioridade_elevacao_desempenho_avaliacao_nacional',
'prioridade_educacao_direitos_humanos',
'prioridade_educacao_campo_indigena_quilombola',
'prioridade_educacao_jovem_adulto',
'prioridade_educacao_profissional',
'prioridade_acompanhamento_avaliacao_creche_pre_escola',
'prioridade_diminuicao_evasao_escolar',
'prioridade_chamada_publica_matricula',
'prioridade_ampliacao_jornada_escolar',
'prioridade_uso_tecnologia',
'prioridade_combate_bulliyng',
'prioridade_programa_mediacao_resolucao_conflito_escolar',
'combate_discriminacao_racial',
'combate_discriminacao_religiosa',
'combate_homofobia',
'combate_outros_tipos_discriminacao',
'nenhum_tipo_combate',
'projeto_educacao_campo',
'projeto_educacao_indigena',
'projeto_comunidade_quilombola',
'projeto_comunidade_tradicional',
'nenhum_projeto_educacional',
'plano_estadual_educacao',
'lei_atual_pee',
'ano_atual_pee',
'constituicao_forum_permanente_educacao',
'ano_constituicao_forum_permanente_educacao',
'instrumento_constituicao',
'plano_carreira_magisterio',
'lei_criacao_plano_carreira_magisterio',
'ano_criacao_plano_carreira_magisterio',
'criterio_tempo_efetivo',
'criterio_avaliacao_desempenho',
'criterio_qualificacao',
'criterio_qualificacao_licenciatura',
'criterio_qualificacao_curso_aperfeicoamento',
'criterio_qualificacao_especializacao',
'criterio_qualificacao_mestrado',
'criterio_qualificacao_doutorado',
'criterio_desempenho_prova_conhecimento',
'criterio_desempenho_aluno',
'criterio_incorporacao_permanente_remuneracao',
'criterio_outro',
'lei_carga_horaria_interacao_aluno',
'carga_horaria_semanal_opcao_1',
'carga_horaria_semanal_opcao_2',
'carga_horaria_semanal_opcao_3',
'carga_horaria_semanal_opcao_4',
'carga_horaria_semanal_opcao_5',
'piso_salarial_definido_magisterio_publico',
'plano_carreira_nao_docente',
'lei_plano_carreira_nao_docente',
'ano_plano_carreira_nao_docente',
'conselho_educacao',
'lei_criacao_conselho_educacao',
'ano_criacao_conselho_educacao',
'formacao_conselho_educacao',
'carater_conselho_educacao_consultivo',
'carater_conselho_educacao_deliberativo',
'carater_conselho_educacao_normativo',
'carater_conselho_educacao_fiscalizador',
'conselho_educacao_reuniao_12_meses',
'conselho_educacao_integrante',
'conselho_educacao_capacitacao_periodicamente',
'conselho_educacao_capacitacao_ocasionalmente',
'conselho_educacao_nao_realiza_capacitacao',
'conselho_educacao_infraestrutura',
'conselho_educacao_infraestrutura_sala',
'conselho_educacao_infraestrutura_computador',
'conselho_educacao_infraestrutura_impressora',
'conselho_educacao_infraestrutura_acesso_internet',
'conselho_educacao_infraestrutura_veiculo',
'conselho_educacao_infraestrutura_telefone',
'conselho_educacao_infraestrutura_diarias',
'conselho_educacao_infraestrutura_dotacao_orcamentaria_propria',
'composicao_conselho_educacao_pais_alunos',
'composicao_conselho_educacao_assembleia_legislativa',
'composicao_conselho_educacao_diretor_escola_rede_estadual',
'composicao_conselho_educacao_servidor_escola_rede_estadual',
'composicao_conselho_educacao_conselho_tutelar',
'composicao_conselho_educacao_escola_privada',
'composicao_conselho_educacao_instituicao_ensino_superior',
'composicao_conselho_educacao_sindicato_educacao',
'composicao_conselho_educacao_secretaria_educacao',
'composicao_conselho_educacao_movimento_negro',
'composicao_conselho_educacao_comunidade_quilombola',
'composicao_conselho_educacao_povo_indigena',
'composicao_conselho_educacao_comunidade_tradicional',
'composicao_conselho_educacao_outro',
'funcao_gestor_educacao_conselho_educacao',
'conselho_fundeb',
'lei_criacao_conselho_fundeb',
'ano_criacao_conselho_fundeb',
'formacao_conselho_fundeb',
'conselho_fundeb_reuniao_12_meses',
'conselho_fundeb_integrantes',
'conselho_fundeb_capacitacao_periodicamente',
'conselho_fundeb_capacitacao_ocasionalmente',
'conselho_fundeb_nao_realiza_capacitacao',
'conselho_fundeb_infraestrutura',
'conselho_fundeb_infraestrutura_sala_propria',
'conselho_fundeb_infraestrutura_computador',
'conselho_fundeb_infraestrutura_impressora',
'conselho_fundeb_infraestrutura_acesso_internet',
'conselho_fundeb_infraestrutura_veiculo',
'conselho_fundeb_infraestrutura_telefone',
'conselho_fundeb_infraestrutura_diarias',
'conselho_fundeb_infraestrutura_dotacao_orcamentaria_propria',
'conselho_alimentacao_escolar',
'lei_criacao_conselho_alimentacao_escolar',
'ano_criacao_conselho_alimentacao_escolar',
'formacao_alimentacao_escolar',
'carater_conselho_alimentacao_escolar_consultivo',
'carater_conselho_alimentacao_escolar_deliberativo',
'carater_conselho_alimentacao_escolar_normativo',
'carater_conselho_alimentacao_escolar_fiscalizador',
'conselho_alimentacao_escolar_reuniao_12_meses',
'conselho_alimentacao_escolar_integrantes',
'conselho_alimentacao_escolar_capacitacao_periodicamente',
'conselho_alimentacao_escolar_capacitacao_ocasionalmente',
'conselho_alimentacao_escolar_nao_realiza_capacitacao',
'conselho_alimentacao_escolar_infraestrutura',
'conselho_alimentacao_escolar_infraestrutura_sala_propria',
'conselho_alimentacao_escolar_infraestrutura_computador',
'conselho_alimentacao_escolar_infraestrutura_impressora',
'conselho_alimentacao_escolar_infraestrutura_acesso_internet',
'conselho_alimentacao_escolar_infraestrutura_veiculo',
'conselho_alimentacao_escolar_infraestrutura_telefone',
'conselho_alimentacao_escolar_infraestrutura_diarias',
'conselho_alimentacao_escolar_infraestrutura_dotacao_orcamentaria_propria',
'conselho_transporte_escolar',
'lei_criacao_conselho_transporte_escolar',
'ano_criacao_conselho_transporte_escolar',
'formacao_conselho_transporte_escolar',
'carater_conselho_transporte_escolar_consultivo',
'carater_conselho_transporte_escolar_deliberativo',
'carater_conselho_transporte_escolar_normativo',
'carater_conselho_transporte_escolar_fiscalizador',
'conselho_transporte_escolar_reuniao_12_meses',
'conselho_transporte_escolar_integrantes',
'conselho_transporte_escolar_capacitacao_periodicamente',
'conselho_transporte_escolar_capacitacao_ocasionalmente',
'conselho_transporte_escolar_nao_realiza_capacitacao',
'conselho_transporte_escolar_infraestrutura',
'conselho_transporte_escolar_infraestrutura_sala_propria',
'conselho_transporte_escolar_infraestrutura_computador',
'conselho_transporte_escolar_infraestrutura_impressora',
'conselho_transporte_escolar_infraestrutura_acesso_internet',
'conselho_transporte_escolar_infraestrutura_veiculo_proprio',
'conselho_transporte_escolar_infraestrutura_telefone',
'conselho_transporte_escolar_infraestrutura_diarias',
'conselho_transporte_escolar_infraestrutura_dotacao_orcamentaria_propria',
'percentual_receita_municipio_destinado_ensino',
'responsabilidade_recurso_financeiro',
'lei_estadual_criacao_conselho_escolar',
'lei_conselho_escolar',
'ano_conselho_escolar',
'formacao_conselho_escolar',
'ordenacao_despesas_educacao',
'nomeacao_diretor_concurso_publico',
'nomeacao_diretor_livre',
'nomeacao_diretor_indicacao',
'nomeacao_diretor_eleicao',
'nomeacao_diretor_processo_seletivo',
'nomeacao_diretor_outro',
'programa_formacao_gestao_escolar_exercer_cargo',
'tipo_programa']]

caracterizacao_orgao_gestor = {'Secretaria exclusiva' : '1',
                               'Secretaria estadual em conjunto com outras políticas' : '2',
                               'Secretaria estadual exclusiva' : '3',
                               'Secretaria em conjunto com outras políticas setoriais' : '4'}

gestor_sexo = {'Masculino' : '1',
               'Feminino' : '2'}

gestor_raca_cor = {'Branca' : '1',
                   'Pardo' : '2'}
programa_curso = {'Escola de gestores da Educação Básica/ MEC (6)' : '1',
                  'Formação pela Escola/FNDE (7)' : '2',
                  'Programa Nacional de Formação Continuada à Distância nas Ações do FNDE' : '3',
                  'Programa de Apoio aos Dirigentes Municipais de Educação' : '4',
                  'Outro' : '5'}

gestor_escolaridade = {'Pós-graduação': '1',
                       'Especialização' : '2',
                       'Ensino superior completo' : '3',
                       'Mestrado' : '4',
                       'Doutorado' : '5',
                       'Ensino superior incompleto' : '6'}

gestor_escolaridade_formacao = {'Pedagogo' : '1',
                                'Advogado' : '2',
                                'Letras' : '3',
                                'Administração' : '4',
                                'Engenheiro' : '5',
                                'Físico' : '6',
                                'Jornalista' : '7',
                                'Educadora Artística': '8',
                                'Biólogo' : '9',
                                'Economista' : '10',
                                'Historiador' : '11',
                                'Geógrafo' : '12',
                                'Arquiteto' : '13',
                                'Outra': '14'}

instrumento_constituicao = {'Portaria' : '1',
                            'Decreto' : '2',
                            'Lei' : '3',
                            'Outro' : '4'}


formacao_conselho_educacao = {'Paritário' : '1',
                              'Tem maior representação da sociedade civil' : '2',
                              'Tem maior representação governamental' : '3',
                              'Não paritário' : '4'}

funcao_gestor_educacao_conselho_educacao = {'Participa apenas como ouvinte' : '1',
                                            'Membro nato' : '2',
                                            'Presidente do conselho' : '3',
                                            'Membro do conselho, como representante do poder executivo' : '4',
                                            'Participa somente como convidado' : '5'}


formacao_conselho_fundeb = {'Paritário' : '1',
                            'Tem maior representação da sociedade civil' : '2',
                            'Tem maior representação governamental' : '3'}

formacao_alimentacao_escolar = {'Paritário' : '1',
                                'Tem maior representação da sociedade civil' : '2',
                                'Não paritário' : '3'}

responsabilidade_recurso_financeiro = {'Órgão gestor da educação' : '1',
                                       'Outra estrutura estadual que não a educação' : '2'}

formacao_conselho_escolar = {'Paritários' : '1',
                             'Tem maior representação dos profissionais das escolas' : '2'}

ordenacao_despesas_educacao = {'Secretário de educação' : '1',
                               'Governador' : '2',
                               'Secretário de finanças/secretário de fazenda' : '3',
                               'Outros' : '4'}
                          
tipo_programa = {'Outra escola' : '1',
                 'Escola de Gestores da Educação Básica/MEC' : '2'}

df_completo['caracterizacao_orgao_gestor'] = df_completo['caracterizacao_orgao_gestor'].map(caracterizacao_orgao_gestor)
df_completo['gestor_sexo'] = df_completo['gestor_sexo'].map(gestor_sexo)
df_completo['gestor_raca_cor'] = df_completo['gestor_raca_cor'].map(gestor_raca_cor)
df_completo['gestor_escolaridade'] = df_completo['gestor_escolaridade'].map(gestor_escolaridade)
df_completo['programa_curso'] = df_completo['programa_curso'].map(programa_curso)
df_completo['gestor_escolaridade_formacao'] = df_completo['gestor_escolaridade_formacao'].map(gestor_escolaridade_formacao)
df_completo['formacao_conselho_educacao'] = df_completo['formacao_conselho_educacao'].map(formacao_conselho_educacao)
df_completo['funcao_gestor_educacao_conselho_educacao'] = df_completo['funcao_gestor_educacao_conselho_educacao'].map(funcao_gestor_educacao_conselho_educacao)
df_completo['formacao_conselho_fundeb'] = df_completo['formacao_conselho_fundeb'].map(formacao_conselho_fundeb)
df_completo['formacao_alimentacao_escolar'] = df_completo['formacao_alimentacao_escolar'].map(formacao_alimentacao_escolar)
df_completo['responsabilidade_recurso_financeiro'] = df_completo['responsabilidade_recurso_financeiro'].map(responsabilidade_recurso_financeiro)
df_completo['formacao_conselho_escolar'] = df_completo['formacao_conselho_escolar'].map(formacao_conselho_escolar)
df_completo['ordenacao_despesas_educacao'] = df_completo['ordenacao_despesas_educacao'].map(ordenacao_despesas_educacao)
df_completo['tipo_programa'] = df_completo['tipo_programa'].map(tipo_programa)
df_completo['instrumento_constituicao'] = df_completo['instrumento_constituicao'].map(instrumento_constituicao)

df_completo = df_completo.replace('-','').replace('(*) Não soube informar', '').replace('Não soube informar', '').replace(np.nan, '')
df_completo = df_completo.replace('Sim','1').replace('Não', '0')
df_completo['gestor_escolaridade_formacao'] = df_completo['gestor_escolaridade_formacao'].replace('Pedagogia', 'Pedagogo').replace('Direito', 'Advogado').replace('Administração', 'Administrador').replace('Física', 'Físico')

df_completo.to_csv(output + 'estadic.educacao.csv', index=False, na_rep='')
