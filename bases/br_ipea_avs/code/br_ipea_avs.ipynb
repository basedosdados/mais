# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/Shareddrives/Base dos Dados - Geral/Dados/Conjuntos/br_ipea_avs/input/atlasivs_dadosbrutos_pt.csv', sep = ';', encoding='latin1', dtype=str)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Renomeando as colunas de df

df = df.rename(columns={'ano':'ano',
'nome_uf' : 'sigla_uf',
'municipio' : 'id_municipio',
'municipio_6digt' : 'id_municipio_6',
'label_cor':'raca_cor',
'label_sexo':'sexo',
'label_sit_dom':'localizacao',
'ivs':'ivs',
'ivs_infraestrutura_urbana':'ivs_infraestrutura_urbana',
'ivs_capital_humano':'ivs_capital_humano',
'ivs_renda_e_trabalho':'ivs_renda_trabalho',
'idhm':'idhm',
'idhm_long':'idhm_l',
'idhm_educ':'idhm_e',
'idhm_renda':'idhm_r',
'idhm_educ_sub_esc':'idhm_subescolaridade',
'idhm_educ_sub_freq':'idhm_subfrequencia',
'prosp_soc':'prosperidade_social',
't_vulner_mais1h':'porporcao_vulnerabilidade_socioeconomica',
't_eletrica':'propocao_energia_eletrica',
't_densidadem2':'proporcao_domicilio_densidade',
't_sem_agua_esgoto':'proporcao_sem_agua_esgoto',
't_sem_lixo':'proporcao_sem_coleta',
'renda_per_capita':'renda_per_capita',
't_renda_todos_trabalhos':'renda_media_18_mais',
't_nremunerado_18m':'proporcao_sem_renda_18_mais',
't_renda_trab':'renda_trabalho',
'rdpc_def_vulner':'renda_per_capita_vulneravel',
't_vulner':'proporcao_vulneravel',
'vulner15a24':'vulneravel_15_24',
't_vulner_depende_idosos':'proporcao_vulneravel_dependente_idoso',
'dom_vulner_idoso':'populacao_vulneravel_e_idoso',
't_razdep':'razao_dependencia',
't_fectot':'fecundidade_total',
't_env':'taxa_envelhecimento',
't_mort1':'mortalidade_1_menos',
't_fmor5':'proporcao_mortalidade_5_menos',
't_c0a5_fora':'proporcao_crianca_fora_escola_0_5',
't_pop5a6_escola':'proporcao_escola_5_6',
't_c6a14_fora':'proporcao_crianca_fora_escola_6_14',
't_m10a17_filho':'proporcao_maternidade_10_17',
'mchefe_fmenor':'proporcao_maternidade_crianca_15_menos',
't_mchefe_fundin_fmenor':'proporcao_maternidade_fundamental_incompleto_crianca_15_menos',
't_analf_15m':'proporcao_analfabetismo_15_mais',
't_analf_18m':'proporcao_analfabetismo_18_mais',
't_analf_25m':'proporcao_analfabetismo_25_mais',
't_cdom_fundin':'proporcao_responsavel_fundamental_incompleto',
't_pop11a13_ffun':'proporcao_anos_finais_11_13',
't_pop15a17_fundc':'proporcao_fundamental_completo_15_17',
't_pop18m_fundc':'proporcao_fundamental_completo_18_mais',
't_pop18a20_medioc':'proporcao_medio_completo_18_20',
'vulner_dia':'populacao_ocupada_trabalho',
't_fundc_ocup18m':'proporcao_ocupado_fundamental_18_mais',
't_medioc_ocup18m':'proporcao_ocupado_medio_18_mais',
't_supec_ocup18m':'proporcao_ocupado_superior_18_mais',
't_p15a24_nada':'proporcao_desocupado_15_24',
't_desocup18m':'proporcao_desocupado_18_mais',
't_p18m_fundin_informal':'proporcao_ocupados_informal_18_mais',
't_carteira_18m':'proporcao_carteira_18_mais',
't_scarteira_18m':'proporcao_sem_carteira_18_mais',
't_setorpublico_18m':'proporcao_setor_publico_18_mais',
't_contapropria_18m':'proporcao_empreendedor_18_mais',
't_empregador_18m':'proporcao_empregador_18_mais',
't_formal_18m':'proporcao_mercado_formal_18_mais',
't_atividade10a14':'proporcao_atividade_10_14',
'pea10m':'pea_10_mais',
'pea10a14':'pea_10_14',
'pea15a17':'pea_15_17',
'pea18m':'pea_18_mais',
'espvida':'expectativa_vida',
'i_gini':'indice_gini',
'pop0a1':'populacao_0_1',
'pop1a3':'populacao_1_3',
'pop4':'populacao_4',
'pop5':'populacao_5',
'pop6':'populacao_6',
'pop6a10':'populacao_6_10',
'pop6a17':'populacao_6_17',
'pop11a13':'populacao_11_13',
'pop11a14':'populacao_11_14',
'pop12a14':'populacao_12_14',
'pop15m':'populacao_15_mais',
'pop15a17':'populacao_15_17',
'pop15a24':'populacao_15_24',
'pop16a18':'populacao_16_18',
'pop18m':'populacao_18_mais',
'pop18a20':'populacao_18_20',
'pop18a24':'populacao_18_24',
'pop19a21':'populacao_19_21',
'pop25m':'populacao_25_mais',
'pop65m':'populacao_65_mais'})

ufs = {'Acre':'AC', 'Alagoas':'AL', 'Amazonas':'AM', 'Amapá':'AP', 'Bahia':'BA', 'Ceará':'CE', 'Distrito Federal':'DF', 'Espírito Santo':'ES', 'Goiás':'GO', 
       'Maranhão':'MA', 'Minas Gerais':'MG', 'Mato Grosso do Sul':'MS', 'Mato Grosso':'MT', 'Pará':'PA', 'Paraíba':'PB', 'Pernambuco':'PE', 'Piauí':'PI', 
       'Paraná':'PR', 'Rio de Janeiro':'RJ', 'Rio Grande do Norte':'RN', 'Rondônia':'RO', 'Roraima':'RR', 'Rio Grande do Sul':'RS',
       'Santa Catarina':'SC', 'Sergipe':'SE', 'São Paulo':'SP', 'Tocantins':'TO'}

df['sigla_uf'] = df['sigla_uf'].map(ufs)

# loop for para realização de um replace

colunas = ['ivs',
'ivs_infraestrutura_urbana',
'ivs_capital_humano',
'ivs_renda_trabalho',
'idhm',
'idhm_l',
'idhm_e',
'idhm_r',
'idhm_subescolaridade',
'idhm_subfrequencia',
'porporcao_vulnerabilidade_socioeconomica',
'propocao_energia_eletrica',
'proporcao_domicilio_densidade',
'proporcao_sem_agua_esgoto',
'proporcao_sem_coleta',
'renda_per_capita',
'renda_media_18_mais',
'proporcao_sem_renda_18_mais',
'renda_trabalho',
'renda_per_capita_vulneravel',
'proporcao_vulneravel',
'proporcao_vulneravel_dependente_idoso',
'razao_dependencia',
'fecundidade_total',
'taxa_envelhecimento',
'mortalidade_1_menos',
'proporcao_mortalidade_5_menos',
'proporcao_crianca_fora_escola_0_5',
'proporcao_escola_5_6',
'proporcao_crianca_fora_escola_6_14',
'proporcao_maternidade_10_17',
'proporcao_maternidade_fundamental_incompleto_crianca_15_menos',
'proporcao_analfabetismo_15_mais',
'proporcao_analfabetismo_18_mais',
'proporcao_analfabetismo_25_mais',
'proporcao_responsavel_fundamental_incompleto',
'proporcao_anos_finais_11_13',
'proporcao_fundamental_completo_15_17',
'proporcao_fundamental_completo_18_mais',
'proporcao_medio_completo_18_20',
'proporcao_ocupado_fundamental_18_mais',
'proporcao_ocupado_medio_18_mais',
'proporcao_ocupado_superior_18_mais',
'proporcao_desocupado_15_24',
'proporcao_desocupado_18_mais',
'proporcao_ocupados_informal_18_mais',
'proporcao_carteira_18_mais',
'proporcao_sem_carteira_18_mais',
'proporcao_setor_publico_18_mais',
'proporcao_empreendedor_18_mais',
'proporcao_empregador_18_mais',
'proporcao_mercado_formal_18_mais',
'proporcao_atividade_10_14',
'expectativa_vida',
'indice_gini']
for x in colunas:
    df[x] = df[x].apply(lambda x: str(x).replace(',','.'))


# Substituindo as linhas vazias por -
df = df.replace(np.nan, '').replace('-', '').replace('nan', '')

# Replace cor
df['raca_cor'] = df['raca_cor'].replace('Total Cor', 'total').str.lower()

# Replace cor
df['sexo'] = df['sexo'].replace('Total Sexo', 'total').str.lower()
 
# Replace localização
df['localizacao'] = df['localizacao'].replace('Total Situação de Domicílio', 'total').str.lower()

# Replace Prosperidade Social

df['prosperidade_social'] = df['prosperidade_social'].str.lower()

# Visualizando todas as colunas do DataFrame. 
# Importante quando for trabalhar com muitas colunas
pd.set_option('display.max_columns', None)
pd.set_option('display.max_row', None)

# %% [markdown]
# # Brasil

# %%
df_brasil = df

df_brasil = df.drop(['id',
         'nivel',
         'regiao',
         'nome_regiao',
         'uf', 'sigla_uf',
         'rm',
         'nome_rm',
         'id_municipio',
         'id_municipio_6',
         'nome_municipio_uf',
         'udh',
         'nome_udh',
         'brasil'], axis=1)

# Reordenando as colunas

df_brasil = df[['ano',
'raca_cor',
'sexo',
'localizacao',
'ivs',
'ivs_infraestrutura_urbana',
'ivs_capital_humano',
'ivs_renda_trabalho',
'idhm',
'idhm_l',
'idhm_e',
'idhm_r',
'idhm_subescolaridade',
'idhm_subfrequencia',
'prosperidade_social',
'porporcao_vulnerabilidade_socioeconomica',
'propocao_energia_eletrica',
'proporcao_domicilio_densidade',
'proporcao_sem_agua_esgoto',
'proporcao_sem_coleta',
'renda_per_capita',
'renda_media_18_mais',
'proporcao_sem_renda_18_mais',
'renda_trabalho',
'renda_per_capita_vulneravel',
'proporcao_vulneravel',
'vulneravel_15_24',
'proporcao_vulneravel_dependente_idoso',
'populacao_vulneravel_e_idoso',
'razao_dependencia',
'fecundidade_total',
'taxa_envelhecimento',
'mortalidade_1_menos',
'proporcao_mortalidade_5_menos',
'proporcao_crianca_fora_escola_0_5',
'proporcao_escola_5_6',
'proporcao_crianca_fora_escola_6_14',
'proporcao_maternidade_10_17',
'proporcao_maternidade_crianca_15_menos',
'proporcao_maternidade_fundamental_incompleto_crianca_15_menos',
'proporcao_analfabetismo_15_mais',
'proporcao_analfabetismo_18_mais',
'proporcao_analfabetismo_25_mais',
'proporcao_responsavel_fundamental_incompleto',
'proporcao_anos_finais_11_13',
'proporcao_fundamental_completo_15_17',
'proporcao_fundamental_completo_18_mais',
'proporcao_medio_completo_18_20',
'populacao_ocupada_trabalho',
'proporcao_ocupado_fundamental_18_mais',
'proporcao_ocupado_medio_18_mais',
'proporcao_ocupado_superior_18_mais',
'proporcao_desocupado_15_24',
'proporcao_desocupado_18_mais',
'proporcao_ocupados_informal_18_mais',
'proporcao_carteira_18_mais',
'proporcao_sem_carteira_18_mais',
'proporcao_setor_publico_18_mais',
'proporcao_empreendedor_18_mais',
'proporcao_empregador_18_mais',
'proporcao_mercado_formal_18_mais',
'proporcao_atividade_10_14',
'pea_10_mais',
'pea_10_14',
'pea_15_17',
'pea_18_mais',
'expectativa_vida',
'indice_gini',
'populacao_0_1',
'populacao_1_3',
'populacao_4',
'populacao_5',
'populacao_6',
'populacao_6_10',
'populacao_6_17',
'populacao_11_13',
'populacao_11_14',
'populacao_12_14',
'populacao_15_mais',
'populacao_15_17',
'populacao_15_24',
'populacao_16_18',
'populacao_18_mais',
'populacao_18_20',
'populacao_18_24',
'populacao_19_21',
'populacao_25_mais',
'populacao_65_mais']]

df_brasil.to_csv('/content/drive/Shareddrives/Base dos Dados - Geral/Dados/Conjuntos/br_ipea_avs/output/brasil.csv', index=False, na_rep='')

# %% [markdown]
# # UF

# %%
# excluindo as colunas

uf = df.drop(['id',
         'nivel',
         'regiao',
         'nome_regiao',
         'uf',
         'rm',
         'nome_rm',
         'id_municipio',
         'id_municipio_6',
         'nome_municipio_uf',
         'udh',
         'nome_udh',
         'brasil'
        ], axis=1)


# Reordenando as colunas

uf = df[['ano',
'sigla_uf',
'raca_cor',
'sexo',
'localizacao',
'ivs',
'ivs_infraestrutura_urbana',
'ivs_capital_humano',
'ivs_renda_trabalho',
'idhm',
'idhm_l',
'idhm_e',
'idhm_r',
'idhm_subescolaridade',
'idhm_subfrequencia',
'prosperidade_social',
'porporcao_vulnerabilidade_socioeconomica',
'propocao_energia_eletrica',
'proporcao_domicilio_densidade',
'proporcao_sem_agua_esgoto',
'proporcao_sem_coleta',
'renda_per_capita',
'renda_media_18_mais',
'proporcao_sem_renda_18_mais',
'renda_trabalho',
'renda_per_capita_vulneravel',
'proporcao_vulneravel',
'vulneravel_15_24',
'proporcao_vulneravel_dependente_idoso',
'populacao_vulneravel_e_idoso',
'razao_dependencia',
'fecundidade_total',
'taxa_envelhecimento',
'mortalidade_1_menos',
'proporcao_mortalidade_5_menos',
'proporcao_crianca_fora_escola_0_5',
'proporcao_escola_5_6',
'proporcao_crianca_fora_escola_6_14',
'proporcao_maternidade_10_17',
'proporcao_maternidade_crianca_15_menos',
'proporcao_maternidade_fundamental_incompleto_crianca_15_menos',
'proporcao_analfabetismo_15_mais',
'proporcao_analfabetismo_18_mais',
'proporcao_analfabetismo_25_mais',
'proporcao_responsavel_fundamental_incompleto',
'proporcao_anos_finais_11_13',
'proporcao_fundamental_completo_15_17',
'proporcao_fundamental_completo_18_mais',
'proporcao_medio_completo_18_20',
'populacao_ocupada_trabalho',
'proporcao_ocupado_fundamental_18_mais',
'proporcao_ocupado_medio_18_mais',
'proporcao_ocupado_superior_18_mais',
'proporcao_desocupado_15_24',
'proporcao_desocupado_18_mais',
'proporcao_ocupados_informal_18_mais',
'proporcao_carteira_18_mais',
'proporcao_sem_carteira_18_mais',
'proporcao_setor_publico_18_mais',
'proporcao_empreendedor_18_mais',
'proporcao_empregador_18_mais',
'proporcao_mercado_formal_18_mais',
'proporcao_atividade_10_14',
'pea_10_mais',
'pea_10_14',
'pea_15_17',
'pea_18_mais',
'expectativa_vida',
'indice_gini',
'populacao_0_1',
'populacao_1_3',
'populacao_4',
'populacao_5',
'populacao_6',
'populacao_6_10',
'populacao_6_17',
'populacao_11_13',
'populacao_11_14',
'populacao_12_14',
'populacao_15_mais',
'populacao_15_17',
'populacao_15_24',
'populacao_16_18',
'populacao_18_mais',
'populacao_18_20',
'populacao_18_24',
'populacao_19_21',
'populacao_25_mais',
'populacao_65_mais']]

uf.to_csv('/content/drive/Shareddrives/Base dos Dados - Geral/Dados/Conjuntos/br_ipea_avs/output/uf.csv', index=False, na_rep='')

# %% [markdown]
# # Municipio

# %%
# excluindo as colunas

municipio=df.drop(['id',
         'nivel',
         'regiao',
         'nome_regiao',
         'uf',
         'rm',
         'nome_rm',
         'id_municipio_6',
         'nome_municipio_uf',
         'udh',
         'nome_udh',
         'brasil'
        ], axis=1)


# Reordenando as colunas

municipio = df[['ano',
'sigla_uf',
'id_municipio',
'raca_cor',
'sexo',
'localizacao',
'ivs',
'ivs_infraestrutura_urbana',
'ivs_capital_humano',
'ivs_renda_trabalho',
'idhm',
'idhm_l',
'idhm_e',
'idhm_r',
'idhm_subescolaridade',
'idhm_subfrequencia',
'prosperidade_social',
'porporcao_vulnerabilidade_socioeconomica',
'propocao_energia_eletrica',
'proporcao_domicilio_densidade',
'proporcao_sem_agua_esgoto',
'proporcao_sem_coleta',
'renda_per_capita',
'renda_media_18_mais',
'proporcao_sem_renda_18_mais',
'renda_trabalho',
'renda_per_capita_vulneravel',
'proporcao_vulneravel',
'vulneravel_15_24',
'proporcao_vulneravel_dependente_idoso',
'populacao_vulneravel_e_idoso',
'razao_dependencia',
'fecundidade_total',
'taxa_envelhecimento',
'mortalidade_1_menos',
'proporcao_mortalidade_5_menos',
'proporcao_crianca_fora_escola_0_5',
'proporcao_escola_5_6',
'proporcao_crianca_fora_escola_6_14',
'proporcao_maternidade_10_17',
'proporcao_maternidade_crianca_15_menos',
'proporcao_maternidade_fundamental_incompleto_crianca_15_menos',
'proporcao_analfabetismo_15_mais',
'proporcao_analfabetismo_18_mais',
'proporcao_analfabetismo_25_mais',
'proporcao_responsavel_fundamental_incompleto',
'proporcao_anos_finais_11_13',
'proporcao_fundamental_completo_15_17',
'proporcao_fundamental_completo_18_mais',
'proporcao_medio_completo_18_20',
'populacao_ocupada_trabalho',
'proporcao_ocupado_fundamental_18_mais',
'proporcao_ocupado_medio_18_mais',
'proporcao_ocupado_superior_18_mais',
'proporcao_desocupado_15_24',
'proporcao_desocupado_18_mais',
'proporcao_ocupados_informal_18_mais',
'proporcao_carteira_18_mais',
'proporcao_sem_carteira_18_mais',
'proporcao_setor_publico_18_mais',
'proporcao_empreendedor_18_mais',
'proporcao_empregador_18_mais',
'proporcao_mercado_formal_18_mais',
'proporcao_atividade_10_14',
'pea_10_mais',
'pea_10_14',
'pea_15_17',
'pea_18_mais',
'expectativa_vida',
'indice_gini',
'populacao_0_1',
'populacao_1_3',
'populacao_4',
'populacao_5',
'populacao_6',
'populacao_6_10',
'populacao_6_17',
'populacao_11_13',
'populacao_11_14',
'populacao_12_14',
'populacao_15_mais',
'populacao_15_17',
'populacao_15_24',
'populacao_16_18',
'populacao_18_mais',
'populacao_18_20',
'populacao_18_24',
'populacao_19_21',
'populacao_25_mais',
'populacao_65_mais']]

municipio = municipio.query("id_municipio != 'geral'")

municipio.to_csv('/content/drive/Shareddrives/Base dos Dados - Geral/Dados/Conjuntos/br_ipea_avs/output/municipio.csv', index=False, na_rep='')
